# %% [markdown]
# ## The Google of Quotes

# %% [markdown]
# The file “quotes.txt” contains pairs of lines, with the first line being a quote
# and the following line being the person who said it. We want to build a
# search engine that, given a word or words, finds the best matching quotes.

# %%
## Import the regular expressions library

import re
import math

# %%
## Open the file and read lines from the file

file = open('quotes.txt','r')
file_list = file.readlines()
file_list
# Out:
# ['How we spend our days is, of course, how we spend our lives.\n',
#  'Annie Dillard\n',
#  'Two roads diverged in a wood, and I...I took the one less traveled by, and that has made all the difference.\n',
#  'Robert Frost\n',
#  'What is happiness? The feeling that power is growing, that resistance is overcome.\n',
#  'Friedrich Nietzsche\n',
#  'A great deal of intelligence can be invested in ignorance when the need for illusion is deep.\n',
#  'Saul Bellow\n',
#  'Those who are preoccupied with `making a statement` usually don`t have any statements worth making.\n',
#  'Thomas Sowell\n',
#  'Women need a reason to have sex -- men just need a place.\n',
#  'Billy Crystal\n',
#  'The heart has its reasons, of which the mind knows nothing.\n',
#  'Blaise Pascal\n',
#  'It is necessary for the welfare of society that genius should be privileged to utter sedition, to blaspheme, to outrage good taste, to corrupt the youthful mind, and generally to scandalize one`s uncles.\n',
#  'George Bernard Shaw\n',
#  'Freedom is not something that anybody can be given; freedom is something people take and people are as free as they want to be.\n',
#  'James Baldwin\n',
#  'Collecting more taxes than is absolutely necessary is legalized robbery.\n',
#  'Calvin Coolidge\n',
#  'I almost had a pyschic girlfriend, but she left me before we met.\n',
#  'Steven Wright\n',
#  'The man who disobeys his parents will have disobedient sons.\n',
#  'Nachman of Bratslav\n',
#  'I know God will not give me anything I can`t handle. I just wish that He didn`t trust me so much.\n',
#  'Mother Teresa\n',
#  'When an American says that he loves his country, he means not only that he loves the New England hills, the prairies glistening in the sun, the wide and rising plains, the great mountains, and the sea. He means that he loves an inner air, an inner light in which freedom lives and in which a man can draw the breath of self-respect.\n',
#  'Adlai Stevenson\n',
#  'Words which do not give the light of Christ increase the darkness.\n',
#  'Mother Teresa\n',
#  'My dream is of a place and a time where America will once again be seen as the last best hope of earth.\n',
#  'Abraham Lincoln\n',
#  'An actor is at most a poet and at least an entertainer.\n',
#  'Marlon Brando\n',
#  'Humility is the foundation of all the other virtues hence, in the soul in which this virtue does not exist there cannot be any other virtue except in mere appearance.\n',
#  'Saint Augustine\n',
#  'The object of teaching a child is to enable him to get along without a teacher.\n',
#  'Elbert Hubbard\n',
#  'Avoid the base hypocrisy of condemning in one man what you pass over in silence when committed by another.\n',
#  'Theodore Roosevelt\n',
#  'Most football teams are temperamental. That`s 90% temper and 10% mental.\n',
#  'Doug Plank\n',
#  'There can be no liberty unless there is economic liberty.\n',
#  'Margaret Thatcher\n',
#  'Idealism is fine, but as it approaches reality, the costs become prohibitive.\n',
#  'William F. Buckley\n',
#  'I didn`t attend the funeral, but I sent a nice letter saying I approved of it.\n',
#  'Mark Twain\n',
#  'Every woman knows all about everything.\n',
#  'Rudyard Kipling\n',
#  'Perfect humility dispenses with modesty.\n',
#  'C.S. Lewis\n',
#  'I think a good gift for the president would be a chocolate revolver. And since he`s so busy, you`d probably have to run up to him and hand it to him.\n',
#  'Jack Handey\n',
#  'The thought of being president frightens me. I do not think I want the job.\n',
#  'Ronald Reagan\n',
#  'A journey of a thousand miles begins with a single step.\n',
#  'Confucius\n',
#  'Most modern freedom is at root fear. It is not so much that we are too bold to endure rules; it is rather that we are too timid to endure responsibilities.\n',
#  'GK Chesterton\n',
#  'Television is a medium of entertainment which permits millions of people to listen to the same joke at the same time, and yet remain lonesome.\n',
#  'T.S. Eliot\n',
#  'Imagination will often carry us to worlds that never were. But without it, we go nowhere.\n',
#  'Carl Sagan\n',
#  'In any fairly large and talkative community such as a university there is always the danger that those who think alike should gravitate together where they will henceforth encounter opposition only in the emasculated form of rumour that the outsiders say thus and thus. The absent are easily refuted, complacent dogmatism thrives, and differences of opinion are embittered by the group hostility. Each group hears not the best, but the worst, that the other group can say.\n',
#  'C.S. Lewis\n',
#  'Success does not consist in never making mistakes but in never making the same one a second time.\n',
#  'George Bernard Shaw\n',
#  'Take time to deliberate, but when the time for action has arrived, stop thinking and go in.\n',
#  'Napoleon Bonaparte\n',
#  'I`m never going to be famous. My name will never be writ large on the roster of Those Who Do Things. I don`t do any thing. Not one single thing. I used to bite my nails, but I don`t even do that any more.\n',
#  'Dorothy Parker\n',
#  'Money doesn`t talk, it swears.\n',
#  'Bob Dylan\n',
#  'Advertising is the life of trade.\n',
#  'Calvin Coolidge\n',
#  'Christmas can be celebrated in the school room with pine trees, tinsel and reindeers, but there must be no mention of the man whose birthday is being celebrated. One wonders how a teacher would answer if a student asked why it was called Christmas.\n',
#  'Ronald Reagan\n',
#  'Experience is that marvelous thing that enables you to recognize a mistake when you make it again.\n',
#  'Franklin Jones\n',
#  'He that would make his own liberty secure, must guard even his enemy from opposition; for if he violates this duty he establishes a precedent that will reach himself.\n',
#  'Thomas Paine\n',
#  'Originality is the fine art of remembering what you hear but forgetting where you heard it.\n',
#  'Laurence Peter\n',
#  'I arrive at the end of this review having done my duty as a critic. I have described the movie accurately and you have a good idea what you are in for if you go to see it. Most of you will not. I cannot argue with you. Some of you will--the brave and the curious. You embody the spirit of the man who first wondered what it would taste like to eat an oyster.\n',
#  'Roger Ebert\n',
#  'Men marry to make an end; women to make a beginning.\n',
#  'Alexis Dupuy\n',
#  'Show me a thoroughly satisfied man and I will show you a failure.\n',
#  'Thomas Edison\n',
#  'I have often wondered how it is that every man loves himself more than all the rest of men, but yet sets less value on his own opinion of himself than on the opinion of others.\n',
#  'Marcus Aurelius\n',
#  'You find out more about God from the Moral Law than from the univerise in general just as you find out more about a man by listening to his conversation than by looking at a house he has built.\n',
#  'C.S. Lewis\n',
#  'Instead of a trap door, what about a trap window? The guy looks out it, and if he leans too far, he falls out. Wait. I guess that`s like a regular window.\n',
#  'Jack Handey\n',
#  'Man was made for action, and to promote by the exertion of his faculties such changes in the external circumstances both of himself and others, as may seem most favourable to the happiness of all.\n',
#  'Adam Smith\n',
#  'In every man`s heart there is a secret nerve that answers to the vibrations of beauty.\n',
#  'Christopher Morley\n',
#  'If Jack`s in love, he`s no judge of Jill`s beauty.\n',
#  'Benjamin Franklin\n',
#  'The Democrats seem to be basically nicer people, but they have demonstrated time and again that they have the management skills of celery.\n',
#  'Dave Barry\n',
#  'Without courage, wisdom bears no fruit.\n',
#  'Baltasar Gracian\n',
#  'I thought it completely absurd to mention my name in the same breath as the Presidency.\n',
#  'Dwight Eisenhower\n',
#  'The only reason for time is so that everything doesn`t happen at once.\n',
#  'Albert Einstein\n',
#  'The fool doth think he is wise, but the wise man knows himself to be a fool.\n',
#  'William Shakespeare\n',
#  'You don`t have to stay up nights to succeed; you have to stay awake days.\n',
#  'Author Unknown\n',
#  'Life is what happens to you while you`re busy making other plans.\n',
#  'John Lennon\n',
#  'Fear not those who argue but those who dodge.\n',
#  'Dale Carnegie\n',
#  'I have a hobby...I have the world`s largest collection of sea shells. I keep it scattered on beaches all over the world. Maybe you`ve seen some of it...\n',
#  'Steven Wright\n',
#  'The art of being happy lies in the power of extracting happiness from common things.\n',
#  'Henry Ward Beecher\n',
#  'Demoralize the enemy from within by surprise, terror, sabotage, assassination. This is the war of the future.\n',
#  'Adolf Hitler\n',
#  'If eighty percent of your sales come from twenty percent of all of your items, just carry those twenty percent.\n',
#  'Henry Kissinger\n',
#  'It`s not how old you are, it`s how hard you work at it.\n',
#  'Jonah Barrington\n',
#  'What sunshine is to flowers, smiles are to humanity. These are but trifles, to be sure; but scattered along life`s pathway, the good they do is inconceivable.\n',
#  'Joseph Addison\n',
#  'You got to be very careful if you don`t know where you`re going, because you might not get there.\n',
#  'Yogi Berra\n',
#  'Life is not a support system for art. It`s the other way around.\n',
#  'Stephen King\n',
#  'Love is the delightful interval between meeting a beautiful girl and discovering that she looks like a haddock.\n',
#  'John Barrymore\n',
#  'The supernatural is the natural not yet understood.\n',
#  'Elbert Hubbard\n',
#  'Those who forget good and evil and seek only to know the facts are more likely to achieve good than those who view the world through the distorting medium of their own desires.\n',
#  'Bertrand Russell\n',
#  'Experience proves this, or that, or nothing, according to the preconceptions we bring to it.\n',
#  'C.S. Lewis\n',
#  'Nothing separates the generations more than music. By the time a child is eight or nine, he has developed a passion for his own music that is even stronger than his passions for procrastination and weird clothes.\n',
#  'Bill Cosby\n',
#  'The hour of departure has arrived, and we go our ways - I to die, and you to live. Which is better God only knows.\n',
#  'Plato\n',
#  'The statistics on sanity are that one out of every four Americans are suffering from some form of mental illness. Think of your three best friends. If they`re okay, then it`s you.\n',
#  'Rita Mae Brown\n',
#  'Nietzsche was stupid and abnormal.\n',
#  'Leo Tolstoy\n',
#  'Everybody can be great... because anybody can serve. You don`t have to have a college degree to serve. You don`t have to make your subject and verb agree to serve. You only need a heart full of grace. A soul generated by love.\n',
#  'Martin Luther King Jr.\n',
#  'People have a way of becoming what you encourage them to be, not what you nag them to be.\n',
#  'Author Unknown\n',
#  'All men are frauds. The only difference between them is that some admit it. I myself deny it.\n',
#  'Henry Mencken\n',
#  'America is not like a blanket: one piece of unbroken cloth, the same color, the same texture, the same size. America is more like a quilt: many patches, many pieces, many colors, many sizes, all woven and held together by a common thread.\n',
#  'Jesse Jackson\n',
#  'When nothing seems to help, I go and look at a stonecutter hammering away at his rock perhaps a hundred times without as much as a crack showing in it. Yet at the hundred and first blow it will split in two, and I know it was not that blow that did it, but all that had gone before.\n',
#  'Jacob August Riis\n',
#  'In any moment of decision, the best thing you can do is the right thing. The worst thing you can do is nothing.\n',
#  'Theodore Roosevelt\n',
#  'Self-denial is the shining sore on the leprous body of Christianity.\n',
#  'Oscar Wilde\n',
#  'I have never been hurt by what I have not said.\n',
#  'Calvin Coolidge\n',
#  'If you judge people, you have no time to love them.\n',
#  'Mother Teresa\n',
#  'The means of defense against foreign danger historically have become the instruments of tyranny at home.\n',
#  'James Madison\n',
#  'He who is not courageous enough to take risks will accomplish nothing in life.\n',
#  'Muhammad Ali\n',
#  'He that fights and runs away, may turn and fight another day; but he that is in battle slain, will never rise to fight again.\n',
#  'Tacitus\n',
#  'America did not invent human rights. In a very real sense...human rights invented America.\n',
#  'Jimmy Carter\n',
#  'No matter how much cats fight, there always seem to be plenty of kittens.\n',
#  'Abraham Lincoln\n',
#  'Success, the real success, does not depend upon the position you hold but upon how you carry yourself in that position.\n',
#  'Theodore Roosevelt\n',
#  'Happiness makes up in height for what it lacks in length.\n',
#  'Robert Frost\n',
#  'Poetry is the art of creating imaginary gardens with real toads.\n',
#  'Marianne Moore\n',
#  'It is by the goodness of God that, in this country, we have three benefits: freedom of speech, freedom of thought, and the wisdom never to use either.\n',
#  'Mark Twain\n',
#  'The Bible is not my book, and Christianity is not my religion. I could never give assent to the long, complicated statements of Christian dogma.\n',
#  'Abraham Lincoln\n',
#  'He wrapped himself in quotations--as a beggar would enfold himself in the purple of Emperors.\n',
#  'Rudyard Kipling\n',
#  'The truth is always a trick to those who live among lies.\n',
#  'Author Unknown\n',
#  'What you do speaks so loudly that I cannot hear what you say.\n',
#  'Ralph Waldo Emerson\n',
#  'All glory is fleeting.\n',
#  'George Patton\n',
#  'No distance of place or lapse of time can lessen the friendship of those who are thoroughly persuaded of each other`s worth.\n',
#  'Robert Southey\n',
#  'Washington is a city of Southern efficiency and Northern charm.\n',
#  'John F. Kennedy\n',
#  'If you`re in a boxing match, try not to let the other guy`s glove touch your lips, because you don`t know where that glove has been.\n',
#  'Jack Handey\n',
#  'Never discourage anyone who continually makes progress, no matter how slow.\n',
#  'Plato\n',
#  'Not only is there no God, but try finding a plumber on Sunday.\n',
#  'Woody Allen\n',
#  'Rome remained free for four hundred years and Sparta eight hundred, although their citizens were armed all that time; but many other states that have been disarmed have lost their liberties in less than forty years.\n',
#  'Nicolo Machiavelli\n',
#  'Science without religion is lame, religion without science is blind.\n',
#  'Albert Einstein\n',
#  'Knowledge rests not upon truth alone, but upon error also.\n',
#  'Carl Jung\n',
#  'In politics shared hatreds are almost always the basis of friendships.\n',
#  'Alexis de Tocqueville\n',
#  'Genius may have its limitations, but stupidity is not thus handicapped.\n',
#  'Elbert Hubbard\n',
#  'In life, as in art, the beautiful moves in curves.\n',
#  'Edward Bulwer-Lytton\n',
#  'I planted some bird seed. A bird came up. Now I don`t know what to feed it.\n',
#  'Steven Wright\n',
#  'Not everybody trusts paintings, but people believe photographs.\n',
#  'Ansel Adams\n',
#  'The things that will destroy America are prosperity at any price, peace at any price, safety first instead of duty first, the love of soft living and the get rich quick theory of life.\n',
#  'Theodore Roosevelt\n',
#  'There are people who put their dreams in a little box and say, Yes, I`ve got dreams, of course I`ve got dreams. Then they put the box away and bring it out once in awhile to look in it, and yep, they`re still there.\n',
#  'Erna Bombeck\n',
#  'Knowledge comes, but wisdom lingers.\n',
#  'Calvin Coolidge\n',
#  'Men are born ignorant, not stupid; they are made stupid by education.\n',
#  'Bertrand Russell\n',
#  'If we do not help a man in trouble, it is as if we caused the trouble.\n',
#  'Nachman of Bratslav\n',
#  'Patience is the companion of wisdom.\n',
#  'Saint Augustine\n',
#  'Marriage is our last, best chance to grow up.\n',
#  'Joseph Barth\n',
#  'Patriotism is not short, frenzied outbursts of emotion, but the tranquil and steady dedication of a lifetime.\n',
#  'Adlai Stevenson\n',
#  'A man`s very highest moment is, I have no doubt at all, when he kneels in the dust, and beats his breast, and tells all the sins of his life.\n',
#  'Oscar Wilde\n',
#  'Associate yourself with men of good quality if you esteem your own reputation; for `tis better to be alone than in bad company.\n',
#  'George Washington\n',
#  'Beauty is all very well at first sight; but whoever looks at it when it has been in the house three days?\n',
#  'George Bernard Shaw\n',
#  'I had a dream the other night. I dreamed that Jimmy Carter came to me and asked why I wanted his job. I told him I didn`t want his job. I want to be President.\n',
#  'Ronald Reagan\n',
#  'To assert that the earth revolves around the sun is as erroneous as to claim that Jesus was not born of a virgin.\n',
#  'Cardinal Bellarmine\n',
#  'Reality is that which, when you stop believing in it, doesn`t go away.\n',
#  'Phillip K. Dick\n',
#  'Deliberation and debate is the way you stir the soul of our democracy.\n',
#  'Jesse Jackson\n',
#  'Nothing noble is done without risk.\n',
#  'André Gide\n',
#  'Fatherhood is pretending the present you love most is soap on-a-rope.\n',
#  'Bill Cosby\n',
#  'No nation keeps its word. A nation is a big, blind worm, following what? Fate perhaps. A nation has no honor, it has no word to keep.\n',
#  'Carl Jung\n',
#  'Democracy means that anyone can grow up to be president, and anyone who doesn`t grow up can be vice president.\n',
#  'Johnny Carson\n',
#  'All men desire to know.\n',
#  'Aristotle\n',
#  'Women are the only realists; their whole object in life is to pit their realism against the extravagant, excessive, and occasionally drunken idealism of men.\n',
#  'GK Chesterton\n',
#  'Don`t go around saying the world owes you a living. The world owes you nothing. It was here first.\n',
#  'Mark Twain\n',
#  'I could not handle being a woman, I would stay home all day and play with my breasts.\n',
#  'Steve Martin\n',
#  'I confess, I do not believe in time.\n',
#  'Vladimir Nabokov\n',
#  'Man is the only animal that blushes - or needs to.\n',
#  'Mark Twain\n',
#  'True wisdom comes to each of us when we realize how little we understand about life, ourselves, and the world around us.\n',
#  'Socrates\n',
#  'Any reviewer who expresses rage and loathing for a novel is preposterous. He or she is like a person who has put on full armor and attacked a hot fudge sundae.\n',
#  'Kurt Vonnegut\n',
#  'There is no substitute for hard work.\n',
#  'Thomas Edison\n',
#  'Cast your cares on God; that anchor holds.\n',
#  'Frank Moore Colby\n',
#  'She is not perfect. You are not perfect. The question is whether or not you are perfect for each other.\n',
#  'Robin Williams\n',
#  'Fanaticism consists of redoubling your efforts when you have forgotten your aim.\n',
#  'George Santayana\n',
#  'Government is not reason; it is not eloquent; it is force. Like fire, it is a dangerous servant and a fearful master.\n',
#  'George Washington\n',
#  'Let us not forget that the cultivation of the earth is the most important labor of man. When tillage begins, other arts will follow. The farmers, therefore, are the founders of civilization.\n',
#  'Daniel Webster\n',
#  'A right delayed is a right denied.\n',
#  'Martin Luther King Jr.\n',
#  'Against criticism a man can neither protest nor defend himself; he must act in spite of it, and then it will gradually yield to him.\n',
#  'Johann Wolfgang von Goethe\n',
#  'Everything is simpler than you think and at the same time more complex than you imagine.\n',
#  'Johann Wolfgang von Goethe\n',
#  'The world is full of suffering. It is also full of overcoming it.\n',
#  'Helen Keller\n',
#  'Love is repaid by love alone!\n',
#  'Mother Teresa\n',
#  'The only way to keep your health is to eat what you don`t want, drink what you don`t like, and do what you`d rather not.\n',
#  'Mark Twain\n',
#  'No man but a blockhead ever wrote, except for money.\n',
#  'Samuel Johnson\n',
#  'It behooves every man to remember that the work of the critic is of altogether secondary importance, and that, in the end, progress is accomplished by the man who does things.\n',
#  'Theodore Roosevelt\n',
#  'Why are people`s ``deepest desires`` always so shallow?\n',
#  'Author Unknown\n',
#  'Were it possible for us to wait for ourselves to come into the room, not many of us would find our hearts breaking into flower as we heard the door handle turn.\n',
#  'Rebecca West\n',
#  'Thus the metric system did not really catch on in the States, unless you count the increasing popularity of the nine-millimeter bullet.\n',
#  'Dave Barry\n',
#  'Ask not what your country can do for you - ask what you can do for your country.\n',
#  'John F. Kennedy\n',
#  'It is error alone which needs the support of government. Truth can stand by itself.\n',
#  'Thomas Jefferson\n',
#  'To have the reputation of possessing the most perfect social tact, talk to every woman as if you loved her, and to every man as if he bored you.\n',
#  'Oscar Wilde\n',
#  'Remember, if you smoke after sex you`re doing it too fast.\n',
#  'Woody Allen\n',
#  'Fame is a fickle food upon a shifting plate.\n',
#  'Emily Dickinson\n',
#  'Philosophy is to the real world as masturbation is to sex.\n',
#  'Karl Marx\n',
#  'It is always thus, impelled by a state of mind which is destined not to last, that we make our irrevocable decisions.\n',
#  'Marcel Proust\n',
#  'Love anything and your heart will be wrung and possibly broken. If you want to make sure of keeping it intact you must give it to no one, not even an animal. Wrap it carefully round with hobbies and little luxuries; avoid all entanglements. Lock it up safe in the casket or coffin of your selfishness. But in that casket, safe, dark, motionless, airless, it will change. It will not be broken; it will become unbreakable, impenetrable, irredeemable. To love is to be vulnerable.\n',
#  'C.S. Lewis\n',
#  'Ignorance more frequently begets confidence than does knowledge.\n',
#  'Charles Darwin\n',
#  'When I see a play and understand it the first time, then I know it can`t be much good.\n',
#  'T.S. Eliot\n',
#  'To explain the unknown by the known is a logical procedure; to explain the known by the unknown is a form of theological lunacy.\n',
#  'David Brooks\n',
#  'I mistrust the judgment of every man in a case in which his own wishes are concerned.\n',
#  'Daniel Webster\n',
#  'We ascribe beauty to that which is simple; which has no superfluous parts; which exactly answers its end; which stands related to all things; which is the mean of many extremes.\n',
#  'Ralph Waldo Emerson\n',
#  'Americans are so enamored of equality, they would rather be equal in slavery than unequal in freedom.\n',
#  'Alexis de Tocqueville\n',
#  'In the long run, we shape our lives and we shape ourselves. The process never ends until we die, and the choices that we make are ultimately our responsibility.\n',
#  'Eleanor Roosevelt\n',
#  'Don`t ever take a fence down until you know why it was put up.\n',
#  'Robert Frost\n',
#  'I am Envy. I cannot read and therefore wish all books burned.\n',
#  'Christopher Marlowe\n',
#  'Of all bad men religious bad men are the worst.\n',
#  'C.S. Lewis\n',
#  'God`s colors all are fast.\n',
#  'John Greenleaf Whittier\n',
#  'Christmas is a time when you get homesick, even when you`re home.\n',
#  'Carol Nelson\n',
#  'We all wish to be judged by our peers, by the men `after our own heart.` Only they really know our mind and only they judge it by standards we fully acknowledge. Theirs is the praise we really covet and the blame we really dread. The little pockets of early Chrstians survived because they cared exclusively for the love of `the bretheren` and stopped their ears to the opinion of the Pagan society around them. But a circle of criminals, cranks, or perverts survives in just the same way; by becoming deaf to the opinion of the outer world, by discounting it as the chatter of outsiders who `don`t understand,` of the `conventional,` the `bourgeois,` the `Establishment,` of prigs, prudes, and humbugs.\n',
#  'C.S. Lewis\n',
#  'Duties are not performed for duty`s sake, but because their neglect would make the man uncomfortable. A man performs but one duty - the duty of contenting his spirit, the duty of making himself agreeable to himself.\n',
#  'Mark Twain\n',
#  'A free society is one where it is safe to be unpopular.\n',
#  'Adlai Stevenson\n',
#  'If variety is the spice of life, marriage is the big can of leftover Spam.\n',
#  'Johnny Carson\n',
#  'Truth sits upon the lips of dying men.\n',
#  'Matthew Arnold\n',
#  'As a woman, I find it very embarrassing to be in a meeting and realize I`m the only one in the room with balls.\n',
#  'Rita Mae Brown\n',
#  'A mind that is stretched by a new experience can never go back to its old dimensions.\n',
#  'Oliver Wendell Holmes\n',
#  'If there is any principle of the Constitution that more imperatively calls for attachment than any other it is the principle of free thought, not free thought for those who agree with us but freedom for the thought that we hate.\n',
#  'Oliver Wendell Holmes\n',
#  'Thus far, the reputed idiot Bush has graduated from Yale and Harvard, made a stack of cash in the oil industry, become the first consecutive-term governor of Texas, defeated a dual-term VP for the presidency, and led his party to [November 5th`s] extraordinary triumphs. Let his opponents keep calling him stupid; if they do, within five years Bush will be King of England, the Pope, and world Formula One motor racing champion.\n',
#  'Tim Blair\n',
#  'All art is but imitation of nature.\n',
#  'Lucius Annaeus Seneca\n',
#  'We should take care not to make the intellect our god; it has, of course, powerful muscles, but no personality.\n',
#  'Albert Einstein\n',
#  'Every author should weigh his work and ask, `Will humanity gain any benefit from it?`\n',
#  'Nachman of Bratslav\n',
#  'The older I grow the more I distrust the familiar doctrine that age brings wisdom.\n',
#  'Henry Mencken\n',
#  'The significant problems we face cannot be solved at the same level of thinking we were at when we created them.\n',
#  'Albert Einstein\n',
#  'Heroism is not only in the man, but in the occasion.\n',
#  'Calvin Coolidge\n',
#  'Nothing is wrong with Southern California that a rise in the ocean level wouldn`t cure.\n',
#  'Kenneth Millar\n',
#  'Nothing that you have not given away will ever be really yours.\n',
#  'C.S. Lewis\n',
#  'A `geek` by definition is someone who eats live animals....I`ve never eaten live animals.\n',
#  'Crispin Glover\n',
#  'Politics is perhaps the only profession for which no preparation is thought necessary.\n',
#  'Robert Louis Stevenson\n',
#  'The only kind of seafood I trust is the fish stick, a totally featureless fish that doesn`t have eyeballs or fins.\n',
#  'Dave Barry\n',
#  'I have never taken any exercise except sleeping and resting.\n',
#  'Mark Twain\n',
#  'Skepticism is a virtue in history as well as in philosophy.\n',
#  'Napoleon Bonaparte\n',
#  'The sleeping fox catches no poultry.\n',
#  'Benjamin Franklin\n',
#  'Obstacles do not exist to be surrendered to, but only to be broken.\n',
#  'Adolf Hitler\n',
#  'A man can`t be too careful in the choice of his enemies.\n',
#  'Oscar Wilde\n',
#  'After silence, that which comes nearest to expressing the inexpressible is Music.\n',
#  'Aldous Huxley\n',
#  'To one who has faith, no explanation is necessary. To one without faith, no explanation is possible.\n',
#  'Thomas Aquinas\n',
#  'Thinking is the hardest work there is, which is the probable reason why so few engage in it.\n',
#  'Henry Ford\n',
#  'A government which robs Peter to pay Paul can always depend on the support of Paul.\n',
#  'George Bernard Shaw\n',
#  'Don`t let people drive you crazy when you know it`s in walking distance.\n',
#  'Author Unknown\n',
#  'Well-timed silence hath more eloquence than speech.\n',
#  'Martin Farquhar Tupper\n',
#  'The first principle is that you must not fool yourself - and you are the easiest person to fool.\n',
#  'Richard P. Feynman\n',
#  'Guard with jealous attention the public liberty. Suspect everyone who approaches that jewel.\n',
#  'Patrick Henry\n',
#  'In the beginning, the universe was created. This made a lot of people very angry, and has been widely regarded as a bad idea.\n',
#  'Douglas Adams\n',
#  'Anyone who invokes authors in discussion is not using his intelligence but his memory.\n',
#  'Leonardo da Vinci\n',
#  'To me there has never been a higher source of earthly honor or distinction than that connected with advances in science.\n',
#  'Isaac Newton\n',
#  'You know, there`s a million fine looking women in the world, dude. But they don`t all bring you lasagna at work. Most of `em just cheat on you.\n',
#  'Kevin Smith\n',
#  'Government consists in nothing else but so controlling subjects that they shall neither be able to, nor have cause to do it harm.\n',
#  'Nicolo Machiavelli\n',
#  'There is no glory in battle worth the blood it costs.\n',
#  'Dwight Eisenhower\n',
#  'Being born is like being kidnapped. And then sold into slavery.\n',
#  'Andy Warhol\n',
#  'The magic of first love is our ignorance that it can never end.\n',
#  'Benjamin Disraeli\n',
#  'Art, like morality, consists in drawing the line somewhere.\n',
#  'GK Chesterton\n',
#  'If music be the food of love, play on.\n',
#  'William Shakespeare\n',
#  'Politics has got so expensive that it takes lots of money to even get beat with.\n',
#  'Will Rogers\n',
#  'Back in the old days, most families were close-knit. Grown children and their parents continued to live together, under the same roof, sometimes in the same small, crowded room, year in and year out, until they died, frequently by strangulation.\n',
#  'Dave Barry\n',
#  'Without computers, the government would be unable to function at the level of effectiveness and efficiency that we have come to expect.  This is because the primary function of the government is -- and here I am quoting directly from the U.S. Constitution -- `to spew out paper.`\n',
#  'Dave Barry\n',
#  'In politics, if you want anything said, ask a man; if you want anything done, ask a woman.\n',
#  'Margaret Thatcher\n',
#  'Nobody can have the consolations of religion or philosophy unless he has first experienced their desolations.\n',
#  'Aldous Huxley\n',
#  'Everything that irritates us about others can lead us to an understanding of ourselves.\n',
#  'Carl Jung\n',
#  'I`m not normally a religious man, but if you`re up there, save me, Superman!\n',
#  'Homer Simpson\n',
#  'The practice of art isn`t to make a living. It`s to make your soul grow.\n',
#  'Kurt Vonnegut\n',
#  'There cannot be true democracy unless women`s voices are heard.\n',
#  'Hillary Clinton\n',
#  'Just as your hand, held before the eye, can hide the tallest mountain, so this small earthly life keeps us from seeing the vast radiance that fills the core of the universe.\n',
#  'Nachman of Bratslav\n',
#  'There are several good protections against temptation, but the surest is cowardice.\n',
#  'Mark Twain\n',
#  'A Native American elder once described his own inner struggles in this manner: Inside of me there are two dogs. One of the dogs is mean and evil. The other dog is good. The mean dog fights the good dog all the time. When asked which dog wins, he reflected.\n',
#  'George Bernard Shaw\n',
#  'Surely what a man does when he is caught off his guard is the best evidence as to what sort of man he is.\n',
#  'C.S. Lewis\n',
#  'For each illness that doctors cure with medicine, they provoke ten in healthy people by inoculating them with the virus that is a thousand times more powerful than any microbe: the idea that one is ill.\n',
#  'Marcel Proust\n',
#  'When I took office, only high energy physicists had ever heard of what is called the Worldwide Web....now even my cat has its own page.\n',
#  'Bill Clinton\n',
#  'The president cannot escape from his office.\n',
#  'Dwight Eisenhower\n',
#  'Of all the animals, man is the only one that lies.\n',
#  'Mark Twain\n',
#  'The greatest thing in this world is not so much where we are, but in what direction we are moving.\n',
#  'Oliver Wendell Holmes\n',
#  'How did it get so late so soon? It`s night before it`s afternoon. December is here before it`s June. My goodness how the time has flewn. How did it get so late so soon?\n',
#  'Theodor Seuss Geisel\n',
#  'Humor is mankind`s greatest blessing.\n',
#  'Mark Twain\n',
#  'It takes a lot of courage to show your dreams to someone else.\n',
#  'Erna Bombeck\n',
#  'I love Thanksgiving. It`s the only time in Los Angeles that you see natural breasts.\n',
#  'Arnold Schwarzenegger\n',
#  'The aging process has you firmly in its grasp if you never get the urge to throw a snowball.\n',
#  'Doug Larson\n',
#  'The surest way of spoiling a pleasure is to start examining your satisfaction.\n',
#  'C.S. Lewis\n',
#  'There are some who`ve forgotten why we have a military. It`s not to promote war; it`s to be prepared for peace.\n',
#  'Ronald Reagan\n',
#  'Bashfulness is an ornament to youth, but a reproach to old age.\n',
#  'Aristotle\n',
#  'You are never too old to set another goal or to dream a new dream.\n',
#  'C.S. Lewis\n',
#  'If you could kick the person in the pants responsible for most of your trouble, you wouldn`t sit for a month.\n',
#  'Theodore Roosevelt\n',
#  'The philosophy of one century is the common sense of the next.\n',
#  'Henry Ward Beecher\n',
#  'The broad masses of a population are more amenable to the appeal of rhetoric than to any other force.\n',
#  'Adolf Hitler\n',
#  'Plato was a bore.\n',
#  'Friedrich Nietzsche\n',
#  'The MPAA rates this PG-13. It is too vulgar for anyone under 13, and too dumb for anyone over 13.\n',
#  'Roger Ebert\n',
#  'Dying is the most embarrassing thing that can ever happen to you, because someone`s got to take care of all your details.\n',
#  'Andy Warhol\n',
#  'It has been said that man is a rational animal. All my life I have been searching for evidence which could support this.\n',
#  'Bertrand Russell\n',
#  'The laws of gravity cannot be held responsible for people falling in love.\n',
#  'Albert Einstein\n',
#  'Of course the people dont want war...that is understood. But voice or no voice, the people can always be brought to the bidding of the leaders. That is easy. All you have to do is tell them they are being attacked, and denounce the pacifists for lack of patriotism and exposing the country to danger. It works the same in any country.\n',
#  'Hermann Goering\n',
#  'One thing they never tell you about child raising is that for the rest of your life, at the drop of a hat, you are expected to know your child`s name and how old he or she is.\n',
#  'Erna Bombeck\n',
#  'If we have no peace, it is because we have forgotten that we belong to each other.\n',
#  'Mother Teresa\n',
#  'I think it`s the duty of the comedian to find out where the line is drawn and cross it deliberately.\n',
#  'George Carlin\n',
#  'Nothing in the world is more dangerous than sincere ignorance and conscientious stupidity.\n',
#  'Martin Luther King Jr.\n',
#  'If a man is called to be a streetsweeper, he should sweep streets even as Michelangelo painted, or Beethoven composed music, or Shakespeare wrote poetry. He should sweep streets so well that all the host of heaven and earth will pause to say, here lived a great streetsweeper who did his job well.\n',
#  'Martin Luther King Jr.\n',
#  'There is a great deal of difference between an eager man who wants to read a book and the tired man who wants a book to read.\n',
#  'GK Chesterton\n',
#  'To find out a girl`s faults, praise her to her girl friends.\n',
#  'Benjamin Franklin\n',
#  'Forever is composed of nows.\n',
#  'Emily Dickinson\n',
#  'Alexander, Caesar, Charlemagne, and myself founded empires; but what foundation did we rest the creations of our genius? Upon force. Jesus Christ founded an empire upon love; and at this hour millions of men would die for Him.\n',
#  'Napoleon Bonaparte\n',
#  'Man`s best possession is a sympathetic wife.\n',
#  'Euripides\n',
#  'A grandmother pretends she doesn`t know who you are on Halloween.\n',
#  'Erna Bombeck\n',
#  'Perhaps one of the most important accomplishments of my administration has been minding my own business.\n',
#  'Calvin Coolidge\n',
#  'Laughter is the sun that drives winter from the human face.\n',
#  'Victor Hugo\n',
#  'If I feel physically as if the top of my head were taken off, I know that is poetry.\n',
#  'Emily Dickinson\n',
#  'Love is a fruit in season at all times, and within reach of every hand.\n',
#  'Mother Teresa\n',
#  'Having someone wonder where you are when you don`t come home at night is a very old human need.\n',
#  'Margaret Mead\n',
#  'I paid too much for it, but it`s worth it.\n',
#  'Samuel Goldwyn\n',
#  'I think the best possible social program is a job.\n',
#  'Ronald Reagan\n',
#  'Ocean: A body of water occupying 2/3 of a world made for man...who has no gills.\n',
#  'Ambrose Bierce\n',
#  'Moral indignation is jealousy with a halo.\n',
#  'H.G. Wells\n',
#  'Information is not knowledge.\n',
#  'Albert Einstein\n',
#  'The price of greatness is responsibility.\n',
#  'Winston Churchill\n',
#  'There is hope for the future because God has a sense of humor and we are funny to God.\n',
#  'Bill Cosby\n',
#  'Why, you can take the most gallant sailor, the most intrepid airman or the most audacious soldier, put them at a table together - what do you get? The sum of their fears.\n',
#  'Winston Churchill\n',
#  'The mind of the thoroughly well-informed man is a dreadful thing. It is like a bric-à-brac shop, all monsters and dust, with everything priced above its proper value.\n',
#  'Oscar Wilde\n',
#  'Cooking was invented in prehistoric times, when a primitive tribe had a lucky accident. The tribe had killed an animal and was going to eat it raw, when a tribe member named Woog tripped and dropped it into the fire. At first the other tribe members were angry at Woog, but then, as the aroma of burning meat filled the air, they had an idea. So they ate Woog raw.\n',
#  'Dave Barry\n',
#  'I have been the artist with the longest career, and I am so proud and honoured to be chosen from heaven to be invincible.\n',
#  'Michael Jackson\n',
#  'On the plus side, death is one of the few things that can be done just as easily lying down.\n',
#  'Woody Allen\n',
#  'If we will be quiet and ready enough, we shall find compensation in every disappointment.\n',
#  'Henry Thoreau\n',
#  'I get to go to lots of overseas places, like Canada.\n',
#  'Britney Spears\n',
#  'Imagination is a quality given a man to compensate him for what he is not, and a sense of humor was provided to console him for what he is.\n',
#  'Oscar Wilde\n',
#  'Without music, life would be a mistake.\n',
#  'Friedrich Nietzsche\n',
#  'I will honor Christmas in my heart, and try to keep it all the year.\n',
#  'Charles Dickens\n',
#  'Don`t walk in front of me, I may not follow. Don`t walk behind me, I may not lead. Just walk beside me and be my friend.\n',
#  'Albert Camus\n',
#  'You can`t depend on your eyes when your imagination is out of focus.\n',
#  'Mark Twain\n',
#  'I like your Christ, I do not like your Christians. Your Christians are so unlike your Christ.\n',
#  'Mahatma Gandhi\n',
#  'Let us now set forth one of the fundamental truths about marriage: the wife is in charge.\n',
#  'Bill Cosby\n',
#  'True patriotism hates injustice in its own land more than anywhere else.\n',
#  'Clarence Darrow\n',
#  'If a man is proud of his wealth, he should not be praised until it is known how he employs it.\n',
#  'Socrates\n',
#  'I like to say that I`m bisexual...when I want sex, I buy it.\n',
#  'Boy George\n',
#  'We`ve got to live. No matter how many skies have fallen.\n',
#  'D.H. Lawrence\n',
#  'Do good by stealth, and blush to find it fame.\n',
#  'Alexander Pope\n',
#  'There is a theory which states that if ever anyone discovers exactly what the Universe is for and why it is here, it will instantly disappear and be replaced by something even more bizarre and inexplicable. There is another theory which states that this has already happened.\n',
#  'Douglas Adams\n',
#  'I don`t care what is written about me, so long as it isn`t true.\n',
#  'Dorothy Parker\n',
#  'Get mad, then get over it.\n',
#  'Colin Powell\n',
#  'I always cheer up immensely if an attack is particularly wounding because I think, well, if they attack one personally, it means they have not a single political argument left.\n',
#  'Margaret Thatcher\n',
#  'Observe constantly that all things take place by change, and accustom thyself to consider that the nature of the Universe love nothing so much as to change. The Universe is change.\n',
#  'Marcus Aurelius\n',
#  'You give me a credit to which I have no claim in calling me `the writer of the Constitution of the United States.` This was not, like the fabled Goddess of Wisdom, the offspring of a single brain. It ought to be regarded as the work of many heads and many hands.\n',
#  'James Madison\n',
#  'Since love grows within you, so beauty grows. For love is the beauty of the soul.\n',
#  'Saint Augustine\n',
#  'You know you`re getting old when the candles cost more than the cake.\n',
#  'Bob Hope\n',
#  'Freedom is the right to question and change the established way of doing things. It is the continuous revolution of the marketplace. It is the understanding that allows us to recognize shortcomings and seek solutions.\n',
#  'Ronald Reagan\n',
#  'There is time for everything.\n',
#  'Thomas Edison\n',
#  'The nation which forgets its defenders will be itself forgotten.\n',
#  'Calvin Coolidge\n',
#  'Show me your hands. Do they have scars from giving? Show me your feet. Are they wounded in service? Show me your heart. Have you left a place for divine love?\n',
#  'Fulton J. Sheen\n',
#  'There are no secrets to success. It is the result of preparation, hard work, and learning from failure.\n',
#  'Colin Powell\n',
#  'The movie`s director is the pilot. It`s his vision. For an actor, the time to worry about flying is when you`re on the ground. If you don`t want to fly with the director, don`t get on the plane.\n',
#  'Denzel Washington\n',
#  'My aim is to put down on paper what I see and what I feel in the best and simplest way.\n',
#  'Ernest Hemingway\n',
#  'Don`t marry a man to reform him - that`s what reform schools are for.\n',
#  'Mae West\n',
#  'Analyzing humor is like dissecting a frog. Few people are interested and the frog dies of it.\n',
#  'E.B. White\n',
#  'If you`re afraid to ask the question, it`s probably because you already know the answer.\n',
#  'Miriam M. Wynn\n',
#  'You should do your own car repairs. It`s an easy way to save money and possibly maim yourself for life.\n',
#  'Dave Barry\n',
#  'The ACLU is always yakking about the Constitution, and most of us are getting mighty tired of it. I mean, if the Constitution is so great, how come it was amended so many times? Huh?\n',
#  'Dave Barry\n',
#  'One definition of an economist is somebody who sees something happen in practice and wonders if it will work in theory.\n',
#  'Ronald Reagan\n',
#  'Chicago sounds rough to the maker of verse. One comfort we have: Cincinnati sounds worse.\n',
#  'Oliver Wendell Holmes\n',
#  'There are men in all ages who mean to govern well, but they mean to govern. They promise to be good masters, but they mean to be masters.\n',
#  'Daniel Webster\n',
#  'A leader is a man who can adapt principles to circumstances.\n',
#  'George Patton\n',
#  'Sex at age ninety is like trying to shoot pool with a rope.\n',
#  'George Burns\n',
#  'You don`t take a photograph, you make it.\n',
#  'Ansel Adams\n',
#  'The mintage of wisdom is to know that rest is rust, and that real life is in love, laughter, and work.\n',
#  'Elbert Hubbard\n',
#  'He therefore is the truest friend to the liberty of this country who tries most to promote its virtue, and who, so far as his power and influence extend, will not suffer a man to be chosen into any office of power and trust who is not a wise and virtuous man.\n',
#  'Samuel Adams\n',
#  'The biggest bore is the person who is bored by everyone and everything.\n',
#  'Frank Tyger\n',
#  'I hate war as only a soldier who has lived it can, only as one who has seen its brutality, its futility, its stupidity.\n',
#  'Dwight Eisenhower\n',
#  'Success is going from failure to failure without losing enthusiasm.\n',
#  'Winston Churchill\n',
#  'We have the Bill of Rights. What we need is a Bill of Responsibilities.\n',
#  'Bill Maher\n',
#  'Even peace may be purchased at too high a price.\n',
#  'Benjamin Franklin\n',
#  'The last thing a political party gives up is its vocabulary.\n',
#  'Alexis de Tocqueville\n',
#  'Many of life`s failures are people who did not realize how close they were to success when they gave up.\n',
#  'Thomas Edison\n',
#  'We are what we repeatedly do. Excellence, therefore, is not an act, but a habit.\n',
#  'Aristotle\n',
#  'Would you live with ease? Do what you ought, not what you please.\n',
#  'Benjamin Franklin\n',
#  'Men have always been afraid that women could get along without them.\n',
#  'Margaret Mead\n',
#  'Being is desirable because it is identical with Beauty, and Beauty is loved because it is Being. We ourselves possess Beauty when we are true to our own being; ugliness is in going over to another order; knowing ourselves, we are beautiful; in self-ignorance, we are ugly.\n',
#  'Ambrose Bierce\n',
#  'Money never made a man happy yet, nor will it. There is nothing in its nature to produce happiness. The more a man has, the more he wants. Instead of its filling a vacuum, it makes one. If it satisfies one want, it doubles and trebles that want another way. That was a true proverb of the wise man, rely upon it; ``Better is little with the fear of the Lord, than great treasure, and trouble therewith.\n',
#  'Benjamin Franklin\n',
#  'Science is not about building a body of known `facts`. It is a method for asking awkward questions and subjecting them to a reality-check, thus avoiding the human tendency to believe whatever makes us feel good.\n',
#  'Terry Pratchett\n',
#  'A man is never more truthful than when he acknowledges himself a liar.\n',
#  'Mark Twain\n',
#  'The writer’s job is not to judge, but to seek to understand.\n',
#  'Ernest Hemingway\n',
#  'When in doubt, do it.\n',
#  'Oliver Wendell Holmes\n',
#  'This is the second most exciting indoor sport, and the other one shouldn`t have spectators.\n',
#  'Dick Vertleib\n',
#  'Nothing before had ever made me thoroughly realise, though I had read various scientific books, that science consists in grouping facts so that general laws or conclusions may be drawn from them.\n',
#  'Charles Darwin\n',
#  'Death and life have their determined appointments; riches and honors depend upon heaven.\n',
#  'Confucius\n',
#  'Those who expect to reap the blessings of freedom must, like men, undergo the fatigue of supporting it.\n',
#  'Thomas Paine\n',
#  'Maturity is a bitter disappointment for which no remedy exists, unless laughter can be said to remedy anything.\n',
#  'Kurt Vonnegut\n',
#  'Once you have flown, you will walk the earth with your eyes turned skywards, for there you have been, and there you long to return.\n',
#  'Leonardo da Vinci\n',
#  'Let him who desires peace prepare for war.\n',
#  'Vegetius\n',
#  'We live in an age when unnecessary things are our only necessities.\n',
#  'Oscar Wilde\n',
#  'A typical vice of American politics is the avoidance of saying anything real on real issues.\n',
#  'Theodore Roosevelt\n',
#  '`Tis the business of little minds to shrink, but he whose heart is firm, and whose conscience approves his conduct, will pursue his principles unto death.\n',
#  'Thomas Paine\n',
#  'It is impossible to experience one`s death objectively and still carry a tune.\n',
#  'Woody Allen\n',
#  'Serious sport has nothing to do with fair play. It is bound up with hatred, jealousy, boastfulness, disregard of all rules and sadistic pleasure in witnessing violence. In other words: it is war minus the shooting.\n',
#  'George Orwell\n',
#  'How did it happen that their lips came together? How does it happen that birds sing, that snow melts, that the rose unfolds, that the dawn whitens behind the stark shapes of trees on the quivering summit of the hill? A kiss, and all was said.\n',
#  'Victor Hugo\n',
#  'Four-fifths of all our troubles would disappear, if we would only sit down and keep still.\n',
#  'Calvin Coolidge\n',
#  'Character is what you are in the dark.\n',
#  'John Whorfin\n',
#  'Opera is when a guy gets stabbed in the back and, instead of bleeding, he sings.\n',
#  'Ed Gardner\n',
# ...
#  'People sleep peaceably in their beds at night only because rough men stand ready to do violence on their behalf.\n',
#  'George Orwell\n',
#  'Are you entitled to the fruits of your labor or does government have some presumptive right to spend and spend and spend?\n',
#  'Ronald Reagan\n',
#  'Don`t worry about the world coming to an end today. It`s already tomorrow in Australia.\n',
#  'Charles Schulz\n',
#  'There are painters who transform the sun to a yellow spot, but there are others who with the help of their art and their intelligence, transform a yellow spot into the sun.\n',
#  'Pablo Picasso\n',
#  'What I don`t like about office Christmas parties is looking for a job the next day.\n',
#  'Phyllis Diller\n',
#  'Never give in--never, never, never, never, in nothing great or small, large or petty, never give in except to convictions of honour and good sense. Never yield to force; never yield to the apparently overwhelming might of the enemy.\n',
#  'Winston Churchill\n',
#  'They that can give up essential liberty to obtain a little temporary safety deserve neither liberty nor safety.\n',
#  'Benjamin Franklin\n',
#  'This is slavery, not to speak one`s thought.\n',
#  'Euripides\n',
#  'Where knowledge ends, religion begins.\n',
#  'Benjamin Disraeli\n',
#  'For me, survival is the ability to cope with difficulties, with circumstances, and to overcome them.\n',
#  'Nelson Mandela\n',
#  'I went out to the country so i could examine the simple things in life.\n',
#  'Henry Thoreau\n',
#  'Of course I don`t believe in it. But I understand that it brings you luck whether you believe in it or not.\n',
#  'Niels Bohr\n',
#  'In all chaos there is a cosmos, in all disorder a secret order.\n',
#  'Carl Jung\n',
#  'The direction in which education starts a man will determine his future life.\n',
#  'Plato\n',
#  'If society fits you comfortably enough, you call it freedom.\n',
#  'Robert Frost\n',
#  'I hope that when you are my age, you will be able to say as I have been able to say: We lived in freedom. We lived lives that were a statement, not an apology.\n',
#  'Ronald Reagan\n',
#  'In Heaven all the interesting people are missing.\n',
#  'Friedrich Nietzsche\n',
#  'The days of looking the other way while despotic regimes trample human rights, rob their nations` wealth, and then excuse their failings by feeding their people a steady diet of anti-Western hatred are over.\n',
#  'Dick Cheney\n',
#  'If tyranny and oppression come to this land, it will be in the guise of fighting a foreign enemy.\n',
#  'James Madison\n',
#  'I love deadlines. I especially like the whooshing sound they make as they go flying by.\n',
#  'Douglas Adams\n',
#  'I made this letter longer than usual because I lack the time to make it short.\n',
#  'Blaise Pascal\n',
#  'There is only one force of history that can break the reign of hatred and resentment, and expose the pretensions of tyrants, and reward the hopes of the decent and tolerant, and that is the force of human freedom.\n',
#  'George W. Bush\n',
#  'Dogs look up to you. Cats look down on you. Pigs treat you like equals.\n',
#  'Winston Churchill\n',
#  'The act of policing is, in order to punish less often, to punish more severely.\n',
#  'Napoleon Bonaparte\n',
#  'The health of a democratic society may be measured by the quality of functions performed by private citizens.\n',
#  'Alexis de Tocqueville\n',
#  'Nobody expects to trust his body overmuch after the age of fifty.\n',
#  'Alexander Hamilton\n',
#  'An oppressive government is more to be feared than a tiger.\n',
#  'Confucius\n',
#  'I`m a middle age white guy, which means I`m constantly reminded that my particular group is responsible for the oppression of every known minority PLUS most wars PLUS government corruption PLUS pollution of the environment, not to mention that it was middle-age white guys who killed Bambi`s mom.\n',
#  'Dave Barry\n',
#  'I cried because I had no shoes, `till I met a man who had no feet. So I said, `You got any shoes you`re not using`?\n',
#  'Steven Wright\n',
#  'New knowledge is the most valuable commodity on earth. The more truth we have to work with, the richer we become.\n',
#  'Kurt Vonnegut\n',
#  'The giving of love is an education in itself.\n',
#  'Eleanor Roosevelt\n',
#  'By a curious confusion, many modern critics have passed from the proposition that a masterpiece may be unpopular to the other proposition that unless it is unpopular it cannot be a masterpiece.\n',
#  'GK Chesterton\n',
#  'Such is the delicacy of man alone, that no object is produced to his liking. He finds that in everything there is need for improvement. The whole industry of human life is employed not in procuring the supply of our three humble necessities, food, clothes and lodging, but in procuring the conveniences of it according to the nicety and delicacy of our tastes.\n',
#  'Adam Smith\n',
#  'Being president is like being a jackass in a hailstorm. There`s nothing to do but stand there and take it.\n',
#  'Lyndon B. Johnson\n',
#  'Men marry because they are tired; women because they are curious. Both are disappointed.\n',
#  'Oscar Wilde\n',
#  'The greatest happiness of life is the conviction that we are loved, loved for ourselves, or rather, loved in spite of ourselves.\n',
#  'Victor Hugo\n',
#  'Though I am not naturally honest, I am sometimes by chance.\n',
#  'William Shakespeare\n',
#  'Experts tell us that if the Millennium Bug is not fixed, when the year 2000 arrives, our financial records will be inaccurate, our telephone system will be unreliable, our government will be paralyzed and airline flights will be canceled without warning. In other words, things will be pretty much the same as they are now.\n',
#  'Dave Barry\n',
#  'People can misinterpret almost anything so that it coincides with views they already hold. They take from art what they already believe.\n',
#  'Stanley Kubrick\n',
#  'In framing a government which is to be administered by men over men the great difficulty lies in this: You must first enable the government to control the governed, and in the next place, oblige it to control itself.\n',
#  'Alexander Hamilton\n',
#  'There`s nothing sadder in this world than to awake Christmas morning and not be a child.\n',
#  'Erna Bombeck\n',
#  'When we die, our bodies are buried. When we live, our souls are buried.\n',
#  'Jason Mechalek\n',
#  'You must be the change you wish to see in the world.\n',
#  'Mahatma Gandhi\n',
#  'The eyes of the world are upon you. The hopes and prayers of liberty-loving people everywhere march with you.\n',
#  'Dwight Eisenhower\n',
#  'No man will make a great leader who wants to do it all himself or get all the credit for doing it.\n',
#  'Andrew Carnegie\n',
#  'Three grand essentials to happiness in this life are something to do, something to love, and something to hope for.\n',
#  'Joseph Addison\n',
#  'Trust the people. This is the one irrefutable lesson of the entire postwar period contradicting the notion that rigid government controls are essential to economic development.\n',
#  'Ronald Reagan\n',
#  'Education is an admirable thing, but it is well to remember from time to time that nothing that is worth knowing can be taught.\n',
#  'Oscar Wilde\n',
#  'I love writing. I love the swirl and swing of words as they tangle with human emotions.\n',
#  'James Michener\n',
#  'It is only our bad temper that we put down to being tired or worried or hungry; we put our good temper down to ourselves.\n',
#  'C.S. Lewis\n',
#  'This country was built on rape, slavery, murder, degradation and affiliation with crime.\n',
#  'Mike Tyson\n',
#  'The good thing about being bisexual is that it doubles your chance of a date on a Saturday night.\n',
#  'Woody Allen\n',
#  'Every year, back comes Spring, with nasty little birds yapping their fool heads off and the ground all mucked up with plants.\n',
#  'Dorothy Parker\n',
#  'Every difference of opinion is not a difference of principle. We have called by different names brethren of the same principle.\n',
#  'Thomas Jefferson\n',
#  'The best way to win an argument is to begin by being right.\n',
#  'Jill Ruckleshaus\n',
#  'You can discover more about a person in an hour of play than in a year of conversation.\n',
#  'Plato\n',
#  'To think is to differ.\n',
#  'Clarence Darrow\n',
#  'I have come to the conclusion that my subjective account of my motivation is largely mythical on almost all occasions. I don`t know why I do things.\n',
#  'J.B.S. Haldane\n',
#  'If your kid makes one of those little homemade guitars out of a cigar box and rubber bands, don`t let him just play it once or twice and then throw it away. Make him practice on it, every day, for about three hours a day. Later, he`ll thank you.\n',
#  'Jack Handey\n',
#  'I feel impelled to speak today in a language that in a sense is new-one which I, who have spent so much of my life in the military profession, would have preferred never to use. That new language is the language of atomic warfare.\n',
#  'Dwight Eisenhower\n',
#  'To write a good love letter, you ought to begin without knowing what you mean to say and to finish without knowing what you have written.\n',
#  'Jean-Jacques Rousseau\n',
#  'Accept the challenges so that you can feel the exhilaration of victory.\n',
#  'George Patton\n',
#  'God enters by a private door into every individual.\n',
#  'Ralph Waldo Emerson\n',
#  'To grasp the full significance of life is the actor`s duty, to interpret it is his problem and to express it his dedication.\n',
#  'Marlon Brando\n',
#  'There is one thing alone that stands the brunt of life throughout its course: a quiet conscience.\n',
#  'Euripides\n',
#  'Mothers are fonder than fathers of their children because they are more certain they are their own.\n',
#  'Aristotle\n',
#  'If we command our wealth, we shall be rich and free; if our wealth commands us, we are poor indeed.\n',
#  'Edmund Burke\n',
#  'The great nations have always acted like gangsters, and the small nations like prostitutes.\n',
#  'Stanley Kubrick\n',
#  'When angry, count ten before you speak; if very angry, a hundred.\n',
#  'Thomas Jefferson\n',
#  'Don`t ask God to change the laws of nature for you.\n',
#  'Nachman of Bratslav\n',
#  'It is said that gifts persuade even the gods.\n',
#  'Euripides\n',
#  'PRESIDENCY, n. The greased pig in the field game of American politics.\n',
#  'Ambrose Bierce\n',
#  'Those who make peaceful revolution impossible will make violent revolution inevitable.\n',
#  'John F. Kennedy\n',
#  'As scarce as truth is, the supply has always been in excess of the demand.\n',
#  'Josh Billings\n',
#  'A people that values its privileges above its principles soon loses both.\n',
#  'Dwight Eisenhower\n',
#  'A University of Chicago professor said the greatest day in the world was when a water puppy crawled out on land and decided to stay. The water puppy, he said, went on to become a man. If he proves that, I am willing to give up Christmas, Thanksgiving, and New Year`s Day, and to celebrate Water Puppy Day.\n',
#  'William Jennings Bryan\n',
#  'You know what the fellow said: In Italy for thirty years under the Borgias they had warfare, terror, murder, and bloodshed, but they produced Michaelangelo, Leonardo Da Vinci, and the Renaissance. In Switzerland, they had brotherly love--they had five hundred years of democracy and peace, and what did they produce? The cuckoo clock.\n',
#  'Orson Welles\n',
#  'The leading cause of death among fashion models is falling through street grates.\n',
#  'Dave Barry\n',
#  'If you have an apple and I have an apple and we exchange these apples then you and I will still each have one apple. But if you have an idea and I have an idea and we exchange these ideas, then each of us will have two ideas.\n',
#  'George Bernard Shaw\n',
#  'Some succeed by what they know; some by what they do; and a few by what they are.\n',
#  'Elbert Hubbard\n',
#  'Philosophy is questions that may never be answered. Religion is answers that may never be questioned.\n',
#  'Author Unknown\n',
#  'My formula for success is rise early, work late, and strike oil.\n',
#  'Paul Getty\n',
#  'Intoxicated with unbroken success, we have become too self-sufficient to feel the necessity of redeeming and preserving grace, too proud to pray to the God that made us.\n',
#  'Abraham Lincoln\n',
#  'I`ve had a wonderful time, but this wasn`t it.\n',
#  'Groucho Marx\n',
#  'The difference between sex and death is that with death you can do it alone and no one is going to make fun of you.\n',
#  'Woody Allen\n',
#  'When you have the facts on your side, argue the facts. When you have the law on your side, argue the law. When you have neither, holler.\n',
#  'Al Gore\n',
#  'The worst moment for the athieist is when he feels thankful and has no one to thank.\n',
#  'Dante Gabriel Rossetti\n',
#  'It is most unwise for people in love to marry.\n',
#  'George Bernard Shaw\n',
#  'Reason is experimental intelligence, conceived after the pattern of science, and used in the creation of social arts; it has something to do. It liberates man from the bondage of the past, due to ignorance and accident hardened into custom. It projects a better future and assists man in its realization.\n',
#  'John Dewey\n',
#  'Playwriting gets into your blood and you can`t stop it. At least, not until the producers or the public tell you to.\n',
#  'T.S. Eliot\n',
#  'Though force can protect in emergency, only justice, fairness, consideration and cooperation can finally lead men to the dawn of eternal peace.\n',
#  'Dwight Eisenhower\n',
#  'Wedding: a ceremony at which two persons undertake to become one, one undertakes to become nothing, and nothing undertakes to become supportable.\n',
#  'Ambrose Bierce\n',
#  'Just because I look sexy on the cover of Rolling Stone doesn`t mean I`m naughty.\n',
#  'Britney Spears\n',
#  'Slang is the language which takes off its coat, spits on its hands - and goes to work.\n',
#  'Carl Sandburg\n',
#  'It is a scientific fact that your body will not absorb cholesterol if you take it from another person`s plate.\n',
#  'Dave Barry\n',
#  'Having a male gynecologist is like going to an auto mechanic who doesn`t own a car.\n',
#  'Carrie Snow\n',
#  'Always leave something to wish for; otherwise you will be miserable from your very happiness.\n',
#  'Baltasar Gracian\n',
#  'In the Orthodox spiritual tradition, the ultimate moral question we ask is the following: Is what we are doing, is what I am doing, beautiful or not?\n',
#  'Carolyn Gifford\n',
#  'Don`t take life too seriously; you`ll never get out of it alive.\n',
#  'Elbert Hubbard\n',
#  'America is the only country ever founded on a creed.\n',
#  'GK Chesterton\n',
#  'Theology is only thought applied to religion.\n',
#  'GK Chesterton\n',
#  'Every man must decide whether he will walk in the light of creative altruism or in the darkness of destructive selfishness.\n',
#  'Martin Luther King Jr.\n',
#  'Mothers all want their sons to grow up to be president, but they don`t want them to become politicians in the process.\n',
#  'John F. Kennedy\n',
#  'Love means loving the unlovable - or it is no virtue at all.\n',
#  'GK Chesterton\n',
#  'It does not require a majority to prevail, but rather an irate, tireless minority keen to set brush fires in people`s minds.\n',
#  'Samuel Adams\n',
#  'To be a philosopher is not merely to have subtle thoughts; but so to love wisdom as to live according to its dictates.\n',
#  'Henry Thoreau\n',
#  'Corrupt politicians make the other ten percent look bad.\n',
#  'Henry Kissinger\n',
#  'To be awake is to be alive.\n',
#  'Henry Thoreau\n',
#  'Black holes are where God divided by zero.\n',
#  'Steven Wright\n',
#  'He that cannot obey, cannot command.\n',
#  'Benjamin Franklin\n',
#  'The puritanism of Christianity has played havoc with the moderation that an enlightened and tolerant critical spirit would have produced. I`ve noticed that in whatever country, county, town, or other region there is a regulation enjoining temperance, the population seems to be entirely composed of teetotallers and drunkards. There`s a Bible on that shelf there. But I keep it next to Voltaire - poison and antidote.\n',
#  'Bertrand Russell\n',
#  'She was what we used to call a suicide blond - dyed by her own hand.\n',
#  'Saul Bellow\n',
#  ...]

# %% [markdown]
# #### (a) Building a list of full quotes
# First, read in the file, and create
# a list of full quotes of the form “quote - speaker”. <br>

# %%
## Create a new list with the quote and author as part of the same list element

list_of_quotes = list()
for i in range(0, len(file_list), 2) :
    quote =  file_list[i].rstrip() + ' - ' + file_list[i+1].rstrip()

    list_of_quotes.append(quote)

list_of_quotes
# Out:
# ['How we spend our days is, of course, how we spend our lives. - Annie Dillard',
#  'Two roads diverged in a wood, and I...I took the one less traveled by, and that has made all the difference. - Robert Frost',
#  'What is happiness? The feeling that power is growing, that resistance is overcome. - Friedrich Nietzsche',
#  'A great deal of intelligence can be invested in ignorance when the need for illusion is deep. - Saul Bellow',
#  'Those who are preoccupied with `making a statement` usually don`t have any statements worth making. - Thomas Sowell',
#  'Women need a reason to have sex -- men just need a place. - Billy Crystal',
#  'The heart has its reasons, of which the mind knows nothing. - Blaise Pascal',
#  'It is necessary for the welfare of society that genius should be privileged to utter sedition, to blaspheme, to outrage good taste, to corrupt the youthful mind, and generally to scandalize one`s uncles. - George Bernard Shaw',
#  'Freedom is not something that anybody can be given; freedom is something people take and people are as free as they want to be. - James Baldwin',
#  'Collecting more taxes than is absolutely necessary is legalized robbery. - Calvin Coolidge',
#  'I almost had a pyschic girlfriend, but she left me before we met. - Steven Wright',
#  'The man who disobeys his parents will have disobedient sons. - Nachman of Bratslav',
#  'I know God will not give me anything I can`t handle. I just wish that He didn`t trust me so much. - Mother Teresa',
#  'When an American says that he loves his country, he means not only that he loves the New England hills, the prairies glistening in the sun, the wide and rising plains, the great mountains, and the sea. He means that he loves an inner air, an inner light in which freedom lives and in which a man can draw the breath of self-respect. - Adlai Stevenson',
#  'Words which do not give the light of Christ increase the darkness. - Mother Teresa',
#  'My dream is of a place and a time where America will once again be seen as the last best hope of earth. - Abraham Lincoln',
#  'An actor is at most a poet and at least an entertainer. - Marlon Brando',
#  'Humility is the foundation of all the other virtues hence, in the soul in which this virtue does not exist there cannot be any other virtue except in mere appearance. - Saint Augustine',
#  'The object of teaching a child is to enable him to get along without a teacher. - Elbert Hubbard',
#  'Avoid the base hypocrisy of condemning in one man what you pass over in silence when committed by another. - Theodore Roosevelt',
#  'Most football teams are temperamental. That`s 90% temper and 10% mental. - Doug Plank',
#  'There can be no liberty unless there is economic liberty. - Margaret Thatcher',
#  'Idealism is fine, but as it approaches reality, the costs become prohibitive. - William F. Buckley',
#  'I didn`t attend the funeral, but I sent a nice letter saying I approved of it. - Mark Twain',
#  'Every woman knows all about everything. - Rudyard Kipling',
#  'Perfect humility dispenses with modesty. - C.S. Lewis',
#  'I think a good gift for the president would be a chocolate revolver. And since he`s so busy, you`d probably have to run up to him and hand it to him. - Jack Handey',
#  'The thought of being president frightens me. I do not think I want the job. - Ronald Reagan',
#  'A journey of a thousand miles begins with a single step. - Confucius',
#  'Most modern freedom is at root fear. It is not so much that we are too bold to endure rules; it is rather that we are too timid to endure responsibilities. - GK Chesterton',
#  'Television is a medium of entertainment which permits millions of people to listen to the same joke at the same time, and yet remain lonesome. - T.S. Eliot',
#  'Imagination will often carry us to worlds that never were. But without it, we go nowhere. - Carl Sagan',
#  'In any fairly large and talkative community such as a university there is always the danger that those who think alike should gravitate together where they will henceforth encounter opposition only in the emasculated form of rumour that the outsiders say thus and thus. The absent are easily refuted, complacent dogmatism thrives, and differences of opinion are embittered by the group hostility. Each group hears not the best, but the worst, that the other group can say. - C.S. Lewis',
#  'Success does not consist in never making mistakes but in never making the same one a second time. - George Bernard Shaw',
#  'Take time to deliberate, but when the time for action has arrived, stop thinking and go in. - Napoleon Bonaparte',
#  'I`m never going to be famous. My name will never be writ large on the roster of Those Who Do Things. I don`t do any thing. Not one single thing. I used to bite my nails, but I don`t even do that any more. - Dorothy Parker',
#  'Money doesn`t talk, it swears. - Bob Dylan',
#  'Advertising is the life of trade. - Calvin Coolidge',
#  'Christmas can be celebrated in the school room with pine trees, tinsel and reindeers, but there must be no mention of the man whose birthday is being celebrated. One wonders how a teacher would answer if a student asked why it was called Christmas. - Ronald Reagan',
#  'Experience is that marvelous thing that enables you to recognize a mistake when you make it again. - Franklin Jones',
#  'He that would make his own liberty secure, must guard even his enemy from opposition; for if he violates this duty he establishes a precedent that will reach himself. - Thomas Paine',
#  'Originality is the fine art of remembering what you hear but forgetting where you heard it. - Laurence Peter',
#  'I arrive at the end of this review having done my duty as a critic. I have described the movie accurately and you have a good idea what you are in for if you go to see it. Most of you will not. I cannot argue with you. Some of you will--the brave and the curious. You embody the spirit of the man who first wondered what it would taste like to eat an oyster. - Roger Ebert',
#  'Men marry to make an end; women to make a beginning. - Alexis Dupuy',
#  'Show me a thoroughly satisfied man and I will show you a failure. - Thomas Edison',
#  'I have often wondered how it is that every man loves himself more than all the rest of men, but yet sets less value on his own opinion of himself than on the opinion of others. - Marcus Aurelius',
#  'You find out more about God from the Moral Law than from the univerise in general just as you find out more about a man by listening to his conversation than by looking at a house he has built. - C.S. Lewis',
#  'Instead of a trap door, what about a trap window? The guy looks out it, and if he leans too far, he falls out. Wait. I guess that`s like a regular window. - Jack Handey',
#  'Man was made for action, and to promote by the exertion of his faculties such changes in the external circumstances both of himself and others, as may seem most favourable to the happiness of all. - Adam Smith',
#  'In every man`s heart there is a secret nerve that answers to the vibrations of beauty. - Christopher Morley',
#  'If Jack`s in love, he`s no judge of Jill`s beauty. - Benjamin Franklin',
#  'The Democrats seem to be basically nicer people, but they have demonstrated time and again that they have the management skills of celery. - Dave Barry',
#  'Without courage, wisdom bears no fruit. - Baltasar Gracian',
#  'I thought it completely absurd to mention my name in the same breath as the Presidency. - Dwight Eisenhower',
#  'The only reason for time is so that everything doesn`t happen at once. - Albert Einstein',
#  'The fool doth think he is wise, but the wise man knows himself to be a fool. - William Shakespeare',
#  'You don`t have to stay up nights to succeed; you have to stay awake days. - Author Unknown',
#  'Life is what happens to you while you`re busy making other plans. - John Lennon',
#  'Fear not those who argue but those who dodge. - Dale Carnegie',
#  'I have a hobby...I have the world`s largest collection of sea shells. I keep it scattered on beaches all over the world. Maybe you`ve seen some of it... - Steven Wright',
#  'The art of being happy lies in the power of extracting happiness from common things. - Henry Ward Beecher',
#  'Demoralize the enemy from within by surprise, terror, sabotage, assassination. This is the war of the future. - Adolf Hitler',
#  'If eighty percent of your sales come from twenty percent of all of your items, just carry those twenty percent. - Henry Kissinger',
#  'It`s not how old you are, it`s how hard you work at it. - Jonah Barrington',
#  'What sunshine is to flowers, smiles are to humanity. These are but trifles, to be sure; but scattered along life`s pathway, the good they do is inconceivable. - Joseph Addison',
#  'You got to be very careful if you don`t know where you`re going, because you might not get there. - Yogi Berra',
#  'Life is not a support system for art. It`s the other way around. - Stephen King',
#  'Love is the delightful interval between meeting a beautiful girl and discovering that she looks like a haddock. - John Barrymore',
#  'The supernatural is the natural not yet understood. - Elbert Hubbard',
#  'Those who forget good and evil and seek only to know the facts are more likely to achieve good than those who view the world through the distorting medium of their own desires. - Bertrand Russell',
#  'Experience proves this, or that, or nothing, according to the preconceptions we bring to it. - C.S. Lewis',
#  'Nothing separates the generations more than music. By the time a child is eight or nine, he has developed a passion for his own music that is even stronger than his passions for procrastination and weird clothes. - Bill Cosby',
#  'The hour of departure has arrived, and we go our ways - I to die, and you to live. Which is better God only knows. - Plato',
#  'The statistics on sanity are that one out of every four Americans are suffering from some form of mental illness. Think of your three best friends. If they`re okay, then it`s you. - Rita Mae Brown',
#  'Nietzsche was stupid and abnormal. - Leo Tolstoy',
#  'Everybody can be great... because anybody can serve. You don`t have to have a college degree to serve. You don`t have to make your subject and verb agree to serve. You only need a heart full of grace. A soul generated by love. - Martin Luther King Jr.',
#  'People have a way of becoming what you encourage them to be, not what you nag them to be. - Author Unknown',
#  'All men are frauds. The only difference between them is that some admit it. I myself deny it. - Henry Mencken',
#  'America is not like a blanket: one piece of unbroken cloth, the same color, the same texture, the same size. America is more like a quilt: many patches, many pieces, many colors, many sizes, all woven and held together by a common thread. - Jesse Jackson',
#  'When nothing seems to help, I go and look at a stonecutter hammering away at his rock perhaps a hundred times without as much as a crack showing in it. Yet at the hundred and first blow it will split in two, and I know it was not that blow that did it, but all that had gone before. - Jacob August Riis',
#  'In any moment of decision, the best thing you can do is the right thing. The worst thing you can do is nothing. - Theodore Roosevelt',
#  'Self-denial is the shining sore on the leprous body of Christianity. - Oscar Wilde',
#  'I have never been hurt by what I have not said. - Calvin Coolidge',
#  'If you judge people, you have no time to love them. - Mother Teresa',
#  'The means of defense against foreign danger historically have become the instruments of tyranny at home. - James Madison',
#  'He who is not courageous enough to take risks will accomplish nothing in life. - Muhammad Ali',
#  'He that fights and runs away, may turn and fight another day; but he that is in battle slain, will never rise to fight again. - Tacitus',
#  'America did not invent human rights. In a very real sense...human rights invented America. - Jimmy Carter',
#  'No matter how much cats fight, there always seem to be plenty of kittens. - Abraham Lincoln',
#  'Success, the real success, does not depend upon the position you hold but upon how you carry yourself in that position. - Theodore Roosevelt',
#  'Happiness makes up in height for what it lacks in length. - Robert Frost',
#  'Poetry is the art of creating imaginary gardens with real toads. - Marianne Moore',
#  'It is by the goodness of God that, in this country, we have three benefits: freedom of speech, freedom of thought, and the wisdom never to use either. - Mark Twain',
#  'The Bible is not my book, and Christianity is not my religion. I could never give assent to the long, complicated statements of Christian dogma. - Abraham Lincoln',
#  'He wrapped himself in quotations--as a beggar would enfold himself in the purple of Emperors. - Rudyard Kipling',
#  'The truth is always a trick to those who live among lies. - Author Unknown',
#  'What you do speaks so loudly that I cannot hear what you say. - Ralph Waldo Emerson',
#  'All glory is fleeting. - George Patton',
#  'No distance of place or lapse of time can lessen the friendship of those who are thoroughly persuaded of each other`s worth. - Robert Southey',
#  'Washington is a city of Southern efficiency and Northern charm. - John F. Kennedy',
#  'If you`re in a boxing match, try not to let the other guy`s glove touch your lips, because you don`t know where that glove has been. - Jack Handey',
#  'Never discourage anyone who continually makes progress, no matter how slow. - Plato',
#  'Not only is there no God, but try finding a plumber on Sunday. - Woody Allen',
#  'Rome remained free for four hundred years and Sparta eight hundred, although their citizens were armed all that time; but many other states that have been disarmed have lost their liberties in less than forty years. - Nicolo Machiavelli',
#  'Science without religion is lame, religion without science is blind. - Albert Einstein',
#  'Knowledge rests not upon truth alone, but upon error also. - Carl Jung',
#  'In politics shared hatreds are almost always the basis of friendships. - Alexis de Tocqueville',
#  'Genius may have its limitations, but stupidity is not thus handicapped. - Elbert Hubbard',
#  'In life, as in art, the beautiful moves in curves. - Edward Bulwer-Lytton',
#  'I planted some bird seed. A bird came up. Now I don`t know what to feed it. - Steven Wright',
#  'Not everybody trusts paintings, but people believe photographs. - Ansel Adams',
#  'The things that will destroy America are prosperity at any price, peace at any price, safety first instead of duty first, the love of soft living and the get rich quick theory of life. - Theodore Roosevelt',
#  'There are people who put their dreams in a little box and say, Yes, I`ve got dreams, of course I`ve got dreams. Then they put the box away and bring it out once in awhile to look in it, and yep, they`re still there. - Erna Bombeck',
#  'Knowledge comes, but wisdom lingers. - Calvin Coolidge',
#  'Men are born ignorant, not stupid; they are made stupid by education. - Bertrand Russell',
#  'If we do not help a man in trouble, it is as if we caused the trouble. - Nachman of Bratslav',
#  'Patience is the companion of wisdom. - Saint Augustine',
#  'Marriage is our last, best chance to grow up. - Joseph Barth',
#  'Patriotism is not short, frenzied outbursts of emotion, but the tranquil and steady dedication of a lifetime. - Adlai Stevenson',
#  'A man`s very highest moment is, I have no doubt at all, when he kneels in the dust, and beats his breast, and tells all the sins of his life. - Oscar Wilde',
#  'Associate yourself with men of good quality if you esteem your own reputation; for `tis better to be alone than in bad company. - George Washington',
#  'Beauty is all very well at first sight; but whoever looks at it when it has been in the house three days? - George Bernard Shaw',
#  'I had a dream the other night. I dreamed that Jimmy Carter came to me and asked why I wanted his job. I told him I didn`t want his job. I want to be President. - Ronald Reagan',
#  'To assert that the earth revolves around the sun is as erroneous as to claim that Jesus was not born of a virgin. - Cardinal Bellarmine',
#  'Reality is that which, when you stop believing in it, doesn`t go away. - Phillip K. Dick',
#  'Deliberation and debate is the way you stir the soul of our democracy. - Jesse Jackson',
#  'Nothing noble is done without risk. - André Gide',
#  'Fatherhood is pretending the present you love most is soap on-a-rope. - Bill Cosby',
#  'No nation keeps its word. A nation is a big, blind worm, following what? Fate perhaps. A nation has no honor, it has no word to keep. - Carl Jung',
#  'Democracy means that anyone can grow up to be president, and anyone who doesn`t grow up can be vice president. - Johnny Carson',
#  'All men desire to know. - Aristotle',
#  'Women are the only realists; their whole object in life is to pit their realism against the extravagant, excessive, and occasionally drunken idealism of men. - GK Chesterton',
#  'Don`t go around saying the world owes you a living. The world owes you nothing. It was here first. - Mark Twain',
#  'I could not handle being a woman, I would stay home all day and play with my breasts. - Steve Martin',
#  'I confess, I do not believe in time. - Vladimir Nabokov',
#  'Man is the only animal that blushes - or needs to. - Mark Twain',
#  'True wisdom comes to each of us when we realize how little we understand about life, ourselves, and the world around us. - Socrates',
#  'Any reviewer who expresses rage and loathing for a novel is preposterous. He or she is like a person who has put on full armor and attacked a hot fudge sundae. - Kurt Vonnegut',
#  'There is no substitute for hard work. - Thomas Edison',
#  'Cast your cares on God; that anchor holds. - Frank Moore Colby',
#  'She is not perfect. You are not perfect. The question is whether or not you are perfect for each other. - Robin Williams',
#  'Fanaticism consists of redoubling your efforts when you have forgotten your aim. - George Santayana',
#  'Government is not reason; it is not eloquent; it is force. Like fire, it is a dangerous servant and a fearful master. - George Washington',
#  'Let us not forget that the cultivation of the earth is the most important labor of man. When tillage begins, other arts will follow. The farmers, therefore, are the founders of civilization. - Daniel Webster',
#  'A right delayed is a right denied. - Martin Luther King Jr.',
#  'Against criticism a man can neither protest nor defend himself; he must act in spite of it, and then it will gradually yield to him. - Johann Wolfgang von Goethe',
#  'Everything is simpler than you think and at the same time more complex than you imagine. - Johann Wolfgang von Goethe',
#  'The world is full of suffering. It is also full of overcoming it. - Helen Keller',
#  'Love is repaid by love alone! - Mother Teresa',
#  'The only way to keep your health is to eat what you don`t want, drink what you don`t like, and do what you`d rather not. - Mark Twain',
#  'No man but a blockhead ever wrote, except for money. - Samuel Johnson',
#  'It behooves every man to remember that the work of the critic is of altogether secondary importance, and that, in the end, progress is accomplished by the man who does things. - Theodore Roosevelt',
#  'Why are people`s ``deepest desires`` always so shallow? - Author Unknown',
#  'Were it possible for us to wait for ourselves to come into the room, not many of us would find our hearts breaking into flower as we heard the door handle turn. - Rebecca West',
#  'Thus the metric system did not really catch on in the States, unless you count the increasing popularity of the nine-millimeter bullet. - Dave Barry',
#  'Ask not what your country can do for you - ask what you can do for your country. - John F. Kennedy',
#  'It is error alone which needs the support of government. Truth can stand by itself. - Thomas Jefferson',
#  'To have the reputation of possessing the most perfect social tact, talk to every woman as if you loved her, and to every man as if he bored you. - Oscar Wilde',
#  'Remember, if you smoke after sex you`re doing it too fast. - Woody Allen',
#  'Fame is a fickle food upon a shifting plate. - Emily Dickinson',
#  'Philosophy is to the real world as masturbation is to sex. - Karl Marx',
#  'It is always thus, impelled by a state of mind which is destined not to last, that we make our irrevocable decisions. - Marcel Proust',
#  'Love anything and your heart will be wrung and possibly broken. If you want to make sure of keeping it intact you must give it to no one, not even an animal. Wrap it carefully round with hobbies and little luxuries; avoid all entanglements. Lock it up safe in the casket or coffin of your selfishness. But in that casket, safe, dark, motionless, airless, it will change. It will not be broken; it will become unbreakable, impenetrable, irredeemable. To love is to be vulnerable. - C.S. Lewis',
#  'Ignorance more frequently begets confidence than does knowledge. - Charles Darwin',
#  'When I see a play and understand it the first time, then I know it can`t be much good. - T.S. Eliot',
#  'To explain the unknown by the known is a logical procedure; to explain the known by the unknown is a form of theological lunacy. - David Brooks',
#  'I mistrust the judgment of every man in a case in which his own wishes are concerned. - Daniel Webster',
#  'We ascribe beauty to that which is simple; which has no superfluous parts; which exactly answers its end; which stands related to all things; which is the mean of many extremes. - Ralph Waldo Emerson',
#  'Americans are so enamored of equality, they would rather be equal in slavery than unequal in freedom. - Alexis de Tocqueville',
#  'In the long run, we shape our lives and we shape ourselves. The process never ends until we die, and the choices that we make are ultimately our responsibility. - Eleanor Roosevelt',
#  'Don`t ever take a fence down until you know why it was put up. - Robert Frost',
#  'I am Envy. I cannot read and therefore wish all books burned. - Christopher Marlowe',
#  'Of all bad men religious bad men are the worst. - C.S. Lewis',
#  'God`s colors all are fast. - John Greenleaf Whittier',
#  'Christmas is a time when you get homesick, even when you`re home. - Carol Nelson',
#  'We all wish to be judged by our peers, by the men `after our own heart.` Only they really know our mind and only they judge it by standards we fully acknowledge. Theirs is the praise we really covet and the blame we really dread. The little pockets of early Chrstians survived because they cared exclusively for the love of `the bretheren` and stopped their ears to the opinion of the Pagan society around them. But a circle of criminals, cranks, or perverts survives in just the same way; by becoming deaf to the opinion of the outer world, by discounting it as the chatter of outsiders who `don`t understand,` of the `conventional,` the `bourgeois,` the `Establishment,` of prigs, prudes, and humbugs. - C.S. Lewis',
#  'Duties are not performed for duty`s sake, but because their neglect would make the man uncomfortable. A man performs but one duty - the duty of contenting his spirit, the duty of making himself agreeable to himself. - Mark Twain',
#  'A free society is one where it is safe to be unpopular. - Adlai Stevenson',
#  'If variety is the spice of life, marriage is the big can of leftover Spam. - Johnny Carson',
#  'Truth sits upon the lips of dying men. - Matthew Arnold',
#  'As a woman, I find it very embarrassing to be in a meeting and realize I`m the only one in the room with balls. - Rita Mae Brown',
#  'A mind that is stretched by a new experience can never go back to its old dimensions. - Oliver Wendell Holmes',
#  'If there is any principle of the Constitution that more imperatively calls for attachment than any other it is the principle of free thought, not free thought for those who agree with us but freedom for the thought that we hate. - Oliver Wendell Holmes',
#  'Thus far, the reputed idiot Bush has graduated from Yale and Harvard, made a stack of cash in the oil industry, become the first consecutive-term governor of Texas, defeated a dual-term VP for the presidency, and led his party to [November 5th`s] extraordinary triumphs. Let his opponents keep calling him stupid; if they do, within five years Bush will be King of England, the Pope, and world Formula One motor racing champion. - Tim Blair',
#  'All art is but imitation of nature. - Lucius Annaeus Seneca',
#  'We should take care not to make the intellect our god; it has, of course, powerful muscles, but no personality. - Albert Einstein',
#  'Every author should weigh his work and ask, `Will humanity gain any benefit from it?` - Nachman of Bratslav',
#  'The older I grow the more I distrust the familiar doctrine that age brings wisdom. - Henry Mencken',
#  'The significant problems we face cannot be solved at the same level of thinking we were at when we created them. - Albert Einstein',
#  'Heroism is not only in the man, but in the occasion. - Calvin Coolidge',
#  'Nothing is wrong with Southern California that a rise in the ocean level wouldn`t cure. - Kenneth Millar',
#  'Nothing that you have not given away will ever be really yours. - C.S. Lewis',
#  'A `geek` by definition is someone who eats live animals....I`ve never eaten live animals. - Crispin Glover',
#  'Politics is perhaps the only profession for which no preparation is thought necessary. - Robert Louis Stevenson',
#  'The only kind of seafood I trust is the fish stick, a totally featureless fish that doesn`t have eyeballs or fins. - Dave Barry',
#  'I have never taken any exercise except sleeping and resting. - Mark Twain',
#  'Skepticism is a virtue in history as well as in philosophy. - Napoleon Bonaparte',
#  'The sleeping fox catches no poultry. - Benjamin Franklin',
#  'Obstacles do not exist to be surrendered to, but only to be broken. - Adolf Hitler',
#  'A man can`t be too careful in the choice of his enemies. - Oscar Wilde',
#  'After silence, that which comes nearest to expressing the inexpressible is Music. - Aldous Huxley',
#  'To one who has faith, no explanation is necessary. To one without faith, no explanation is possible. - Thomas Aquinas',
#  'Thinking is the hardest work there is, which is the probable reason why so few engage in it. - Henry Ford',
#  'A government which robs Peter to pay Paul can always depend on the support of Paul. - George Bernard Shaw',
#  'Don`t let people drive you crazy when you know it`s in walking distance. - Author Unknown',
#  'Well-timed silence hath more eloquence than speech. - Martin Farquhar Tupper',
#  'The first principle is that you must not fool yourself - and you are the easiest person to fool. - Richard P. Feynman',
#  'Guard with jealous attention the public liberty. Suspect everyone who approaches that jewel. - Patrick Henry',
#  'In the beginning, the universe was created. This made a lot of people very angry, and has been widely regarded as a bad idea. - Douglas Adams',
#  'Anyone who invokes authors in discussion is not using his intelligence but his memory. - Leonardo da Vinci',
#  'To me there has never been a higher source of earthly honor or distinction than that connected with advances in science. - Isaac Newton',
#  'You know, there`s a million fine looking women in the world, dude. But they don`t all bring you lasagna at work. Most of `em just cheat on you. - Kevin Smith',
#  'Government consists in nothing else but so controlling subjects that they shall neither be able to, nor have cause to do it harm. - Nicolo Machiavelli',
#  'There is no glory in battle worth the blood it costs. - Dwight Eisenhower',
#  'Being born is like being kidnapped. And then sold into slavery. - Andy Warhol',
#  'The magic of first love is our ignorance that it can never end. - Benjamin Disraeli',
#  'Art, like morality, consists in drawing the line somewhere. - GK Chesterton',
#  'If music be the food of love, play on. - William Shakespeare',
#  'Politics has got so expensive that it takes lots of money to even get beat with. - Will Rogers',
#  'Back in the old days, most families were close-knit. Grown children and their parents continued to live together, under the same roof, sometimes in the same small, crowded room, year in and year out, until they died, frequently by strangulation. - Dave Barry',
#  'Without computers, the government would be unable to function at the level of effectiveness and efficiency that we have come to expect.  This is because the primary function of the government is -- and here I am quoting directly from the U.S. Constitution -- `to spew out paper.` - Dave Barry',
#  'In politics, if you want anything said, ask a man; if you want anything done, ask a woman. - Margaret Thatcher',
#  'Nobody can have the consolations of religion or philosophy unless he has first experienced their desolations. - Aldous Huxley',
#  'Everything that irritates us about others can lead us to an understanding of ourselves. - Carl Jung',
#  'I`m not normally a religious man, but if you`re up there, save me, Superman! - Homer Simpson',
#  'The practice of art isn`t to make a living. It`s to make your soul grow. - Kurt Vonnegut',
#  'There cannot be true democracy unless women`s voices are heard. - Hillary Clinton',
#  'Just as your hand, held before the eye, can hide the tallest mountain, so this small earthly life keeps us from seeing the vast radiance that fills the core of the universe. - Nachman of Bratslav',
#  'There are several good protections against temptation, but the surest is cowardice. - Mark Twain',
#  'A Native American elder once described his own inner struggles in this manner: Inside of me there are two dogs. One of the dogs is mean and evil. The other dog is good. The mean dog fights the good dog all the time. When asked which dog wins, he reflected. - George Bernard Shaw',
#  'Surely what a man does when he is caught off his guard is the best evidence as to what sort of man he is. - C.S. Lewis',
#  'For each illness that doctors cure with medicine, they provoke ten in healthy people by inoculating them with the virus that is a thousand times more powerful than any microbe: the idea that one is ill. - Marcel Proust',
#  'When I took office, only high energy physicists had ever heard of what is called the Worldwide Web....now even my cat has its own page. - Bill Clinton',
#  'The president cannot escape from his office. - Dwight Eisenhower',
#  'Of all the animals, man is the only one that lies. - Mark Twain',
#  'The greatest thing in this world is not so much where we are, but in what direction we are moving. - Oliver Wendell Holmes',
#  'How did it get so late so soon? It`s night before it`s afternoon. December is here before it`s June. My goodness how the time has flewn. How did it get so late so soon? - Theodor Seuss Geisel',
#  'Humor is mankind`s greatest blessing. - Mark Twain',
#  'It takes a lot of courage to show your dreams to someone else. - Erna Bombeck',
#  'I love Thanksgiving. It`s the only time in Los Angeles that you see natural breasts. - Arnold Schwarzenegger',
#  'The aging process has you firmly in its grasp if you never get the urge to throw a snowball. - Doug Larson',
#  'The surest way of spoiling a pleasure is to start examining your satisfaction. - C.S. Lewis',
#  'There are some who`ve forgotten why we have a military. It`s not to promote war; it`s to be prepared for peace. - Ronald Reagan',
#  'Bashfulness is an ornament to youth, but a reproach to old age. - Aristotle',
#  'You are never too old to set another goal or to dream a new dream. - C.S. Lewis',
#  'If you could kick the person in the pants responsible for most of your trouble, you wouldn`t sit for a month. - Theodore Roosevelt',
#  'The philosophy of one century is the common sense of the next. - Henry Ward Beecher',
#  'The broad masses of a population are more amenable to the appeal of rhetoric than to any other force. - Adolf Hitler',
#  'Plato was a bore. - Friedrich Nietzsche',
#  'The MPAA rates this PG-13. It is too vulgar for anyone under 13, and too dumb for anyone over 13. - Roger Ebert',
#  'Dying is the most embarrassing thing that can ever happen to you, because someone`s got to take care of all your details. - Andy Warhol',
#  'It has been said that man is a rational animal. All my life I have been searching for evidence which could support this. - Bertrand Russell',
#  'The laws of gravity cannot be held responsible for people falling in love. - Albert Einstein',
#  'Of course the people dont want war...that is understood. But voice or no voice, the people can always be brought to the bidding of the leaders. That is easy. All you have to do is tell them they are being attacked, and denounce the pacifists for lack of patriotism and exposing the country to danger. It works the same in any country. - Hermann Goering',
#  'One thing they never tell you about child raising is that for the rest of your life, at the drop of a hat, you are expected to know your child`s name and how old he or she is. - Erna Bombeck',
#  'If we have no peace, it is because we have forgotten that we belong to each other. - Mother Teresa',
#  'I think it`s the duty of the comedian to find out where the line is drawn and cross it deliberately. - George Carlin',
#  'Nothing in the world is more dangerous than sincere ignorance and conscientious stupidity. - Martin Luther King Jr.',
#  'If a man is called to be a streetsweeper, he should sweep streets even as Michelangelo painted, or Beethoven composed music, or Shakespeare wrote poetry. He should sweep streets so well that all the host of heaven and earth will pause to say, here lived a great streetsweeper who did his job well. - Martin Luther King Jr.',
#  'There is a great deal of difference between an eager man who wants to read a book and the tired man who wants a book to read. - GK Chesterton',
#  'To find out a girl`s faults, praise her to her girl friends. - Benjamin Franklin',
#  'Forever is composed of nows. - Emily Dickinson',
#  'Alexander, Caesar, Charlemagne, and myself founded empires; but what foundation did we rest the creations of our genius? Upon force. Jesus Christ founded an empire upon love; and at this hour millions of men would die for Him. - Napoleon Bonaparte',
#  'Man`s best possession is a sympathetic wife. - Euripides',
#  'A grandmother pretends she doesn`t know who you are on Halloween. - Erna Bombeck',
#  'Perhaps one of the most important accomplishments of my administration has been minding my own business. - Calvin Coolidge',
#  'Laughter is the sun that drives winter from the human face. - Victor Hugo',
#  'If I feel physically as if the top of my head were taken off, I know that is poetry. - Emily Dickinson',
#  'Love is a fruit in season at all times, and within reach of every hand. - Mother Teresa',
#  'Having someone wonder where you are when you don`t come home at night is a very old human need. - Margaret Mead',
#  'I paid too much for it, but it`s worth it. - Samuel Goldwyn',
#  'I think the best possible social program is a job. - Ronald Reagan',
#  'Ocean: A body of water occupying 2/3 of a world made for man...who has no gills. - Ambrose Bierce',
#  'Moral indignation is jealousy with a halo. - H.G. Wells',
#  'Information is not knowledge. - Albert Einstein',
#  'The price of greatness is responsibility. - Winston Churchill',
#  'There is hope for the future because God has a sense of humor and we are funny to God. - Bill Cosby',
#  'Why, you can take the most gallant sailor, the most intrepid airman or the most audacious soldier, put them at a table together - what do you get? The sum of their fears. - Winston Churchill',
#  'The mind of the thoroughly well-informed man is a dreadful thing. It is like a bric-à-brac shop, all monsters and dust, with everything priced above its proper value. - Oscar Wilde',
#  'Cooking was invented in prehistoric times, when a primitive tribe had a lucky accident. The tribe had killed an animal and was going to eat it raw, when a tribe member named Woog tripped and dropped it into the fire. At first the other tribe members were angry at Woog, but then, as the aroma of burning meat filled the air, they had an idea. So they ate Woog raw. - Dave Barry',
#  'I have been the artist with the longest career, and I am so proud and honoured to be chosen from heaven to be invincible. - Michael Jackson',
#  'On the plus side, death is one of the few things that can be done just as easily lying down. - Woody Allen',
#  'If we will be quiet and ready enough, we shall find compensation in every disappointment. - Henry Thoreau',
#  'I get to go to lots of overseas places, like Canada. - Britney Spears',
#  'Imagination is a quality given a man to compensate him for what he is not, and a sense of humor was provided to console him for what he is. - Oscar Wilde',
#  'Without music, life would be a mistake. - Friedrich Nietzsche',
#  'I will honor Christmas in my heart, and try to keep it all the year. - Charles Dickens',
#  'Don`t walk in front of me, I may not follow. Don`t walk behind me, I may not lead. Just walk beside me and be my friend. - Albert Camus',
#  'You can`t depend on your eyes when your imagination is out of focus. - Mark Twain',
#  'I like your Christ, I do not like your Christians. Your Christians are so unlike your Christ. - Mahatma Gandhi',
#  'Let us now set forth one of the fundamental truths about marriage: the wife is in charge. - Bill Cosby',
#  'True patriotism hates injustice in its own land more than anywhere else. - Clarence Darrow',
#  'If a man is proud of his wealth, he should not be praised until it is known how he employs it. - Socrates',
#  'I like to say that I`m bisexual...when I want sex, I buy it. - Boy George',
#  'We`ve got to live. No matter how many skies have fallen. - D.H. Lawrence',
#  'Do good by stealth, and blush to find it fame. - Alexander Pope',
#  'There is a theory which states that if ever anyone discovers exactly what the Universe is for and why it is here, it will instantly disappear and be replaced by something even more bizarre and inexplicable. There is another theory which states that this has already happened. - Douglas Adams',
#  'I don`t care what is written about me, so long as it isn`t true. - Dorothy Parker',
#  'Get mad, then get over it. - Colin Powell',
#  'I always cheer up immensely if an attack is particularly wounding because I think, well, if they attack one personally, it means they have not a single political argument left. - Margaret Thatcher',
#  'Observe constantly that all things take place by change, and accustom thyself to consider that the nature of the Universe love nothing so much as to change. The Universe is change. - Marcus Aurelius',
#  'You give me a credit to which I have no claim in calling me `the writer of the Constitution of the United States.` This was not, like the fabled Goddess of Wisdom, the offspring of a single brain. It ought to be regarded as the work of many heads and many hands. - James Madison',
#  'Since love grows within you, so beauty grows. For love is the beauty of the soul. - Saint Augustine',
#  'You know you`re getting old when the candles cost more than the cake. - Bob Hope',
#  'Freedom is the right to question and change the established way of doing things. It is the continuous revolution of the marketplace. It is the understanding that allows us to recognize shortcomings and seek solutions. - Ronald Reagan',
#  'There is time for everything. - Thomas Edison',
#  'The nation which forgets its defenders will be itself forgotten. - Calvin Coolidge',
#  'Show me your hands. Do they have scars from giving? Show me your feet. Are they wounded in service? Show me your heart. Have you left a place for divine love? - Fulton J. Sheen',
#  'There are no secrets to success. It is the result of preparation, hard work, and learning from failure. - Colin Powell',
#  'The movie`s director is the pilot. It`s his vision. For an actor, the time to worry about flying is when you`re on the ground. If you don`t want to fly with the director, don`t get on the plane. - Denzel Washington',
#  'My aim is to put down on paper what I see and what I feel in the best and simplest way. - Ernest Hemingway',
#  'Don`t marry a man to reform him - that`s what reform schools are for. - Mae West',
#  'Analyzing humor is like dissecting a frog. Few people are interested and the frog dies of it. - E.B. White',
#  'If you`re afraid to ask the question, it`s probably because you already know the answer. - Miriam M. Wynn',
#  'You should do your own car repairs. It`s an easy way to save money and possibly maim yourself for life. - Dave Barry',
#  'The ACLU is always yakking about the Constitution, and most of us are getting mighty tired of it. I mean, if the Constitution is so great, how come it was amended so many times? Huh? - Dave Barry',
#  'One definition of an economist is somebody who sees something happen in practice and wonders if it will work in theory. - Ronald Reagan',
#  'Chicago sounds rough to the maker of verse. One comfort we have: Cincinnati sounds worse. - Oliver Wendell Holmes',
#  'There are men in all ages who mean to govern well, but they mean to govern. They promise to be good masters, but they mean to be masters. - Daniel Webster',
#  'A leader is a man who can adapt principles to circumstances. - George Patton',
#  'Sex at age ninety is like trying to shoot pool with a rope. - George Burns',
#  'You don`t take a photograph, you make it. - Ansel Adams',
#  'The mintage of wisdom is to know that rest is rust, and that real life is in love, laughter, and work. - Elbert Hubbard',
#  'He therefore is the truest friend to the liberty of this country who tries most to promote its virtue, and who, so far as his power and influence extend, will not suffer a man to be chosen into any office of power and trust who is not a wise and virtuous man. - Samuel Adams',
#  'The biggest bore is the person who is bored by everyone and everything. - Frank Tyger',
#  'I hate war as only a soldier who has lived it can, only as one who has seen its brutality, its futility, its stupidity. - Dwight Eisenhower',
#  'Success is going from failure to failure without losing enthusiasm. - Winston Churchill',
#  'We have the Bill of Rights. What we need is a Bill of Responsibilities. - Bill Maher',
#  'Even peace may be purchased at too high a price. - Benjamin Franklin',
#  'The last thing a political party gives up is its vocabulary. - Alexis de Tocqueville',
#  'Many of life`s failures are people who did not realize how close they were to success when they gave up. - Thomas Edison',
#  'We are what we repeatedly do. Excellence, therefore, is not an act, but a habit. - Aristotle',
#  'Would you live with ease? Do what you ought, not what you please. - Benjamin Franklin',
#  'Men have always been afraid that women could get along without them. - Margaret Mead',
#  'Being is desirable because it is identical with Beauty, and Beauty is loved because it is Being. We ourselves possess Beauty when we are true to our own being; ugliness is in going over to another order; knowing ourselves, we are beautiful; in self-ignorance, we are ugly. - Ambrose Bierce',
#  'Money never made a man happy yet, nor will it. There is nothing in its nature to produce happiness. The more a man has, the more he wants. Instead of its filling a vacuum, it makes one. If it satisfies one want, it doubles and trebles that want another way. That was a true proverb of the wise man, rely upon it; ``Better is little with the fear of the Lord, than great treasure, and trouble therewith. - Benjamin Franklin',
#  'Science is not about building a body of known `facts`. It is a method for asking awkward questions and subjecting them to a reality-check, thus avoiding the human tendency to believe whatever makes us feel good. - Terry Pratchett',
#  'A man is never more truthful than when he acknowledges himself a liar. - Mark Twain',
#  'The writer’s job is not to judge, but to seek to understand. - Ernest Hemingway',
#  'When in doubt, do it. - Oliver Wendell Holmes',
#  'This is the second most exciting indoor sport, and the other one shouldn`t have spectators. - Dick Vertleib',
#  'Nothing before had ever made me thoroughly realise, though I had read various scientific books, that science consists in grouping facts so that general laws or conclusions may be drawn from them. - Charles Darwin',
#  'Death and life have their determined appointments; riches and honors depend upon heaven. - Confucius',
#  'Those who expect to reap the blessings of freedom must, like men, undergo the fatigue of supporting it. - Thomas Paine',
#  'Maturity is a bitter disappointment for which no remedy exists, unless laughter can be said to remedy anything. - Kurt Vonnegut',
#  'Once you have flown, you will walk the earth with your eyes turned skywards, for there you have been, and there you long to return. - Leonardo da Vinci',
#  'Let him who desires peace prepare for war. - Vegetius',
#  'We live in an age when unnecessary things are our only necessities. - Oscar Wilde',
#  'A typical vice of American politics is the avoidance of saying anything real on real issues. - Theodore Roosevelt',
#  '`Tis the business of little minds to shrink, but he whose heart is firm, and whose conscience approves his conduct, will pursue his principles unto death. - Thomas Paine',
#  'It is impossible to experience one`s death objectively and still carry a tune. - Woody Allen',
#  'Serious sport has nothing to do with fair play. It is bound up with hatred, jealousy, boastfulness, disregard of all rules and sadistic pleasure in witnessing violence. In other words: it is war minus the shooting. - George Orwell',
#  'How did it happen that their lips came together? How does it happen that birds sing, that snow melts, that the rose unfolds, that the dawn whitens behind the stark shapes of trees on the quivering summit of the hill? A kiss, and all was said. - Victor Hugo',
#  'Four-fifths of all our troubles would disappear, if we would only sit down and keep still. - Calvin Coolidge',
#  'Character is what you are in the dark. - John Whorfin',
#  'Opera is when a guy gets stabbed in the back and, instead of bleeding, he sings. - Ed Gardner',
#  'Anybody can become angry - that is easy, but to be angry with the right person and to the right degree and at the right time and for the right purpose, and in the right way - that is not within everybody`s power and is not easy. - Aristotle',
#  'If you are resolutely determined to make a lawyer of yourself, the thing is more than half done already. - Abraham Lincoln',
#  'It is only by doing things others have not that one can advance. - George Patton',
#  'No doubt those who really founded modern science were usually those whose love of truth exceeded their love of power. - C.S. Lewis',
#  'I don`t make jokes. I just watch the government and report the facts. - Will Rogers',
#  'The customs and fashions of men change like leaves on the bough, some of which go and others come. - Dante Alighieri',
#  'Friendship is a single soul dwelling in two bodies. - Aristotle',
#  'We must repsect the other fellow`s religion, but only in the sense and to the extent that we respect his theory that his wife is beautiful and his children are smart. - Henry Mencken',
#  'Happiness is so hard to define and foolish to define. Am I acting? That`s the worst thing you can ask yourself. You can be happy suddenly. It can spring on you, not when you reach a plateau. You can be happy going backward or going down. You can be happy at the loss of something. - Steve Martin',
#  'Every gun that is made, every warship launched, every rocket fired, signifies in the final sense a theft from those who hunger and are not fed, those who are cold and are not clothed. - Dwight Eisenhower',
#  'The greatness of our country has been based on our thinking that everyone has a right even to be wrong. - Ronald Reagan',
#  'Unless the religious claims of the Bible are again acknowledged, its literary claims will, I think, be given only `mouth honour` and that decreasingly. - C.S. Lewis',
#  'There are a thousand hacking at the branches of evil to one who is striking at the root. - Henry Thoreau',
#  'The best of life is conversation, and the greatest success is confidence, or perfect understanding between two people. - Ralph Waldo Emerson',
# ...
#  'Let the river roll which way it will, cities will rise on its banks. - Ralph Waldo Emerson',
#  'I like television. I still believe that television is the most powerful form of communication on Earth -- I just hate what is being done with it. - Alton Brown',
#  'No side will win the Battle of the Sexes. There`s too much fraternizing with the enemy. - Henry Kissinger',
#  'I just want to do God`s will. - Martin Luther King Jr.',
#  'God does not give heed to the ambitiousness of our prayers, because he is always ready to give to us his light, not a visible light but an intellectual and spiritual one; but we are not always ready to receive it when we turn aside and down to other things out of a desire for temporal things. - Saint Augustine',
#  '.I had to face the horrible truth: The antitobacco people are lying. Smoking really is cool. And I`m less cool for not doing it. - Tucker Carlson',
#  'Life is no brief candle to me. It is a sort of splendid torch which I have got a hold of for the moment, and I want to make it burn as brightly as possible before handing it onto future generations. - George Bernard Shaw',
#  'Everyone is in awe of the lion tamer in a cage with half a dozen lions -- everyone but a school bus driver. - Laurence Peter',
#  'Peace is its own reward. - Mahatma Gandhi',
#  'I never see what has been done; I only see what remains to be done. - Siddhartha Buddha',
#  'There is only one rule for being a good talker - learn to listen. - Christopher Morley',
#  'Under the doctrine of the separation of powers, the manner in which the president personally exercises his assigned executive powers is not subject to questioning by another branch of government. - Richard Nixon',
#  'We have it in our power to begin the world over again. - Thomas Paine',
#  'I think computer viruses should count as life. I think it says something about human nature that the only form of life we have created so far is purely destructive. We`ve created life in our own image. - Stephen Hawking',
#  'Our attitude towards others determines their attitude towards us. - Earl Nightingale',
#  'Reason and judgment are the qualities of a leader. - Tacitus',
#  'Death is psychologically as important as birth. Shrinking away from it is something unhealthy and abnormal which robs the second half of life of its purpose. - Carl Jung',
#  'A mathematician is a blind man in a dark room looking for a black cat which isn`t there. - Charles Robert',
#  'There is no strength in unbelief. Even the unbelief of what is false is no source of might. It is the truth shining from behind that gives the strength to disbelieve. - George MacDonald',
#  'Parting is all we know of heaven and all we need to know of hell. - Emily Dickinson',
#  'The nice thing about being a celebrity is that, if you bore people, they think it`s their fault. - Henry Kissinger',
#  'It takes a long time to turn a big country around. - Bill Clinton',
#  'It still remains true that no justification of virtue will enable a man to be virtuous. - C.S. Lewis',
#  'I have never started a poem yet whose end I knew. Writing a poem is discovering. - Robert Frost',
#  'Freedom is nothing else but a chance to be better. - Albert Camus',
#  'When the human race has once acquired a supersitition nothing short of death is ever likely to remove it. - Mark Twain',
#  'Some folks look at me and see a certain swagger, which in Texas is called `walking.` - George W. Bush',
#  'In politics, an organized minority is a political majority. - Jesse Jackson',
#  'No one can make you feel inferior without your consent. - Eleanor Roosevelt',
#  'I have never let my schooling interfere with my education. - Mark Twain',
#  'Humility must always be the portion of any man who receives acclaim earned in blood of his followers and sacrifices of his friends. - Dwight Eisenhower',
#  'Many a man`s reputation would not know his character if they met on the street. - Elbert Hubbard',
#  'Indeed, man wishes to be happy even when he so lives as to make happiness impossible. - Saint Augustine',
#  'History does not long entrust the care of freedom to the weak or the timid. - Dwight Eisenhower',
#  'The whole life of an American is passed like a game of chance, a revolutionary crisis, or a battle. - Alexis de Tocqueville',
#  'You can`t build a reputation on what you are going to do. - Henry Ford',
#  'I`m the type who`d be happy not going anywhere as long as I was sure I knew exactly what was happening at the places I wasn`t going to. I`m the type who`d like to sit home and watch every party that I`m invited to on a monitor in my bedroom. - Andy Warhol',
#  'My life has no purpose, no direction, no aim, no meaning, and yet I`m happy. I can`t figure it out. What am I doing right? - Charles Schulz',
#  'Don`t join the book burners. Do not think you are going to conceal thoughts by concealing evidence that they ever existed. - Dwight Eisenhower',
#  'Men show their characters in nothing more clearly than in what they think laughable. - Johann Wolfgang von Goethe',
#  'Providence protects children and idiots. I know because I have tested it. - Mark Twain',
#  'Where there`s marriage without love, there will be love without marriage. - Benjamin Franklin',
#  'The intellect is not a serious thing, and never has been. It is an instrument on which one plays, that is all. - Oscar Wilde',
#  'More than kisses, letters mingle souls. - John Donne',
#  'There is luxury in self-reproach. When we blame ourselves, we feel no one else has a right to blame us. - Oscar Wilde',
#  'You do not lead by hitting people over the head — that`s assault, not leadership. - Dwight Eisenhower',
#  'As soon as one is unhappy one becomes moral. - Marcel Proust',
#  'The function of RAM is to give us guys a way of deciding whose computer has the biggest, studliest, most tumescent MEMORY. This is important, because with today`s complex software, the more memory a computer has, the faster it can produce error messages. So the bottom line is, if you`re a guy, you cannot have enough RAM. - Dave Barry',
#  'The public is wonderfully tolerant. It forgives everything except genius. - Oscar Wilde',
#  'Take everything you like seriously, except yourselves. - Rudyard Kipling',
#  'We need not just a new generation of leadership but a new gender of leadership. - Bill Clinton',
#  'Accept good advice gracefully--as long as it doesn`t interfere with what you intended to do in the first place. - Gene Brown',
#  'By the time we`ve made it, we`ve had it. - Malcolm Forbes',
#  'An idea that is developed and put into action is more important than an idea that exists only as an idea. - Siddhartha Buddha',
#  'I dote on his very absence. - William Shakespeare',
#  'Anger is never without an argument, but seldom with a good one. - George Savile',
#  'He who controls the present, controls the past. He who controls the past, controls the future. - George Orwell',
#  'Those who believe they are exclusively in the right are generally those who achieve something. - Aldous Huxley',
#  'The man who does not read good books has no advantage over the man who cannot read them. - Mark Twain',
#  'From the prodigious hilltops of New Hampshire, let freedom ring. From the mighty mountains of New York, let freedom ring. From the heightening Alleghenies of Pennsylvania, let freedom ring. But not only that: Let freedom ring from every hill and molehill of Mississippi. - Martin Luther King Jr.',
#  'Music expresses that which cannot be said and on which it is impossible to be silent. - Victor Hugo',
#  'Every decent man is ashamed of the government he lives under. - Henry Mencken',
#  'What a man`s mind can create, man`s character can control. - Thomas Edison',
#  'Never confuse the size of your paycheck with the size of your talent. - Marlon Brando',
#  'To me, it`s always a good idea to always carry two sacks of something when you walk around. That way, if anybody says, `Hey, can you give me a hand?,` you can say, `Sorry, got these sacks.` - Jack Handey',
#  'The mystic chords of memory, stretching from every battlefield and patriot grave to every living heart and hearthstone all over this broad land, will yet swell the chorus of the Union, when again touched, as surely they will be, by the better angels of our nature. - Abraham Lincoln',
#  'Sex without love is a meaningless experience, but as far as meaningless experiences go, it`s pretty damn good. - Woody Allen',
#  'Forgiveness is not an occasional act: it is a permanent attitude. - Martin Luther King Jr.',
#  'A man who desires to get married should know either everything or nothing. - Oscar Wilde',
#  'When we`re unemployed, we`re called lazy; when the whites are unemployed it`s called a depression. - Jesse Jackson',
#  'He who learns but does not think, is lost! He who thinks but does not learn is in great danger. - Confucius',
#  'The illegal we do immediately. The unconstitutional takes a little longer. - Henry Kissinger',
#  'Not only does God play dice, but he sometimes throws them where they cannot be seen. - Stephen Hawking',
#  'One of the striking differences between a cat and a lie is that a cat has only nine lives. - Mark Twain',
#  'A few hours of mountain climbing turn a villain and a saint into two rather equal creature. Exhaustion is the shortest way to equality and fraternity, and liberty is added eventually by sleep. - Friedrich Nietzsche',
#  'If all our misfortunes were laid in one common heap, whence everyone must take an equal portion, most people would be content to take their own and depart. - Socrates',
#  'It is the madness of folly, to expect mercy from those who have refused to do justice; and even mercy, where conquest is the object, is only a trick of war; the cunning of the fox is as murderous as the violence of the wolf. - Thomas Paine',
#  'When you stop giving and offering something to the rest of the world, it`s time to turn out the lights. - George Burns',
#  'I don`t work according to nature, but infront and together with it. An artist must observe the nature, but never confuse it with the art. - Pablo Picasso',
#  'Grief can take care of itself, but to get the full value of joy you must have somebody to divide it with. - Mark Twain',
#  'A diplomat is a man who always remembers a woman`s birthday but never remembers her age. - Robert Frost',
#  'If you start to think about your physical or moral condition, you usually find that you are sick. - Johann Wolfgang von Goethe',
#  'No human relation gives one possession in another...every two souls are absolutely different. In friendship and in love, the two side by side raise hands together to find what one cannot reach alone. - Kahlil Gibran',
#  'A word is dead when it is said, some say. I say it just begins to live that day. - Emily Dickinson',
#  'You cannot go on `explaining away` for ever: you will find that you have explained explanation itself away. You cannot go on `seeing through` things for ever. The whole point of seeing through something is to see something through it. - C.S. Lewis',
#  'The invisible and the non-existent look very much alike. - Delos McKown',
#  'To you taxpayers out there, let me say this: Make sure you file your tax return on time! And remember that, even though income taxes can be a “pain in the neck,” the folks at the IRS are regular people just like you, except that they can destroy your life. - Dave Barry',
#  'We do survive every moment, after all, except the last one. - John Updike',
#  'Andy Warhol made fame more famous. - Fran Lebowitz',
#  'It is the dissimilarities and inequalities among men which give rise to the notion of honor; as such differences become less, it grows feeble; and when they disappear, it will vanish too. - Alexis de Tocqueville',
#  'Time is a great teacher, but unfortunately it kills all its pupils. - Louis Hector Berlioz',
#  'To be prepared for war is one of the most effectual means of preserving peace. - George Washington',
#  'What is it that makes a complete stranger dive into an icy river to save a solid-gold baby? Maybe we`ll never know. - Jack Handey',
#  'All children are artists. The problem is how to remain an artist once he grows up. - Pablo Picasso',
#  '“Take a chance! All life is a chance. The man who goes farthest is generally the one who is willing to do and dare. - Dale Carnegie',
#  'Time makes more converts than reason. - Thomas Paine',
#  'Painting is just another way of keeping a diary. - Pablo Picasso',
#  'Anyone who has never made a mistake has never tried anything new. - Albert Einstein',
#  'Sacred cows make the best hamburger. - Mark Twain',
#  'We have to make America the best place in the world to do business. - Dick Cheney',
#  'Love yourself first and everything else falls into line. You really have to love yourself to get anything done in this world. - Lucille Ball',
#  'As Mankind becomes more liberal, they will be more apt to allow that all those who conduct themselves as worthy members of the community are equally entitled to the protections of civil government. I hope ever to see America among the foremost nations of justice and liberality. - George Washington',
#  'Many who seem to be struggling with adversity are happy; many, amid great affluence, are utterly miserable. - Tacitus',
#  'I wake each morning torn between the desire to improve the world and the desire to enjoy it. It makes it hard to plan the day. - E.B. White',
#  'Worry is interest paid on trouble before it falls due. - W. R. Inge',
#  'Games lubricate the body and the mind. - Benjamin Franklin',
#  'The surface of American society is covered with a layer of democratic paint, but from time to time one can see the old aristocratic colours breaking through. - Alexis de Tocqueville',
#  'The commonest thing is delightful if only one hides it. - Oscar Wilde',
#  'That is the true season of love, when we believe that we alone can love, that no one could ever have loved so before us, and that no one will love in the same way after us. - Johann Wolfgang von Goethe',
#  'I`ve been accused of vulgarity. I say that`s bullshit. - Mel Brooks',
#  'Journalism is literature in a hurry. - Matthew Arnold',
#  'Man [has] always assumed that he was more intelligent than dolphins because he had achieved so much-the wheel, New York, wars and so on-while all the dolphins had ever done was muck about in the water having a good time. But conversely, the dolphins had always believed that they were far more intelligent than man-for precisely the same reason. - Douglas Adams',
#  'You can`t teach an old dogma new tricks. - Dorothy Parker',
#  'If you will not fight for the right when you can easily win without bloodshed; if you will not fight when your victory will be sure and not too costly; you may come to the moment when you will have to fight with all the odds against you and only a small chance of survival. There may even be a worse case: you may have to fight when there is no hope of victory, because it is better to perish than to live as slaves. - Winston Churchill',
#  'The best defense against usurpatory government is an assertive citizenry. - William F. Buckley',
#  'Cowards die many times before their deaths. The valiant never taste of death but once. - William Shakespeare',
#  'It is astonishing what an effort it seems to be for many people to put their brains definitely and systematically to work. - Thomas Edison',
#  'Liberty exists in proportion to wholesome restraint. - Daniel Webster',
#  'To be what we are, and to become what we are capable of becoming, is the only end of life. - Robert Louis Stevenson',
#  'I honestly think it is better to be a failure at something you love than to be a success at something you hate. - George Burns',
#  'The power of accurate observation is commonly called cynicism by those who have not got it. - George Bernard Shaw',
#  'Question with boldness even the existence of a God; because, if there be one, he must more approve of the homage of reason, than that of blind-folded fear. - Thomas Jefferson',
#  'We are never deceived; we deceive ourselves. - Johann Wolfgang von Goethe',
#  'Government is not a solution to our problem, government is the problem. - Ronald Reagan']

# %%
len(list_of_quotes) ## the number of quotes in the list
# Out:
# 886

# %% [markdown]
# #### (b) Words from full quotes
# The function words_in_quote takes a full quote as argument and outputs a list of the words in the it. The
# words are all in lower-case, and contain only characters, digits, or
# underscore. <br>

# %%
def words_in_quote(quote):
    
    '''
    A function to return a list of words in the quote
    
    Paramters: 
    quote (str) : A full quote 
    
    Returns:
    A list of words from the quote containing only characters, digits, underscore
    
    '''
    
    words = []
    lower_quote = quote.lower()

    words = re.split(r'[^a-z0-9_`]+',lower_quote)
    return words

# %% [markdown]
# #### (c) Build the postings-list dictionary
# A postings-list is
# a dictionary whose keys are full quotes, and whose values are themselves
# dictionaries with key being a word, and value being the number of times
# the word occurs in the full quote. <br>

# %%
## Create a postings_list dictionary with key as quote and a dictionary as value
## The key dictionary consists words as keys and the frequency of the word in quote as values

postings_list = {}

for i in list_of_quotes:
    words = words_in_quote(i)
    
    words_dictionary = {}
    
    for word in words:
        if word in words_dictionary:
            words_dictionary[word] += 1
        else:
            words_dictionary[word] = 1
    
    postings_list[i] = words_dictionary

postings_list
# Out:
# {'How we spend our days is, of course, how we spend our lives. - Annie Dillard': {'how': 2,
#   'we': 2,
#   'spend': 2,
#   'our': 2,
#   'days': 1,
#   'is': 1,
#   'of': 1,
#   'course': 1,
#   'lives': 1,
#   'annie': 1,
#   'dillard': 1},
#  'Two roads diverged in a wood, and I...I took the one less traveled by, and that has made all the difference. - Robert Frost': {'two': 1,
#   'roads': 1,
#   'diverged': 1,
#   'in': 1,
#   'a': 1,
#   'wood': 1,
#   'and': 2,
#   'i': 2,
#   'took': 1,
#   'the': 2,
#   'one': 1,
#   'less': 1,
#   'traveled': 1,
#   'by': 1,
#   'that': 1,
#   'has': 1,
#   'made': 1,
#   'all': 1,
#   'difference': 1,
#   'robert': 1,
#   'frost': 1},
#  'What is happiness? The feeling that power is growing, that resistance is overcome. - Friedrich Nietzsche': {'what': 1,
#   'is': 3,
#   'happiness': 1,
#   'the': 1,
#   'feeling': 1,
#   'that': 2,
#   'power': 1,
#   'growing': 1,
#   'resistance': 1,
#   'overcome': 1,
#   'friedrich': 1,
#   'nietzsche': 1},
#  'A great deal of intelligence can be invested in ignorance when the need for illusion is deep. - Saul Bellow': {'a': 1,
#   'great': 1,
#   'deal': 1,
#   'of': 1,
#   'intelligence': 1,
#   'can': 1,
#   'be': 1,
#   'invested': 1,
#   'in': 1,
#   'ignorance': 1,
#   'when': 1,
#   'the': 1,
#   'need': 1,
#   'for': 1,
#   'illusion': 1,
#   'is': 1,
#   'deep': 1,
#   'saul': 1,
#   'bellow': 1},
#  'Those who are preoccupied with `making a statement` usually don`t have any statements worth making. - Thomas Sowell': {'those': 1,
#   'who': 1,
#   'are': 1,
#   'preoccupied': 1,
#   'with': 1,
#   '`making': 1,
#   'a': 1,
#   'statement`': 1,
#   'usually': 1,
#   'don`t': 1,
#   'have': 1,
#   'any': 1,
#   'statements': 1,
#   'worth': 1,
#   'making': 1,
#   'thomas': 1,
#   'sowell': 1},
#  'Women need a reason to have sex -- men just need a place. - Billy Crystal': {'women': 1,
#   'need': 2,
#   'a': 2,
#   'reason': 1,
#   'to': 1,
#   'have': 1,
#   'sex': 1,
#   'men': 1,
#   'just': 1,
#   'place': 1,
#   'billy': 1,
#   'crystal': 1},
#  'The heart has its reasons, of which the mind knows nothing. - Blaise Pascal': {'the': 2,
#   'heart': 1,
#   'has': 1,
#   'its': 1,
#   'reasons': 1,
#   'of': 1,
#   'which': 1,
#   'mind': 1,
#   'knows': 1,
#   'nothing': 1,
#   'blaise': 1,
#   'pascal': 1},
#  'It is necessary for the welfare of society that genius should be privileged to utter sedition, to blaspheme, to outrage good taste, to corrupt the youthful mind, and generally to scandalize one`s uncles. - George Bernard Shaw': {'it': 1,
#   'is': 1,
#   'necessary': 1,
#   'for': 1,
#   'the': 2,
#   'welfare': 1,
#   'of': 1,
#   'society': 1,
#   'that': 1,
#   'genius': 1,
#   'should': 1,
#   'be': 1,
#   'privileged': 1,
#   'to': 5,
#   'utter': 1,
#   'sedition': 1,
#   'blaspheme': 1,
#   'outrage': 1,
#   'good': 1,
#   'taste': 1,
#   'corrupt': 1,
#   'youthful': 1,
#   'mind': 1,
#   'and': 1,
#   'generally': 1,
#   'scandalize': 1,
#   'one`s': 1,
#   'uncles': 1,
#   'george': 1,
#   'bernard': 1,
#   'shaw': 1},
#  'Freedom is not something that anybody can be given; freedom is something people take and people are as free as they want to be. - James Baldwin': {'freedom': 2,
#   'is': 2,
#   'not': 1,
#   'something': 2,
#   'that': 1,
#   'anybody': 1,
#   'can': 1,
#   'be': 2,
#   'given': 1,
#   'people': 2,
#   'take': 1,
#   'and': 1,
#   'are': 1,
#   'as': 2,
#   'free': 1,
#   'they': 1,
#   'want': 1,
#   'to': 1,
#   'james': 1,
#   'baldwin': 1},
#  'Collecting more taxes than is absolutely necessary is legalized robbery. - Calvin Coolidge': {'collecting': 1,
#   'more': 1,
#   'taxes': 1,
#   'than': 1,
#   'is': 2,
#   'absolutely': 1,
#   'necessary': 1,
#   'legalized': 1,
#   'robbery': 1,
#   'calvin': 1,
#   'coolidge': 1},
#  'I almost had a pyschic girlfriend, but she left me before we met. - Steven Wright': {'i': 1,
#   'almost': 1,
#   'had': 1,
#   'a': 1,
#   'pyschic': 1,
#   'girlfriend': 1,
#   'but': 1,
#   'she': 1,
#   'left': 1,
#   'me': 1,
#   'before': 1,
#   'we': 1,
#   'met': 1,
#   'steven': 1,
#   'wright': 1},
#  'The man who disobeys his parents will have disobedient sons. - Nachman of Bratslav': {'the': 1,
#   'man': 1,
#   'who': 1,
#   'disobeys': 1,
#   'his': 1,
#   'parents': 1,
#   'will': 1,
#   'have': 1,
#   'disobedient': 1,
#   'sons': 1,
#   'nachman': 1,
#   'of': 1,
#   'bratslav': 1},
#  'I know God will not give me anything I can`t handle. I just wish that He didn`t trust me so much. - Mother Teresa': {'i': 3,
#   'know': 1,
#   'god': 1,
#   'will': 1,
#   'not': 1,
#   'give': 1,
#   'me': 2,
#   'anything': 1,
#   'can`t': 1,
#   'handle': 1,
#   'just': 1,
#   'wish': 1,
#   'that': 1,
#   'he': 1,
#   'didn`t': 1,
#   'trust': 1,
#   'so': 1,
#   'much': 1,
#   'mother': 1,
#   'teresa': 1},
#  'When an American says that he loves his country, he means not only that he loves the New England hills, the prairies glistening in the sun, the wide and rising plains, the great mountains, and the sea. He means that he loves an inner air, an inner light in which freedom lives and in which a man can draw the breath of self-respect. - Adlai Stevenson': {'when': 1,
#   'an': 3,
#   'american': 1,
#   'says': 1,
#   'that': 3,
#   'he': 5,
#   'loves': 3,
#   'his': 1,
#   'country': 1,
#   'means': 2,
#   'not': 1,
#   'only': 1,
#   'the': 7,
#   'new': 1,
#   'england': 1,
#   'hills': 1,
#   'prairies': 1,
#   'glistening': 1,
#   'in': 3,
#   'sun': 1,
#   'wide': 1,
#   'and': 3,
#   'rising': 1,
#   'plains': 1,
#   'great': 1,
#   'mountains': 1,
#   'sea': 1,
#   'inner': 2,
#   'air': 1,
#   'light': 1,
#   'which': 2,
#   'freedom': 1,
#   'lives': 1,
#   'a': 1,
#   'man': 1,
#   'can': 1,
#   'draw': 1,
#   'breath': 1,
#   'of': 1,
#   'self': 1,
#   'respect': 1,
#   'adlai': 1,
#   'stevenson': 1},
#  'Words which do not give the light of Christ increase the darkness. - Mother Teresa': {'words': 1,
#   'which': 1,
#   'do': 1,
#   'not': 1,
#   'give': 1,
#   'the': 2,
#   'light': 1,
#   'of': 1,
#   'christ': 1,
#   'increase': 1,
#   'darkness': 1,
#   'mother': 1,
#   'teresa': 1},
#  'My dream is of a place and a time where America will once again be seen as the last best hope of earth. - Abraham Lincoln': {'my': 1,
#   'dream': 1,
#   'is': 1,
#   'of': 2,
#   'a': 2,
#   'place': 1,
#   'and': 1,
#   'time': 1,
#   'where': 1,
#   'america': 1,
#   'will': 1,
#   'once': 1,
#   'again': 1,
#   'be': 1,
#   'seen': 1,
#   'as': 1,
#   'the': 1,
#   'last': 1,
#   'best': 1,
#   'hope': 1,
#   'earth': 1,
#   'abraham': 1,
#   'lincoln': 1},
#  'An actor is at most a poet and at least an entertainer. - Marlon Brando': {'an': 2,
#   'actor': 1,
#   'is': 1,
#   'at': 2,
#   'most': 1,
#   'a': 1,
#   'poet': 1,
#   'and': 1,
#   'least': 1,
#   'entertainer': 1,
#   'marlon': 1,
#   'brando': 1},
#  'Humility is the foundation of all the other virtues hence, in the soul in which this virtue does not exist there cannot be any other virtue except in mere appearance. - Saint Augustine': {'humility': 1,
#   'is': 1,
#   'the': 3,
#   'foundation': 1,
#   'of': 1,
#   'all': 1,
#   'other': 2,
#   'virtues': 1,
#   'hence': 1,
#   'in': 3,
#   'soul': 1,
#   'which': 1,
#   'this': 1,
#   'virtue': 2,
#   'does': 1,
#   'not': 1,
#   'exist': 1,
#   'there': 1,
#   'cannot': 1,
#   'be': 1,
#   'any': 1,
#   'except': 1,
#   'mere': 1,
#   'appearance': 1,
#   'saint': 1,
#   'augustine': 1},
#  'The object of teaching a child is to enable him to get along without a teacher. - Elbert Hubbard': {'the': 1,
#   'object': 1,
#   'of': 1,
#   'teaching': 1,
#   'a': 2,
#   'child': 1,
#   'is': 1,
#   'to': 2,
#   'enable': 1,
#   'him': 1,
#   'get': 1,
#   'along': 1,
#   'without': 1,
#   'teacher': 1,
#   'elbert': 1,
#   'hubbard': 1},
#  'Avoid the base hypocrisy of condemning in one man what you pass over in silence when committed by another. - Theodore Roosevelt': {'avoid': 1,
#   'the': 1,
#   'base': 1,
#   'hypocrisy': 1,
#   'of': 1,
#   'condemning': 1,
#   'in': 2,
#   'one': 1,
#   'man': 1,
#   'what': 1,
#   'you': 1,
#   'pass': 1,
#   'over': 1,
#   'silence': 1,
#   'when': 1,
#   'committed': 1,
#   'by': 1,
#   'another': 1,
#   'theodore': 1,
#   'roosevelt': 1},
#  'Most football teams are temperamental. That`s 90% temper and 10% mental. - Doug Plank': {'most': 1,
#   'football': 1,
#   'teams': 1,
#   'are': 1,
#   'temperamental': 1,
#   'that`s': 1,
#   '90': 1,
#   'temper': 1,
#   'and': 1,
#   '10': 1,
#   'mental': 1,
#   'doug': 1,
#   'plank': 1},
#  'There can be no liberty unless there is economic liberty. - Margaret Thatcher': {'there': 2,
#   'can': 1,
#   'be': 1,
#   'no': 1,
#   'liberty': 2,
#   'unless': 1,
#   'is': 1,
#   'economic': 1,
#   'margaret': 1,
#   'thatcher': 1},
#  'Idealism is fine, but as it approaches reality, the costs become prohibitive. - William F. Buckley': {'idealism': 1,
#   'is': 1,
#   'fine': 1,
#   'but': 1,
#   'as': 1,
#   'it': 1,
#   'approaches': 1,
#   'reality': 1,
#   'the': 1,
#   'costs': 1,
#   'become': 1,
#   'prohibitive': 1,
#   'william': 1,
#   'f': 1,
#   'buckley': 1},
#  'I didn`t attend the funeral, but I sent a nice letter saying I approved of it. - Mark Twain': {'i': 3,
#   'didn`t': 1,
#   'attend': 1,
#   'the': 1,
#   'funeral': 1,
#   'but': 1,
#   'sent': 1,
#   'a': 1,
#   'nice': 1,
#   'letter': 1,
#   'saying': 1,
#   'approved': 1,
#   'of': 1,
#   'it': 1,
#   'mark': 1,
#   'twain': 1},
#  'Every woman knows all about everything. - Rudyard Kipling': {'every': 1,
#   'woman': 1,
#   'knows': 1,
#   'all': 1,
#   'about': 1,
#   'everything': 1,
#   'rudyard': 1,
#   'kipling': 1},
#  'Perfect humility dispenses with modesty. - C.S. Lewis': {'perfect': 1,
#   'humility': 1,
#   'dispenses': 1,
#   'with': 1,
#   'modesty': 1,
#   'c': 1,
#   's': 1,
#   'lewis': 1},
#  'I think a good gift for the president would be a chocolate revolver. And since he`s so busy, you`d probably have to run up to him and hand it to him. - Jack Handey': {'i': 1,
#   'think': 1,
#   'a': 2,
#   'good': 1,
#   'gift': 1,
#   'for': 1,
#   'the': 1,
#   'president': 1,
#   'would': 1,
#   'be': 1,
#   'chocolate': 1,
#   'revolver': 1,
#   'and': 2,
#   'since': 1,
#   'he`s': 1,
#   'so': 1,
#   'busy': 1,
#   'you`d': 1,
#   'probably': 1,
#   'have': 1,
#   'to': 3,
#   'run': 1,
#   'up': 1,
#   'him': 2,
#   'hand': 1,
#   'it': 1,
#   'jack': 1,
#   'handey': 1},
#  'The thought of being president frightens me. I do not think I want the job. - Ronald Reagan': {'the': 2,
#   'thought': 1,
#   'of': 1,
#   'being': 1,
#   'president': 1,
#   'frightens': 1,
#   'me': 1,
#   'i': 2,
#   'do': 1,
#   'not': 1,
#   'think': 1,
#   'want': 1,
#   'job': 1,
#   'ronald': 1,
#   'reagan': 1},
#  'A journey of a thousand miles begins with a single step. - Confucius': {'a': 3,
#   'journey': 1,
#   'of': 1,
#   'thousand': 1,
#   'miles': 1,
#   'begins': 1,
#   'with': 1,
#   'single': 1,
#   'step': 1,
#   'confucius': 1},
#  'Most modern freedom is at root fear. It is not so much that we are too bold to endure rules; it is rather that we are too timid to endure responsibilities. - GK Chesterton': {'most': 1,
#   'modern': 1,
#   'freedom': 1,
#   'is': 3,
#   'at': 1,
#   'root': 1,
#   'fear': 1,
#   'it': 2,
#   'not': 1,
#   'so': 1,
#   'much': 1,
#   'that': 2,
#   'we': 2,
#   'are': 2,
#   'too': 2,
#   'bold': 1,
#   'to': 2,
#   'endure': 2,
#   'rules': 1,
#   'rather': 1,
#   'timid': 1,
#   'responsibilities': 1,
#   'gk': 1,
#   'chesterton': 1},
#  'Television is a medium of entertainment which permits millions of people to listen to the same joke at the same time, and yet remain lonesome. - T.S. Eliot': {'television': 1,
#   'is': 1,
#   'a': 1,
#   'medium': 1,
#   'of': 2,
#   'entertainment': 1,
#   'which': 1,
#   'permits': 1,
#   'millions': 1,
#   'people': 1,
#   'to': 2,
#   'listen': 1,
#   'the': 2,
#   'same': 2,
#   'joke': 1,
#   'at': 1,
#   'time': 1,
#   'and': 1,
#   'yet': 1,
#   'remain': 1,
#   'lonesome': 1,
#   't': 1,
#   's': 1,
#   'eliot': 1},
#  'Imagination will often carry us to worlds that never were. But without it, we go nowhere. - Carl Sagan': {'imagination': 1,
#   'will': 1,
#   'often': 1,
#   'carry': 1,
#   'us': 1,
#   'to': 1,
#   'worlds': 1,
#   'that': 1,
#   'never': 1,
#   'were': 1,
#   'but': 1,
#   'without': 1,
#   'it': 1,
#   'we': 1,
#   'go': 1,
#   'nowhere': 1,
#   'carl': 1,
#   'sagan': 1},
#  'In any fairly large and talkative community such as a university there is always the danger that those who think alike should gravitate together where they will henceforth encounter opposition only in the emasculated form of rumour that the outsiders say thus and thus. The absent are easily refuted, complacent dogmatism thrives, and differences of opinion are embittered by the group hostility. Each group hears not the best, but the worst, that the other group can say. - C.S. Lewis': {'in': 2,
#   'any': 1,
#   'fairly': 1,
#   'large': 1,
#   'and': 3,
#   'talkative': 1,
#   'community': 1,
#   'such': 1,
#   'as': 1,
#   'a': 1,
#   'university': 1,
#   'there': 1,
#   'is': 1,
#   'always': 1,
#   'the': 8,
#   'danger': 1,
#   'that': 3,
#   'those': 1,
#   'who': 1,
#   'think': 1,
#   'alike': 1,
#   'should': 1,
#   'gravitate': 1,
#   'together': 1,
#   'where': 1,
#   'they': 1,
#   'will': 1,
#   'henceforth': 1,
#   'encounter': 1,
#   'opposition': 1,
#   'only': 1,
#   'emasculated': 1,
#   'form': 1,
#   'of': 2,
#   'rumour': 1,
#   'outsiders': 1,
#   'say': 2,
#   'thus': 2,
#   'absent': 1,
#   'are': 2,
#   'easily': 1,
#   'refuted': 1,
#   'complacent': 1,
#   'dogmatism': 1,
#   'thrives': 1,
#   'differences': 1,
#   'opinion': 1,
#   'embittered': 1,
#   'by': 1,
#   'group': 3,
#   'hostility': 1,
#   'each': 1,
#   'hears': 1,
#   'not': 1,
#   'best': 1,
#   'but': 1,
#   'worst': 1,
#   'other': 1,
#   'can': 1,
#   'c': 1,
#   's': 1,
#   'lewis': 1},
#  'Success does not consist in never making mistakes but in never making the same one a second time. - George Bernard Shaw': {'success': 1,
#   'does': 1,
#   'not': 1,
#   'consist': 1,
#   'in': 2,
#   'never': 2,
#   'making': 2,
#   'mistakes': 1,
#   'but': 1,
#   'the': 1,
#   'same': 1,
#   'one': 1,
#   'a': 1,
#   'second': 1,
#   'time': 1,
#   'george': 1,
#   'bernard': 1,
#   'shaw': 1},
#  'Take time to deliberate, but when the time for action has arrived, stop thinking and go in. - Napoleon Bonaparte': {'take': 1,
#   'time': 2,
#   'to': 1,
#   'deliberate': 1,
#   'but': 1,
#   'when': 1,
#   'the': 1,
#   'for': 1,
#   'action': 1,
#   'has': 1,
#   'arrived': 1,
#   'stop': 1,
#   'thinking': 1,
#   'and': 1,
#   'go': 1,
#   'in': 1,
#   'napoleon': 1,
#   'bonaparte': 1},
#  'I`m never going to be famous. My name will never be writ large on the roster of Those Who Do Things. I don`t do any thing. Not one single thing. I used to bite my nails, but I don`t even do that any more. - Dorothy Parker': {'i`m': 1,
#   'never': 2,
#   'going': 1,
#   'to': 2,
#   'be': 2,
#   'famous': 1,
#   'my': 2,
#   'name': 1,
#   'will': 1,
#   'writ': 1,
#   'large': 1,
#   'on': 1,
#   'the': 1,
#   'roster': 1,
#   'of': 1,
#   'those': 1,
#   'who': 1,
#   'do': 3,
#   'things': 1,
#   'i': 3,
#   'don`t': 2,
#   'any': 2,
#   'thing': 2,
#   'not': 1,
#   'one': 1,
#   'single': 1,
#   'used': 1,
#   'bite': 1,
#   'nails': 1,
#   'but': 1,
#   'even': 1,
#   'that': 1,
#   'more': 1,
#   'dorothy': 1,
#   'parker': 1},
#  'Money doesn`t talk, it swears. - Bob Dylan': {'money': 1,
#   'doesn`t': 1,
#   'talk': 1,
#   'it': 1,
#   'swears': 1,
#   'bob': 1,
#   'dylan': 1},
#  'Advertising is the life of trade. - Calvin Coolidge': {'advertising': 1,
#   'is': 1,
#   'the': 1,
#   'life': 1,
#   'of': 1,
#   'trade': 1,
#   'calvin': 1,
#   'coolidge': 1},
#  'Christmas can be celebrated in the school room with pine trees, tinsel and reindeers, but there must be no mention of the man whose birthday is being celebrated. One wonders how a teacher would answer if a student asked why it was called Christmas. - Ronald Reagan': {'christmas': 2,
#   'can': 1,
#   'be': 2,
#   'celebrated': 2,
#   'in': 1,
#   'the': 2,
#   'school': 1,
#   'room': 1,
#   'with': 1,
#   'pine': 1,
#   'trees': 1,
#   'tinsel': 1,
#   'and': 1,
#   'reindeers': 1,
#   'but': 1,
#   'there': 1,
#   'must': 1,
#   'no': 1,
#   'mention': 1,
#   'of': 1,
#   'man': 1,
#   'whose': 1,
#   'birthday': 1,
#   'is': 1,
#   'being': 1,
#   'one': 1,
#   'wonders': 1,
#   'how': 1,
#   'a': 2,
#   'teacher': 1,
#   'would': 1,
#   'answer': 1,
#   'if': 1,
#   'student': 1,
#   'asked': 1,
#   'why': 1,
#   'it': 1,
#   'was': 1,
#   'called': 1,
#   'ronald': 1,
#   'reagan': 1},
#  'Experience is that marvelous thing that enables you to recognize a mistake when you make it again. - Franklin Jones': {'experience': 1,
#   'is': 1,
#   'that': 2,
#   'marvelous': 1,
#   'thing': 1,
#   'enables': 1,
#   'you': 2,
#   'to': 1,
#   'recognize': 1,
#   'a': 1,
#   'mistake': 1,
#   'when': 1,
#   'make': 1,
#   'it': 1,
#   'again': 1,
#   'franklin': 1,
#   'jones': 1},
#  'He that would make his own liberty secure, must guard even his enemy from opposition; for if he violates this duty he establishes a precedent that will reach himself. - Thomas Paine': {'he': 3,
#   'that': 2,
#   'would': 1,
#   'make': 1,
#   'his': 2,
#   'own': 1,
#   'liberty': 1,
#   'secure': 1,
#   'must': 1,
#   'guard': 1,
#   'even': 1,
#   'enemy': 1,
#   'from': 1,
#   'opposition': 1,
#   'for': 1,
#   'if': 1,
#   'violates': 1,
#   'this': 1,
#   'duty': 1,
#   'establishes': 1,
#   'a': 1,
#   'precedent': 1,
#   'will': 1,
#   'reach': 1,
#   'himself': 1,
#   'thomas': 1,
#   'paine': 1},
#  'Originality is the fine art of remembering what you hear but forgetting where you heard it. - Laurence Peter': {'originality': 1,
#   'is': 1,
#   'the': 1,
#   'fine': 1,
#   'art': 1,
#   'of': 1,
#   'remembering': 1,
#   'what': 1,
#   'you': 2,
#   'hear': 1,
#   'but': 1,
#   'forgetting': 1,
#   'where': 1,
#   'heard': 1,
#   'it': 1,
#   'laurence': 1,
#   'peter': 1},
#  'I arrive at the end of this review having done my duty as a critic. I have described the movie accurately and you have a good idea what you are in for if you go to see it. Most of you will not. I cannot argue with you. Some of you will--the brave and the curious. You embody the spirit of the man who first wondered what it would taste like to eat an oyster. - Roger Ebert': {'i': 3,
#   'arrive': 1,
#   'at': 1,
#   'the': 6,
#   'end': 1,
#   'of': 4,
#   'this': 1,
#   'review': 1,
#   'having': 1,
#   'done': 1,
#   'my': 1,
#   'duty': 1,
#   'as': 1,
#   'a': 2,
#   'critic': 1,
#   'have': 2,
#   'described': 1,
#   'movie': 1,
#   'accurately': 1,
#   'and': 2,
#   'you': 7,
#   'good': 1,
#   'idea': 1,
#   'what': 2,
#   'are': 1,
#   'in': 1,
#   'for': 1,
#   'if': 1,
#   'go': 1,
#   'to': 2,
#   'see': 1,
#   'it': 2,
#   'most': 1,
#   'will': 2,
#   'not': 1,
#   'cannot': 1,
#   'argue': 1,
#   'with': 1,
#   'some': 1,
#   'brave': 1,
#   'curious': 1,
#   'embody': 1,
#   'spirit': 1,
#   'man': 1,
#   'who': 1,
#   'first': 1,
#   'wondered': 1,
#   'would': 1,
#   'taste': 1,
#   'like': 1,
#   'eat': 1,
#   'an': 1,
#   'oyster': 1,
#   'roger': 1,
#   'ebert': 1},
#  'Men marry to make an end; women to make a beginning. - Alexis Dupuy': {'men': 1,
#   'marry': 1,
#   'to': 2,
#   'make': 2,
#   'an': 1,
#   'end': 1,
#   'women': 1,
#   'a': 1,
#   'beginning': 1,
#   'alexis': 1,
#   'dupuy': 1},
#  'Show me a thoroughly satisfied man and I will show you a failure. - Thomas Edison': {'show': 2,
#   'me': 1,
#   'a': 2,
#   'thoroughly': 1,
#   'satisfied': 1,
#   'man': 1,
#   'and': 1,
#   'i': 1,
#   'will': 1,
#   'you': 1,
#   'failure': 1,
#   'thomas': 1,
#   'edison': 1},
#  'I have often wondered how it is that every man loves himself more than all the rest of men, but yet sets less value on his own opinion of himself than on the opinion of others. - Marcus Aurelius': {'i': 1,
#   'have': 1,
#   'often': 1,
#   'wondered': 1,
#   'how': 1,
#   'it': 1,
#   'is': 1,
#   'that': 1,
#   'every': 1,
#   'man': 1,
#   'loves': 1,
#   'himself': 2,
#   'more': 1,
#   'than': 2,
#   'all': 1,
#   'the': 2,
#   'rest': 1,
#   'of': 3,
#   'men': 1,
#   'but': 1,
#   'yet': 1,
#   'sets': 1,
#   'less': 1,
#   'value': 1,
#   'on': 2,
#   'his': 1,
#   'own': 1,
#   'opinion': 2,
#   'others': 1,
#   'marcus': 1,
#   'aurelius': 1},
#  'You find out more about God from the Moral Law than from the univerise in general just as you find out more about a man by listening to his conversation than by looking at a house he has built. - C.S. Lewis': {'you': 2,
#   'find': 2,
#   'out': 2,
#   'more': 2,
#   'about': 2,
#   'god': 1,
#   'from': 2,
#   'the': 2,
#   'moral': 1,
#   'law': 1,
#   'than': 2,
#   'univerise': 1,
#   'in': 1,
#   'general': 1,
#   'just': 1,
#   'as': 1,
#   'a': 2,
#   'man': 1,
#   'by': 2,
#   'listening': 1,
#   'to': 1,
#   'his': 1,
#   'conversation': 1,
#   'looking': 1,
#   'at': 1,
#   'house': 1,
#   'he': 1,
#   'has': 1,
#   'built': 1,
#   'c': 1,
#   's': 1,
#   'lewis': 1},
#  'Instead of a trap door, what about a trap window? The guy looks out it, and if he leans too far, he falls out. Wait. I guess that`s like a regular window. - Jack Handey': {'instead': 1,
#   'of': 1,
#   'a': 3,
#   'trap': 2,
#   'door': 1,
#   'what': 1,
#   'about': 1,
#   'window': 2,
#   'the': 1,
#   'guy': 1,
#   'looks': 1,
#   'out': 2,
#   'it': 1,
#   'and': 1,
#   'if': 1,
#   'he': 2,
#   'leans': 1,
#   'too': 1,
#   'far': 1,
#   'falls': 1,
#   'wait': 1,
#   'i': 1,
#   'guess': 1,
#   'that`s': 1,
#   'like': 1,
#   'regular': 1,
#   'jack': 1,
#   'handey': 1},
#  'Man was made for action, and to promote by the exertion of his faculties such changes in the external circumstances both of himself and others, as may seem most favourable to the happiness of all. - Adam Smith': {'man': 1,
#   'was': 1,
#   'made': 1,
#   'for': 1,
#   'action': 1,
#   'and': 2,
#   'to': 2,
#   'promote': 1,
#   'by': 1,
#   'the': 3,
#   'exertion': 1,
#   'of': 3,
#   'his': 1,
#   'faculties': 1,
#   'such': 1,
#   'changes': 1,
#   'in': 1,
#   'external': 1,
#   'circumstances': 1,
#   'both': 1,
#   'himself': 1,
#   'others': 1,
#   'as': 1,
#   'may': 1,
#   'seem': 1,
#   'most': 1,
#   'favourable': 1,
#   'happiness': 1,
#   'all': 1,
#   'adam': 1,
#   'smith': 1},
#  'In every man`s heart there is a secret nerve that answers to the vibrations of beauty. - Christopher Morley': {'in': 1,
#   'every': 1,
#   'man`s': 1,
#   'heart': 1,
#   'there': 1,
#   'is': 1,
#   'a': 1,
#   'secret': 1,
#   'nerve': 1,
#   'that': 1,
#   'answers': 1,
#   'to': 1,
#   'the': 1,
#   'vibrations': 1,
#   'of': 1,
#   'beauty': 1,
#   'christopher': 1,
#   'morley': 1},
#  'If Jack`s in love, he`s no judge of Jill`s beauty. - Benjamin Franklin': {'if': 1,
#   'jack`s': 1,
#   'in': 1,
#   'love': 1,
#   'he`s': 1,
#   'no': 1,
#   'judge': 1,
#   'of': 1,
#   'jill`s': 1,
#   'beauty': 1,
#   'benjamin': 1,
#   'franklin': 1},
#  'The Democrats seem to be basically nicer people, but they have demonstrated time and again that they have the management skills of celery. - Dave Barry': {'the': 2,
#   'democrats': 1,
#   'seem': 1,
#   'to': 1,
#   'be': 1,
#   'basically': 1,
#   'nicer': 1,
#   'people': 1,
#   'but': 1,
#   'they': 2,
#   'have': 2,
#   'demonstrated': 1,
#   'time': 1,
#   'and': 1,
#   'again': 1,
#   'that': 1,
#   'management': 1,
#   'skills': 1,
#   'of': 1,
#   'celery': 1,
#   'dave': 1,
#   'barry': 1},
#  'Without courage, wisdom bears no fruit. - Baltasar Gracian': {'without': 1,
#   'courage': 1,
#   'wisdom': 1,
#   'bears': 1,
#   'no': 1,
#   'fruit': 1,
#   'baltasar': 1,
#   'gracian': 1},
#  'I thought it completely absurd to mention my name in the same breath as the Presidency. - Dwight Eisenhower': {'i': 1,
#   'thought': 1,
#   'it': 1,
#   'completely': 1,
#   'absurd': 1,
#   'to': 1,
#   'mention': 1,
#   'my': 1,
#   'name': 1,
#   'in': 1,
#   'the': 2,
#   'same': 1,
#   'breath': 1,
#   'as': 1,
#   'presidency': 1,
#   'dwight': 1,
#   'eisenhower': 1},
#  'The only reason for time is so that everything doesn`t happen at once. - Albert Einstein': {'the': 1,
#   'only': 1,
#   'reason': 1,
#   'for': 1,
#   'time': 1,
#   'is': 1,
#   'so': 1,
#   'that': 1,
#   'everything': 1,
#   'doesn`t': 1,
#   'happen': 1,
#   'at': 1,
#   'once': 1,
#   'albert': 1,
#   'einstein': 1},
#  'The fool doth think he is wise, but the wise man knows himself to be a fool. - William Shakespeare': {'the': 2,
#   'fool': 2,
#   'doth': 1,
#   'think': 1,
#   'he': 1,
#   'is': 1,
#   'wise': 2,
#   'but': 1,
#   'man': 1,
#   'knows': 1,
#   'himself': 1,
#   'to': 1,
#   'be': 1,
#   'a': 1,
#   'william': 1,
#   'shakespeare': 1},
#  'You don`t have to stay up nights to succeed; you have to stay awake days. - Author Unknown': {'you': 2,
#   'don`t': 1,
#   'have': 2,
#   'to': 3,
#   'stay': 2,
#   'up': 1,
#   'nights': 1,
#   'succeed': 1,
#   'awake': 1,
#   'days': 1,
#   'author': 1,
#   'unknown': 1},
#  'Life is what happens to you while you`re busy making other plans. - John Lennon': {'life': 1,
#   'is': 1,
#   'what': 1,
#   'happens': 1,
#   'to': 1,
#   'you': 1,
#   'while': 1,
#   'you`re': 1,
#   'busy': 1,
#   'making': 1,
#   'other': 1,
#   'plans': 1,
#   'john': 1,
#   'lennon': 1},
#  'Fear not those who argue but those who dodge. - Dale Carnegie': {'fear': 1,
#   'not': 1,
#   'those': 2,
#   'who': 2,
#   'argue': 1,
#   'but': 1,
#   'dodge': 1,
#   'dale': 1,
#   'carnegie': 1},
#  'I have a hobby...I have the world`s largest collection of sea shells. I keep it scattered on beaches all over the world. Maybe you`ve seen some of it... - Steven Wright': {'i': 3,
#   'have': 2,
#   'a': 1,
#   'hobby': 1,
#   'the': 2,
#   'world`s': 1,
#   'largest': 1,
#   'collection': 1,
#   'of': 2,
#   'sea': 1,
#   'shells': 1,
#   'keep': 1,
#   'it': 2,
#   'scattered': 1,
#   'on': 1,
#   'beaches': 1,
#   'all': 1,
#   'over': 1,
#   'world': 1,
#   'maybe': 1,
#   'you`ve': 1,
#   'seen': 1,
#   'some': 1,
#   'steven': 1,
#   'wright': 1},
#  'The art of being happy lies in the power of extracting happiness from common things. - Henry Ward Beecher': {'the': 2,
#   'art': 1,
#   'of': 2,
#   'being': 1,
#   'happy': 1,
#   'lies': 1,
#   'in': 1,
#   'power': 1,
#   'extracting': 1,
#   'happiness': 1,
#   'from': 1,
#   'common': 1,
#   'things': 1,
#   'henry': 1,
#   'ward': 1,
#   'beecher': 1},
#  'Demoralize the enemy from within by surprise, terror, sabotage, assassination. This is the war of the future. - Adolf Hitler': {'demoralize': 1,
#   'the': 3,
#   'enemy': 1,
#   'from': 1,
#   'within': 1,
#   'by': 1,
#   'surprise': 1,
#   'terror': 1,
#   'sabotage': 1,
#   'assassination': 1,
#   'this': 1,
#   'is': 1,
#   'war': 1,
#   'of': 1,
#   'future': 1,
#   'adolf': 1,
#   'hitler': 1},
#  'If eighty percent of your sales come from twenty percent of all of your items, just carry those twenty percent. - Henry Kissinger': {'if': 1,
#   'eighty': 1,
#   'percent': 3,
#   'of': 3,
#   'your': 2,
#   'sales': 1,
#   'come': 1,
#   'from': 1,
#   'twenty': 2,
#   'all': 1,
#   'items': 1,
#   'just': 1,
#   'carry': 1,
#   'those': 1,
#   'henry': 1,
#   'kissinger': 1},
#  'It`s not how old you are, it`s how hard you work at it. - Jonah Barrington': {'it`s': 2,
#   'not': 1,
#   'how': 2,
#   'old': 1,
#   'you': 2,
#   'are': 1,
#   'hard': 1,
#   'work': 1,
#   'at': 1,
#   'it': 1,
#   'jonah': 1,
#   'barrington': 1},
#  'What sunshine is to flowers, smiles are to humanity. These are but trifles, to be sure; but scattered along life`s pathway, the good they do is inconceivable. - Joseph Addison': {'what': 1,
#   'sunshine': 1,
#   'is': 2,
#   'to': 3,
#   'flowers': 1,
#   'smiles': 1,
#   'are': 2,
#   'humanity': 1,
#   'these': 1,
#   'but': 2,
#   'trifles': 1,
#   'be': 1,
#   'sure': 1,
#   'scattered': 1,
#   'along': 1,
#   'life`s': 1,
#   'pathway': 1,
#   'the': 1,
#   'good': 1,
#   'they': 1,
#   'do': 1,
#   'inconceivable': 1,
#   'joseph': 1,
#   'addison': 1},
#  'You got to be very careful if you don`t know where you`re going, because you might not get there. - Yogi Berra': {'you': 3,
#   'got': 1,
#   'to': 1,
#   'be': 1,
#   'very': 1,
#   'careful': 1,
#   'if': 1,
#   'don`t': 1,
#   'know': 1,
#   'where': 1,
#   'you`re': 1,
#   'going': 1,
#   'because': 1,
#   'might': 1,
#   'not': 1,
#   'get': 1,
#   'there': 1,
#   'yogi': 1,
#   'berra': 1},
#  'Life is not a support system for art. It`s the other way around. - Stephen King': {'life': 1,
#   'is': 1,
#   'not': 1,
#   'a': 1,
#   'support': 1,
#   'system': 1,
#   'for': 1,
#   'art': 1,
#   'it`s': 1,
#   'the': 1,
#   'other': 1,
#   'way': 1,
#   'around': 1,
#   'stephen': 1,
#   'king': 1},
#  'Love is the delightful interval between meeting a beautiful girl and discovering that she looks like a haddock. - John Barrymore': {'love': 1,
#   'is': 1,
#   'the': 1,
#   'delightful': 1,
#   'interval': 1,
#   'between': 1,
#   'meeting': 1,
#   'a': 2,
#   'beautiful': 1,
#   'girl': 1,
#   'and': 1,
#   'discovering': 1,
#   'that': 1,
#   'she': 1,
#   'looks': 1,
#   'like': 1,
#   'haddock': 1,
#   'john': 1,
#   'barrymore': 1},
#  'The supernatural is the natural not yet understood. - Elbert Hubbard': {'the': 2,
#   'supernatural': 1,
#   'is': 1,
#   'natural': 1,
#   'not': 1,
#   'yet': 1,
#   'understood': 1,
#   'elbert': 1,
#   'hubbard': 1},
#  'Those who forget good and evil and seek only to know the facts are more likely to achieve good than those who view the world through the distorting medium of their own desires. - Bertrand Russell': {'those': 2,
#   'who': 2,
#   'forget': 1,
#   'good': 2,
#   'and': 2,
#   'evil': 1,
#   'seek': 1,
#   'only': 1,
#   'to': 2,
#   'know': 1,
#   'the': 3,
#   'facts': 1,
#   'are': 1,
#   'more': 1,
#   'likely': 1,
#   'achieve': 1,
#   'than': 1,
#   'view': 1,
#   'world': 1,
#   'through': 1,
#   'distorting': 1,
#   'medium': 1,
#   'of': 1,
#   'their': 1,
#   'own': 1,
#   'desires': 1,
#   'bertrand': 1,
#   'russell': 1},
#  'Experience proves this, or that, or nothing, according to the preconceptions we bring to it. - C.S. Lewis': {'experience': 1,
#   'proves': 1,
#   'this': 1,
#   'or': 2,
#   'that': 1,
#   'nothing': 1,
#   'according': 1,
#   'to': 2,
#   'the': 1,
#   'preconceptions': 1,
#   'we': 1,
#   'bring': 1,
#   'it': 1,
#   'c': 1,
#   's': 1,
#   'lewis': 1},
#  'Nothing separates the generations more than music. By the time a child is eight or nine, he has developed a passion for his own music that is even stronger than his passions for procrastination and weird clothes. - Bill Cosby': {'nothing': 1,
#   'separates': 1,
#   'the': 2,
#   'generations': 1,
#   'more': 1,
#   'than': 2,
#   'music': 2,
#   'by': 1,
#   'time': 1,
#   'a': 2,
#   'child': 1,
#   'is': 2,
#   'eight': 1,
#   'or': 1,
#   'nine': 1,
#   'he': 1,
#   'has': 1,
#   'developed': 1,
#   'passion': 1,
#   'for': 2,
#   'his': 2,
#   'own': 1,
#   'that': 1,
#   'even': 1,
#   'stronger': 1,
#   'passions': 1,
#   'procrastination': 1,
#   'and': 1,
#   'weird': 1,
#   'clothes': 1,
#   'bill': 1,
#   'cosby': 1},
#  'The hour of departure has arrived, and we go our ways - I to die, and you to live. Which is better God only knows. - Plato': {'the': 1,
#   'hour': 1,
#   'of': 1,
#   'departure': 1,
#   'has': 1,
#   'arrived': 1,
#   'and': 2,
#   'we': 1,
#   'go': 1,
#   'our': 1,
#   'ways': 1,
#   'i': 1,
#   'to': 2,
#   'die': 1,
#   'you': 1,
#   'live': 1,
#   'which': 1,
#   'is': 1,
#   'better': 1,
#   'god': 1,
#   'only': 1,
#   'knows': 1,
#   'plato': 1},
#  'The statistics on sanity are that one out of every four Americans are suffering from some form of mental illness. Think of your three best friends. If they`re okay, then it`s you. - Rita Mae Brown': {'the': 1,
#   'statistics': 1,
#   'on': 1,
#   'sanity': 1,
#   'are': 2,
#   'that': 1,
#   'one': 1,
#   'out': 1,
#   'of': 3,
#   'every': 1,
#   'four': 1,
#   'americans': 1,
#   'suffering': 1,
#   'from': 1,
#   'some': 1,
#   'form': 1,
#   'mental': 1,
#   'illness': 1,
#   'think': 1,
#   'your': 1,
#   'three': 1,
#   'best': 1,
#   'friends': 1,
#   'if': 1,
#   'they`re': 1,
#   'okay': 1,
#   'then': 1,
#   'it`s': 1,
#   'you': 1,
#   'rita': 1,
#   'mae': 1,
#   'brown': 1},
#  'Nietzsche was stupid and abnormal. - Leo Tolstoy': {'nietzsche': 1,
#   'was': 1,
#   'stupid': 1,
#   'and': 1,
#   'abnormal': 1,
#   'leo': 1,
#   'tolstoy': 1},
#  'Everybody can be great... because anybody can serve. You don`t have to have a college degree to serve. You don`t have to make your subject and verb agree to serve. You only need a heart full of grace. A soul generated by love. - Martin Luther King Jr.': {'everybody': 1,
#   'can': 2,
#   'be': 1,
#   'great': 1,
#   'because': 1,
#   'anybody': 1,
#   'serve': 3,
#   'you': 3,
#   'don`t': 2,
#   'have': 3,
#   'to': 4,
#   'a': 3,
#   'college': 1,
#   'degree': 1,
#   'make': 1,
#   'your': 1,
#   'subject': 1,
#   'and': 1,
#   'verb': 1,
#   'agree': 1,
#   'only': 1,
#   'need': 1,
#   'heart': 1,
#   'full': 1,
#   'of': 1,
#   'grace': 1,
#   'soul': 1,
#   'generated': 1,
#   'by': 1,
#   'love': 1,
#   'martin': 1,
#   'luther': 1,
#   'king': 1,
#   'jr': 1,
#   '': 1},
#  'People have a way of becoming what you encourage them to be, not what you nag them to be. - Author Unknown': {'people': 1,
#   'have': 1,
#   'a': 1,
#   'way': 1,
#   'of': 1,
#   'becoming': 1,
#   'what': 2,
#   'you': 2,
#   'encourage': 1,
#   'them': 2,
#   'to': 2,
#   'be': 2,
#   'not': 1,
#   'nag': 1,
#   'author': 1,
#   'unknown': 1},
#  'All men are frauds. The only difference between them is that some admit it. I myself deny it. - Henry Mencken': {'all': 1,
#   'men': 1,
#   'are': 1,
#   'frauds': 1,
#   'the': 1,
#   'only': 1,
#   'difference': 1,
#   'between': 1,
#   'them': 1,
#   'is': 1,
#   'that': 1,
#   'some': 1,
#   'admit': 1,
#   'it': 2,
#   'i': 1,
#   'myself': 1,
#   'deny': 1,
#   'henry': 1,
#   'mencken': 1},
#  'America is not like a blanket: one piece of unbroken cloth, the same color, the same texture, the same size. America is more like a quilt: many patches, many pieces, many colors, many sizes, all woven and held together by a common thread. - Jesse Jackson': {'america': 2,
#   'is': 2,
#   'not': 1,
#   'like': 2,
#   'a': 3,
#   'blanket': 1,
#   'one': 1,
#   'piece': 1,
#   'of': 1,
#   'unbroken': 1,
#   'cloth': 1,
#   'the': 3,
#   'same': 3,
#   'color': 1,
#   'texture': 1,
#   'size': 1,
#   'more': 1,
#   'quilt': 1,
#   'many': 4,
#   'patches': 1,
#   'pieces': 1,
#   'colors': 1,
#   'sizes': 1,
#   'all': 1,
#   'woven': 1,
#   'and': 1,
#   'held': 1,
#   'together': 1,
#   'by': 1,
#   'common': 1,
#   'thread': 1,
#   'jesse': 1,
#   'jackson': 1},
#  'When nothing seems to help, I go and look at a stonecutter hammering away at his rock perhaps a hundred times without as much as a crack showing in it. Yet at the hundred and first blow it will split in two, and I know it was not that blow that did it, but all that had gone before. - Jacob August Riis': {'when': 1,
#   'nothing': 1,
#   'seems': 1,
#   'to': 1,
#   'help': 1,
#   'i': 2,
#   'go': 1,
#   'and': 3,
#   'look': 1,
#   'at': 3,
#   'a': 3,
#   'stonecutter': 1,
#   'hammering': 1,
#   'away': 1,
#   'his': 1,
#   'rock': 1,
#   'perhaps': 1,
#   'hundred': 2,
#   'times': 1,
#   'without': 1,
#   'as': 2,
#   'much': 1,
#   'crack': 1,
#   'showing': 1,
#   'in': 2,
#   'it': 4,
#   'yet': 1,
#   'the': 1,
#   'first': 1,
#   'blow': 2,
#   'will': 1,
#   'split': 1,
#   'two': 1,
#   'know': 1,
#   'was': 1,
#   'not': 1,
#   'that': 3,
#   'did': 1,
#   'but': 1,
#   'all': 1,
#   'had': 1,
#   'gone': 1,
#   'before': 1,
#   'jacob': 1,
#   'august': 1,
#   'riis': 1},
#  'In any moment of decision, the best thing you can do is the right thing. The worst thing you can do is nothing. - Theodore Roosevelt': {'in': 1,
#   'any': 1,
#   'moment': 1,
#   'of': 1,
#   'decision': 1,
#   'the': 3,
#   'best': 1,
#   'thing': 3,
#   'you': 2,
#   'can': 2,
#   'do': 2,
#   'is': 2,
#   'right': 1,
#   'worst': 1,
#   'nothing': 1,
#   'theodore': 1,
#   'roosevelt': 1},
#  'Self-denial is the shining sore on the leprous body of Christianity. - Oscar Wilde': {'self': 1,
#   'denial': 1,
#   'is': 1,
#   'the': 2,
#   'shining': 1,
#   'sore': 1,
#   'on': 1,
#   'leprous': 1,
#   'body': 1,
#   'of': 1,
#   'christianity': 1,
#   'oscar': 1,
#   'wilde': 1},
#  'I have never been hurt by what I have not said. - Calvin Coolidge': {'i': 2,
#   'have': 2,
#   'never': 1,
#   'been': 1,
#   'hurt': 1,
#   'by': 1,
#   'what': 1,
#   'not': 1,
#   'said': 1,
#   'calvin': 1,
#   'coolidge': 1},
#  'If you judge people, you have no time to love them. - Mother Teresa': {'if': 1,
#   'you': 2,
#   'judge': 1,
#   'people': 1,
#   'have': 1,
#   'no': 1,
#   'time': 1,
#   'to': 1,
#   'love': 1,
#   'them': 1,
#   'mother': 1,
#   'teresa': 1},
#  'The means of defense against foreign danger historically have become the instruments of tyranny at home. - James Madison': {'the': 2,
#   'means': 1,
#   'of': 2,
#   'defense': 1,
#   'against': 1,
#   'foreign': 1,
#   'danger': 1,
#   'historically': 1,
#   'have': 1,
#   'become': 1,
#   'instruments': 1,
#   'tyranny': 1,
#   'at': 1,
#   'home': 1,
#   'james': 1,
#   'madison': 1},
#  'He who is not courageous enough to take risks will accomplish nothing in life. - Muhammad Ali': {'he': 1,
#   'who': 1,
#   'is': 1,
#   'not': 1,
#   'courageous': 1,
#   'enough': 1,
#   'to': 1,
#   'take': 1,
#   'risks': 1,
#   'will': 1,
#   'accomplish': 1,
#   'nothing': 1,
#   'in': 1,
#   'life': 1,
#   'muhammad': 1,
#   'ali': 1},
#  'He that fights and runs away, may turn and fight another day; but he that is in battle slain, will never rise to fight again. - Tacitus': {'he': 2,
#   'that': 2,
#   'fights': 1,
#   'and': 2,
#   'runs': 1,
#   'away': 1,
#   'may': 1,
#   'turn': 1,
#   'fight': 2,
#   'another': 1,
#   'day': 1,
#   'but': 1,
#   'is': 1,
#   'in': 1,
#   'battle': 1,
#   'slain': 1,
#   'will': 1,
#   'never': 1,
#   'rise': 1,
#   'to': 1,
#   'again': 1,
#   'tacitus': 1},
#  'America did not invent human rights. In a very real sense...human rights invented America. - Jimmy Carter': {'america': 2,
#   'did': 1,
#   'not': 1,
#   'invent': 1,
#   'human': 2,
#   'rights': 2,
#   'in': 1,
#   'a': 1,
#   'very': 1,
#   'real': 1,
#   'sense': 1,
#   'invented': 1,
#   'jimmy': 1,
#   'carter': 1},
#  'No matter how much cats fight, there always seem to be plenty of kittens. - Abraham Lincoln': {'no': 1,
#   'matter': 1,
#   'how': 1,
#   'much': 1,
#   'cats': 1,
#   'fight': 1,
#   'there': 1,
#   'always': 1,
#   'seem': 1,
#   'to': 1,
#   'be': 1,
#   'plenty': 1,
#   'of': 1,
#   'kittens': 1,
#   'abraham': 1,
#   'lincoln': 1},
#  'Success, the real success, does not depend upon the position you hold but upon how you carry yourself in that position. - Theodore Roosevelt': {'success': 2,
#   'the': 2,
#   'real': 1,
#   'does': 1,
#   'not': 1,
#   'depend': 1,
#   'upon': 2,
#   'position': 2,
#   'you': 2,
#   'hold': 1,
#   'but': 1,
#   'how': 1,
#   'carry': 1,
#   'yourself': 1,
#   'in': 1,
#   'that': 1,
#   'theodore': 1,
#   'roosevelt': 1},
#  'Happiness makes up in height for what it lacks in length. - Robert Frost': {'happiness': 1,
#   'makes': 1,
#   'up': 1,
#   'in': 2,
#   'height': 1,
#   'for': 1,
#   'what': 1,
#   'it': 1,
#   'lacks': 1,
#   'length': 1,
#   'robert': 1,
#   'frost': 1},
#  'Poetry is the art of creating imaginary gardens with real toads. - Marianne Moore': {'poetry': 1,
#   'is': 1,
#   'the': 1,
#   'art': 1,
#   'of': 1,
#   'creating': 1,
#   'imaginary': 1,
#   'gardens': 1,
#   'with': 1,
#   'real': 1,
#   'toads': 1,
#   'marianne': 1,
#   'moore': 1},
#  'It is by the goodness of God that, in this country, we have three benefits: freedom of speech, freedom of thought, and the wisdom never to use either. - Mark Twain': {'it': 1,
#   'is': 1,
#   'by': 1,
#   'the': 2,
#   'goodness': 1,
#   'of': 3,
#   'god': 1,
#   'that': 1,
#   'in': 1,
#   'this': 1,
#   'country': 1,
#   'we': 1,
#   'have': 1,
#   'three': 1,
#   'benefits': 1,
#   'freedom': 2,
#   'speech': 1,
#   'thought': 1,
#   'and': 1,
#   'wisdom': 1,
#   'never': 1,
#   'to': 1,
#   'use': 1,
#   'either': 1,
#   'mark': 1,
#   'twain': 1},
#  'The Bible is not my book, and Christianity is not my religion. I could never give assent to the long, complicated statements of Christian dogma. - Abraham Lincoln': {'the': 2,
#   'bible': 1,
#   'is': 2,
#   'not': 2,
#   'my': 2,
#   'book': 1,
#   'and': 1,
#   'christianity': 1,
#   'religion': 1,
#   'i': 1,
#   'could': 1,
#   'never': 1,
#   'give': 1,
#   'assent': 1,
#   'to': 1,
#   'long': 1,
#   'complicated': 1,
#   'statements': 1,
#   'of': 1,
#   'christian': 1,
#   'dogma': 1,
#   'abraham': 1,
#   'lincoln': 1},
#  'He wrapped himself in quotations--as a beggar would enfold himself in the purple of Emperors. - Rudyard Kipling': {'he': 1,
#   'wrapped': 1,
#   'himself': 2,
#   'in': 2,
#   'quotations': 1,
#   'as': 1,
#   'a': 1,
#   'beggar': 1,
#   'would': 1,
#   'enfold': 1,
#   'the': 1,
#   'purple': 1,
#   'of': 1,
#   'emperors': 1,
#   'rudyard': 1,
#   'kipling': 1},
#  'The truth is always a trick to those who live among lies. - Author Unknown': {'the': 1,
#   'truth': 1,
#   'is': 1,
#   'always': 1,
#   'a': 1,
#   'trick': 1,
#   'to': 1,
#   'those': 1,
#   'who': 1,
#   'live': 1,
#   'among': 1,
#   'lies': 1,
#   'author': 1,
#   'unknown': 1},
#  'What you do speaks so loudly that I cannot hear what you say. - Ralph Waldo Emerson': {'what': 2,
#   'you': 2,
#   'do': 1,
#   'speaks': 1,
#   'so': 1,
#   'loudly': 1,
#   'that': 1,
#   'i': 1,
#   'cannot': 1,
#   'hear': 1,
#   'say': 1,
#   'ralph': 1,
#   'waldo': 1,
#   'emerson': 1},
#  'All glory is fleeting. - George Patton': {'all': 1,
#   'glory': 1,
#   'is': 1,
#   'fleeting': 1,
#   'george': 1,
#   'patton': 1},
#  'No distance of place or lapse of time can lessen the friendship of those who are thoroughly persuaded of each other`s worth. - Robert Southey': {'no': 1,
#   'distance': 1,
#   'of': 4,
#   'place': 1,
#   'or': 1,
#   'lapse': 1,
#   'time': 1,
#   'can': 1,
#   'lessen': 1,
#   'the': 1,
#   'friendship': 1,
#   'those': 1,
#   'who': 1,
#   'are': 1,
#   'thoroughly': 1,
#   'persuaded': 1,
#   'each': 1,
#   'other`s': 1,
#   'worth': 1,
#   'robert': 1,
#   'southey': 1},
#  'Washington is a city of Southern efficiency and Northern charm. - John F. Kennedy': {'washington': 1,
#   'is': 1,
#   'a': 1,
#   'city': 1,
#   'of': 1,
#   'southern': 1,
#   'efficiency': 1,
#   'and': 1,
#   'northern': 1,
#   'charm': 1,
#   'john': 1,
#   'f': 1,
#   'kennedy': 1},
#  'If you`re in a boxing match, try not to let the other guy`s glove touch your lips, because you don`t know where that glove has been. - Jack Handey': {'if': 1,
#   'you`re': 1,
#   'in': 1,
#   'a': 1,
#   'boxing': 1,
#   'match': 1,
#   'try': 1,
#   'not': 1,
#   'to': 1,
#   'let': 1,
#   'the': 1,
#   'other': 1,
#   'guy`s': 1,
#   'glove': 2,
#   'touch': 1,
#   'your': 1,
#   'lips': 1,
#   'because': 1,
#   'you': 1,
#   'don`t': 1,
#   'know': 1,
#   'where': 1,
#   'that': 1,
#   'has': 1,
#   'been': 1,
#   'jack': 1,
#   'handey': 1},
#  'Never discourage anyone who continually makes progress, no matter how slow. - Plato': {'never': 1,
#   'discourage': 1,
#   'anyone': 1,
#   'who': 1,
#   'continually': 1,
#   'makes': 1,
#   'progress': 1,
#   'no': 1,
#   'matter': 1,
#   'how': 1,
#   'slow': 1,
#   'plato': 1},
#  'Not only is there no God, but try finding a plumber on Sunday. - Woody Allen': {'not': 1,
#   'only': 1,
#   'is': 1,
#   'there': 1,
#   'no': 1,
#   'god': 1,
#   'but': 1,
#   'try': 1,
#   'finding': 1,
#   'a': 1,
#   'plumber': 1,
#   'on': 1,
#   'sunday': 1,
#   'woody': 1,
#   'allen': 1},
#  'Rome remained free for four hundred years and Sparta eight hundred, although their citizens were armed all that time; but many other states that have been disarmed have lost their liberties in less than forty years. - Nicolo Machiavelli': {'rome': 1,
#   'remained': 1,
#   'free': 1,
#   'for': 1,
#   'four': 1,
#   'hundred': 2,
#   'years': 2,
#   'and': 1,
#   'sparta': 1,
#   'eight': 1,
#   'although': 1,
#   'their': 2,
#   'citizens': 1,
#   'were': 1,
#   'armed': 1,
#   'all': 1,
#   'that': 2,
#   'time': 1,
#   'but': 1,
#   'many': 1,
#   'other': 1,
#   'states': 1,
#   'have': 2,
#   'been': 1,
#   'disarmed': 1,
#   'lost': 1,
#   'liberties': 1,
#   'in': 1,
#   'less': 1,
#   'than': 1,
#   'forty': 1,
#   'nicolo': 1,
#   'machiavelli': 1},
#  'Science without religion is lame, religion without science is blind. - Albert Einstein': {'science': 2,
#   'without': 2,
#   'religion': 2,
#   'is': 2,
#   'lame': 1,
#   'blind': 1,
#   'albert': 1,
#   'einstein': 1},
#  'Knowledge rests not upon truth alone, but upon error also. - Carl Jung': {'knowledge': 1,
#   'rests': 1,
#   'not': 1,
#   'upon': 2,
#   'truth': 1,
#   'alone': 1,
#   'but': 1,
#   'error': 1,
#   'also': 1,
#   'carl': 1,
#   'jung': 1},
#  'In politics shared hatreds are almost always the basis of friendships. - Alexis de Tocqueville': {'in': 1,
#   'politics': 1,
#   'shared': 1,
#   'hatreds': 1,
#   'are': 1,
#   'almost': 1,
#   'always': 1,
#   'the': 1,
#   'basis': 1,
#   'of': 1,
#   'friendships': 1,
#   'alexis': 1,
#   'de': 1,
#   'tocqueville': 1},
#  'Genius may have its limitations, but stupidity is not thus handicapped. - Elbert Hubbard': {'genius': 1,
#   'may': 1,
#   'have': 1,
#   'its': 1,
#   'limitations': 1,
#   'but': 1,
#   'stupidity': 1,
#   'is': 1,
#   'not': 1,
#   'thus': 1,
#   'handicapped': 1,
#   'elbert': 1,
#   'hubbard': 1},
#  'In life, as in art, the beautiful moves in curves. - Edward Bulwer-Lytton': {'in': 3,
#   'life': 1,
#   'as': 1,
#   'art': 1,
#   'the': 1,
#   'beautiful': 1,
#   'moves': 1,
#   'curves': 1,
#   'edward': 1,
#   'bulwer': 1,
#   'lytton': 1},
#  'I planted some bird seed. A bird came up. Now I don`t know what to feed it. - Steven Wright': {'i': 2,
#   'planted': 1,
#   'some': 1,
#   'bird': 2,
#   'seed': 1,
#   'a': 1,
#   'came': 1,
#   'up': 1,
#   'now': 1,
#   'don`t': 1,
#   'know': 1,
#   'what': 1,
#   'to': 1,
#   'feed': 1,
#   'it': 1,
#   'steven': 1,
#   'wright': 1},
#  'Not everybody trusts paintings, but people believe photographs. - Ansel Adams': {'not': 1,
#   'everybody': 1,
#   'trusts': 1,
#   'paintings': 1,
#   'but': 1,
#   'people': 1,
#   'believe': 1,
#   'photographs': 1,
#   'ansel': 1,
#   'adams': 1},
#  'The things that will destroy America are prosperity at any price, peace at any price, safety first instead of duty first, the love of soft living and the get rich quick theory of life. - Theodore Roosevelt': {'the': 3,
#   'things': 1,
#   'that': 1,
#   'will': 1,
#   'destroy': 1,
#   'america': 1,
#   'are': 1,
#   'prosperity': 1,
#   'at': 2,
#   'any': 2,
#   'price': 2,
#   'peace': 1,
#   'safety': 1,
#   'first': 2,
#   'instead': 1,
#   'of': 3,
#   'duty': 1,
#   'love': 1,
#   'soft': 1,
#   'living': 1,
#   'and': 1,
#   'get': 1,
#   'rich': 1,
#   'quick': 1,
#   'theory': 1,
#   'life': 1,
#   'theodore': 1,
#   'roosevelt': 1},
#  'There are people who put their dreams in a little box and say, Yes, I`ve got dreams, of course I`ve got dreams. Then they put the box away and bring it out once in awhile to look in it, and yep, they`re still there. - Erna Bombeck': {'there': 2,
#   'are': 1,
#   'people': 1,
#   'who': 1,
#   'put': 2,
#   'their': 1,
#   'dreams': 3,
#   'in': 3,
#   'a': 1,
#   'little': 1,
#   'box': 2,
#   'and': 3,
#   'say': 1,
#   'yes': 1,
#   'i`ve': 2,
#   'got': 2,
#   'of': 1,
#   'course': 1,
#   'then': 1,
#   'they': 1,
#   'the': 1,
#   'away': 1,
#   'bring': 1,
#   'it': 2,
#   'out': 1,
#   'once': 1,
#   'awhile': 1,
#   'to': 1,
#   'look': 1,
#   'yep': 1,
#   'they`re': 1,
#   'still': 1,
#   'erna': 1,
#   'bombeck': 1},
#  'Knowledge comes, but wisdom lingers. - Calvin Coolidge': {'knowledge': 1,
#   'comes': 1,
#   'but': 1,
#   'wisdom': 1,
#   'lingers': 1,
#   'calvin': 1,
#   'coolidge': 1},
#  'Men are born ignorant, not stupid; they are made stupid by education. - Bertrand Russell': {'men': 1,
#   'are': 2,
#   'born': 1,
#   'ignorant': 1,
#   'not': 1,
#   'stupid': 2,
#   'they': 1,
#   'made': 1,
#   'by': 1,
#   'education': 1,
#   'bertrand': 1,
#   'russell': 1},
#  'If we do not help a man in trouble, it is as if we caused the trouble. - Nachman of Bratslav': {'if': 2,
#   'we': 2,
#   'do': 1,
#   'not': 1,
#   'help': 1,
#   'a': 1,
#   'man': 1,
#   'in': 1,
#   'trouble': 2,
#   'it': 1,
#   'is': 1,
#   'as': 1,
#   'caused': 1,
#   'the': 1,
#   'nachman': 1,
#   'of': 1,
#   'bratslav': 1},
#  'Patience is the companion of wisdom. - Saint Augustine': {'patience': 1,
#   'is': 1,
#   'the': 1,
#   'companion': 1,
#   'of': 1,
#   'wisdom': 1,
#   'saint': 1,
#   'augustine': 1},
#  'Marriage is our last, best chance to grow up. - Joseph Barth': {'marriage': 1,
#   'is': 1,
#   'our': 1,
#   'last': 1,
#   'best': 1,
#   'chance': 1,
#   'to': 1,
#   'grow': 1,
#   'up': 1,
#   'joseph': 1,
#   'barth': 1},
#  'Patriotism is not short, frenzied outbursts of emotion, but the tranquil and steady dedication of a lifetime. - Adlai Stevenson': {'patriotism': 1,
#   'is': 1,
#   'not': 1,
#   'short': 1,
#   'frenzied': 1,
#   'outbursts': 1,
#   'of': 2,
#   'emotion': 1,
#   'but': 1,
#   'the': 1,
#   'tranquil': 1,
#   'and': 1,
#   'steady': 1,
#   'dedication': 1,
#   'a': 1,
#   'lifetime': 1,
#   'adlai': 1,
#   'stevenson': 1},
#  'A man`s very highest moment is, I have no doubt at all, when he kneels in the dust, and beats his breast, and tells all the sins of his life. - Oscar Wilde': {'a': 1,
#   'man`s': 1,
#   'very': 1,
#   'highest': 1,
#   'moment': 1,
#   'is': 1,
#   'i': 1,
#   'have': 1,
#   'no': 1,
#   'doubt': 1,
#   'at': 1,
#   'all': 2,
#   'when': 1,
#   'he': 1,
#   'kneels': 1,
#   'in': 1,
#   'the': 2,
#   'dust': 1,
#   'and': 2,
#   'beats': 1,
#   'his': 2,
#   'breast': 1,
#   'tells': 1,
#   'sins': 1,
#   'of': 1,
#   'life': 1,
#   'oscar': 1,
#   'wilde': 1},
#  'Associate yourself with men of good quality if you esteem your own reputation; for `tis better to be alone than in bad company. - George Washington': {'associate': 1,
#   'yourself': 1,
#   'with': 1,
#   'men': 1,
#   'of': 1,
#   'good': 1,
#   'quality': 1,
#   'if': 1,
#   'you': 1,
#   'esteem': 1,
#   'your': 1,
#   'own': 1,
#   'reputation': 1,
#   'for': 1,
#   '`tis': 1,
#   'better': 1,
#   'to': 1,
#   'be': 1,
#   'alone': 1,
#   'than': 1,
#   'in': 1,
#   'bad': 1,
#   'company': 1,
#   'george': 1,
#   'washington': 1},
#  'Beauty is all very well at first sight; but whoever looks at it when it has been in the house three days? - George Bernard Shaw': {'beauty': 1,
#   'is': 1,
#   'all': 1,
#   'very': 1,
#   'well': 1,
#   'at': 2,
#   'first': 1,
#   'sight': 1,
#   'but': 1,
#   'whoever': 1,
#   'looks': 1,
#   'it': 2,
#   'when': 1,
#   'has': 1,
#   'been': 1,
#   'in': 1,
#   'the': 1,
#   'house': 1,
#   'three': 1,
#   'days': 1,
#   'george': 1,
#   'bernard': 1,
#   'shaw': 1},
#  'I had a dream the other night. I dreamed that Jimmy Carter came to me and asked why I wanted his job. I told him I didn`t want his job. I want to be President. - Ronald Reagan': {'i': 6,
#   'had': 1,
#   'a': 1,
#   'dream': 1,
#   'the': 1,
#   'other': 1,
#   'night': 1,
#   'dreamed': 1,
#   'that': 1,
#   'jimmy': 1,
#   'carter': 1,
#   'came': 1,
#   'to': 2,
#   'me': 1,
#   'and': 1,
#   'asked': 1,
#   'why': 1,
#   'wanted': 1,
#   'his': 2,
#   'job': 2,
#   'told': 1,
#   'him': 1,
#   'didn`t': 1,
#   'want': 2,
#   'be': 1,
#   'president': 1,
#   'ronald': 1,
#   'reagan': 1},
#  'To assert that the earth revolves around the sun is as erroneous as to claim that Jesus was not born of a virgin. - Cardinal Bellarmine': {'to': 2,
#   'assert': 1,
#   'that': 2,
#   'the': 2,
#   'earth': 1,
#   'revolves': 1,
# ...
#   'just': 1,
#   'begins': 1,
#   'to': 1,
#   'live': 1,
#   'that': 1,
#   'day': 1,
#   'emily': 1,
#   'dickinson': 1},
#  'You cannot go on `explaining away` for ever: you will find that you have explained explanation itself away. You cannot go on `seeing through` things for ever. The whole point of seeing through something is to see something through it. - C.S. Lewis': {'you': 4,
#   'cannot': 2,
#   'go': 2,
#   'on': 2,
#   '`explaining': 1,
#   'away`': 1,
#   'for': 2,
#   'ever': 2,
#   'will': 1,
#   'find': 1,
#   'that': 1,
#   'have': 1,
#   'explained': 1,
#   'explanation': 1,
#   'itself': 1,
#   'away': 1,
#   '`seeing': 1,
#   'through`': 1,
#   'things': 1,
#   'the': 1,
#   'whole': 1,
#   'point': 1,
#   'of': 1,
#   'seeing': 1,
#   'through': 2,
#   'something': 2,
#   'is': 1,
#   'to': 1,
#   'see': 1,
#   'it': 1,
#   'c': 1,
#   's': 1,
#   'lewis': 1},
#  'The invisible and the non-existent look very much alike. - Delos McKown': {'the': 2,
#   'invisible': 1,
#   'and': 1,
#   'non': 1,
#   'existent': 1,
#   'look': 1,
#   'very': 1,
#   'much': 1,
#   'alike': 1,
#   'delos': 1,
#   'mckown': 1},
#  'To you taxpayers out there, let me say this: Make sure you file your tax return on time! And remember that, even though income taxes can be a “pain in the neck,” the folks at the IRS are regular people just like you, except that they can destroy your life. - Dave Barry': {'to': 1,
#   'you': 3,
#   'taxpayers': 1,
#   'out': 1,
#   'there': 1,
#   'let': 1,
#   'me': 1,
#   'say': 1,
#   'this': 1,
#   'make': 1,
#   'sure': 1,
#   'file': 1,
#   'your': 2,
#   'tax': 1,
#   'return': 1,
#   'on': 1,
#   'time': 1,
#   'and': 1,
#   'remember': 1,
#   'that': 2,
#   'even': 1,
#   'though': 1,
#   'income': 1,
#   'taxes': 1,
#   'can': 2,
#   'be': 1,
#   'a': 1,
#   'pain': 1,
#   'in': 1,
#   'the': 3,
#   'neck': 1,
#   'folks': 1,
#   'at': 1,
#   'irs': 1,
#   'are': 1,
#   'regular': 1,
#   'people': 1,
#   'just': 1,
#   'like': 1,
#   'except': 1,
#   'they': 1,
#   'destroy': 1,
#   'life': 1,
#   'dave': 1,
#   'barry': 1},
#  'We do survive every moment, after all, except the last one. - John Updike': {'we': 1,
#   'do': 1,
#   'survive': 1,
#   'every': 1,
#   'moment': 1,
#   'after': 1,
#   'all': 1,
#   'except': 1,
#   'the': 1,
#   'last': 1,
#   'one': 1,
#   'john': 1,
#   'updike': 1},
#  'Andy Warhol made fame more famous. - Fran Lebowitz': {'andy': 1,
#   'warhol': 1,
#   'made': 1,
#   'fame': 1,
#   'more': 1,
#   'famous': 1,
#   'fran': 1,
#   'lebowitz': 1},
#  'It is the dissimilarities and inequalities among men which give rise to the notion of honor; as such differences become less, it grows feeble; and when they disappear, it will vanish too. - Alexis de Tocqueville': {'it': 3,
#   'is': 1,
#   'the': 2,
#   'dissimilarities': 1,
#   'and': 2,
#   'inequalities': 1,
#   'among': 1,
#   'men': 1,
#   'which': 1,
#   'give': 1,
#   'rise': 1,
#   'to': 1,
#   'notion': 1,
#   'of': 1,
#   'honor': 1,
#   'as': 1,
#   'such': 1,
#   'differences': 1,
#   'become': 1,
#   'less': 1,
#   'grows': 1,
#   'feeble': 1,
#   'when': 1,
#   'they': 1,
#   'disappear': 1,
#   'will': 1,
#   'vanish': 1,
#   'too': 1,
#   'alexis': 1,
#   'de': 1,
#   'tocqueville': 1},
#  'Time is a great teacher, but unfortunately it kills all its pupils. - Louis Hector Berlioz': {'time': 1,
#   'is': 1,
#   'a': 1,
#   'great': 1,
#   'teacher': 1,
#   'but': 1,
#   'unfortunately': 1,
#   'it': 1,
#   'kills': 1,
#   'all': 1,
#   'its': 1,
#   'pupils': 1,
#   'louis': 1,
#   'hector': 1,
#   'berlioz': 1},
#  'To be prepared for war is one of the most effectual means of preserving peace. - George Washington': {'to': 1,
#   'be': 1,
#   'prepared': 1,
#   'for': 1,
#   'war': 1,
#   'is': 1,
#   'one': 1,
#   'of': 2,
#   'the': 1,
#   'most': 1,
#   'effectual': 1,
#   'means': 1,
#   'preserving': 1,
#   'peace': 1,
#   'george': 1,
#   'washington': 1},
#  'What is it that makes a complete stranger dive into an icy river to save a solid-gold baby? Maybe we`ll never know. - Jack Handey': {'what': 1,
#   'is': 1,
#   'it': 1,
#   'that': 1,
#   'makes': 1,
#   'a': 2,
#   'complete': 1,
#   'stranger': 1,
#   'dive': 1,
#   'into': 1,
#   'an': 1,
#   'icy': 1,
#   'river': 1,
#   'to': 1,
#   'save': 1,
#   'solid': 1,
#   'gold': 1,
#   'baby': 1,
#   'maybe': 1,
#   'we`ll': 1,
#   'never': 1,
#   'know': 1,
#   'jack': 1,
#   'handey': 1},
#  'All children are artists. The problem is how to remain an artist once he grows up. - Pablo Picasso': {'all': 1,
#   'children': 1,
#   'are': 1,
#   'artists': 1,
#   'the': 1,
#   'problem': 1,
#   'is': 1,
#   'how': 1,
#   'to': 1,
#   'remain': 1,
#   'an': 1,
#   'artist': 1,
#   'once': 1,
#   'he': 1,
#   'grows': 1,
#   'up': 1,
#   'pablo': 1,
#   'picasso': 1},
#  '“Take a chance! All life is a chance. The man who goes farthest is generally the one who is willing to do and dare. - Dale Carnegie': {'': 1,
#   'take': 1,
#   'a': 2,
#   'chance': 2,
#   'all': 1,
#   'life': 1,
#   'is': 3,
#   'the': 2,
#   'man': 1,
#   'who': 2,
#   'goes': 1,
#   'farthest': 1,
#   'generally': 1,
#   'one': 1,
#   'willing': 1,
#   'to': 1,
#   'do': 1,
#   'and': 1,
#   'dare': 1,
#   'dale': 1,
#   'carnegie': 1},
#  'Time makes more converts than reason. - Thomas Paine': {'time': 1,
#   'makes': 1,
#   'more': 1,
#   'converts': 1,
#   'than': 1,
#   'reason': 1,
#   'thomas': 1,
#   'paine': 1},
#  'Painting is just another way of keeping a diary. - Pablo Picasso': {'painting': 1,
#   'is': 1,
#   'just': 1,
#   'another': 1,
#   'way': 1,
#   'of': 1,
#   'keeping': 1,
#   'a': 1,
#   'diary': 1,
#   'pablo': 1,
#   'picasso': 1},
#  'Anyone who has never made a mistake has never tried anything new. - Albert Einstein': {'anyone': 1,
#   'who': 1,
#   'has': 2,
#   'never': 2,
#   'made': 1,
#   'a': 1,
#   'mistake': 1,
#   'tried': 1,
#   'anything': 1,
#   'new': 1,
#   'albert': 1,
#   'einstein': 1},
#  'Sacred cows make the best hamburger. - Mark Twain': {'sacred': 1,
#   'cows': 1,
#   'make': 1,
#   'the': 1,
#   'best': 1,
#   'hamburger': 1,
#   'mark': 1,
#   'twain': 1},
#  'We have to make America the best place in the world to do business. - Dick Cheney': {'we': 1,
#   'have': 1,
#   'to': 2,
#   'make': 1,
#   'america': 1,
#   'the': 2,
#   'best': 1,
#   'place': 1,
#   'in': 1,
#   'world': 1,
#   'do': 1,
#   'business': 1,
#   'dick': 1,
#   'cheney': 1},
#  'Love yourself first and everything else falls into line. You really have to love yourself to get anything done in this world. - Lucille Ball': {'love': 2,
#   'yourself': 2,
#   'first': 1,
#   'and': 1,
#   'everything': 1,
#   'else': 1,
#   'falls': 1,
#   'into': 1,
#   'line': 1,
#   'you': 1,
#   'really': 1,
#   'have': 1,
#   'to': 2,
#   'get': 1,
#   'anything': 1,
#   'done': 1,
#   'in': 1,
#   'this': 1,
#   'world': 1,
#   'lucille': 1,
#   'ball': 1},
#  'As Mankind becomes more liberal, they will be more apt to allow that all those who conduct themselves as worthy members of the community are equally entitled to the protections of civil government. I hope ever to see America among the foremost nations of justice and liberality. - George Washington': {'as': 2,
#   'mankind': 1,
#   'becomes': 1,
#   'more': 2,
#   'liberal': 1,
#   'they': 1,
#   'will': 1,
#   'be': 1,
#   'apt': 1,
#   'to': 3,
#   'allow': 1,
#   'that': 1,
#   'all': 1,
#   'those': 1,
#   'who': 1,
#   'conduct': 1,
#   'themselves': 1,
#   'worthy': 1,
#   'members': 1,
#   'of': 3,
#   'the': 3,
#   'community': 1,
#   'are': 1,
#   'equally': 1,
#   'entitled': 1,
#   'protections': 1,
#   'civil': 1,
#   'government': 1,
#   'i': 1,
#   'hope': 1,
#   'ever': 1,
#   'see': 1,
#   'america': 1,
#   'among': 1,
#   'foremost': 1,
#   'nations': 1,
#   'justice': 1,
#   'and': 1,
#   'liberality': 1,
#   'george': 1,
#   'washington': 1},
#  'Many who seem to be struggling with adversity are happy; many, amid great affluence, are utterly miserable. - Tacitus': {'many': 2,
#   'who': 1,
#   'seem': 1,
#   'to': 1,
#   'be': 1,
#   'struggling': 1,
#   'with': 1,
#   'adversity': 1,
#   'are': 2,
#   'happy': 1,
#   'amid': 1,
#   'great': 1,
#   'affluence': 1,
#   'utterly': 1,
#   'miserable': 1,
#   'tacitus': 1},
#  'I wake each morning torn between the desire to improve the world and the desire to enjoy it. It makes it hard to plan the day. - E.B. White': {'i': 1,
#   'wake': 1,
#   'each': 1,
#   'morning': 1,
#   'torn': 1,
#   'between': 1,
#   'the': 4,
#   'desire': 2,
#   'to': 3,
#   'improve': 1,
#   'world': 1,
#   'and': 1,
#   'enjoy': 1,
#   'it': 3,
#   'makes': 1,
#   'hard': 1,
#   'plan': 1,
#   'day': 1,
#   'e': 1,
#   'b': 1,
#   'white': 1},
#  'Worry is interest paid on trouble before it falls due. - W. R. Inge': {'worry': 1,
#   'is': 1,
#   'interest': 1,
#   'paid': 1,
#   'on': 1,
#   'trouble': 1,
#   'before': 1,
#   'it': 1,
#   'falls': 1,
#   'due': 1,
#   'w': 1,
#   'r': 1,
#   'inge': 1},
#  'Games lubricate the body and the mind. - Benjamin Franklin': {'games': 1,
#   'lubricate': 1,
#   'the': 2,
#   'body': 1,
#   'and': 1,
#   'mind': 1,
#   'benjamin': 1,
#   'franklin': 1},
#  'The surface of American society is covered with a layer of democratic paint, but from time to time one can see the old aristocratic colours breaking through. - Alexis de Tocqueville': {'the': 2,
#   'surface': 1,
#   'of': 2,
#   'american': 1,
#   'society': 1,
#   'is': 1,
#   'covered': 1,
#   'with': 1,
#   'a': 1,
#   'layer': 1,
#   'democratic': 1,
#   'paint': 1,
#   'but': 1,
#   'from': 1,
#   'time': 2,
#   'to': 1,
#   'one': 1,
#   'can': 1,
#   'see': 1,
#   'old': 1,
#   'aristocratic': 1,
#   'colours': 1,
#   'breaking': 1,
#   'through': 1,
#   'alexis': 1,
#   'de': 1,
#   'tocqueville': 1},
#  'The commonest thing is delightful if only one hides it. - Oscar Wilde': {'the': 1,
#   'commonest': 1,
#   'thing': 1,
#   'is': 1,
#   'delightful': 1,
#   'if': 1,
#   'only': 1,
#   'one': 1,
#   'hides': 1,
#   'it': 1,
#   'oscar': 1,
#   'wilde': 1},
#  'That is the true season of love, when we believe that we alone can love, that no one could ever have loved so before us, and that no one will love in the same way after us. - Johann Wolfgang von Goethe': {'that': 4,
#   'is': 1,
#   'the': 2,
#   'true': 1,
#   'season': 1,
#   'of': 1,
#   'love': 3,
#   'when': 1,
#   'we': 2,
#   'believe': 1,
#   'alone': 1,
#   'can': 1,
#   'no': 2,
#   'one': 2,
#   'could': 1,
#   'ever': 1,
#   'have': 1,
#   'loved': 1,
#   'so': 1,
#   'before': 1,
#   'us': 2,
#   'and': 1,
#   'will': 1,
#   'in': 1,
#   'same': 1,
#   'way': 1,
#   'after': 1,
#   'johann': 1,
#   'wolfgang': 1,
#   'von': 1,
#   'goethe': 1},
#  'I`ve been accused of vulgarity. I say that`s bullshit. - Mel Brooks': {'i`ve': 1,
#   'been': 1,
#   'accused': 1,
#   'of': 1,
#   'vulgarity': 1,
#   'i': 1,
#   'say': 1,
#   'that`s': 1,
#   'bullshit': 1,
#   'mel': 1,
#   'brooks': 1},
#  'Journalism is literature in a hurry. - Matthew Arnold': {'journalism': 1,
#   'is': 1,
#   'literature': 1,
#   'in': 1,
#   'a': 1,
#   'hurry': 1,
#   'matthew': 1,
#   'arnold': 1},
#  'Man [has] always assumed that he was more intelligent than dolphins because he had achieved so much-the wheel, New York, wars and so on-while all the dolphins had ever done was muck about in the water having a good time. But conversely, the dolphins had always believed that they were far more intelligent than man-for precisely the same reason. - Douglas Adams': {'man': 2,
#   'has': 1,
#   'always': 2,
#   'assumed': 1,
#   'that': 2,
#   'he': 2,
#   'was': 2,
#   'more': 2,
#   'intelligent': 2,
#   'than': 2,
#   'dolphins': 3,
#   'because': 1,
#   'had': 3,
#   'achieved': 1,
#   'so': 2,
#   'much': 1,
#   'the': 5,
#   'wheel': 1,
#   'new': 1,
#   'york': 1,
#   'wars': 1,
#   'and': 1,
#   'on': 1,
#   'while': 1,
#   'all': 1,
#   'ever': 1,
#   'done': 1,
#   'muck': 1,
#   'about': 1,
#   'in': 1,
#   'water': 1,
#   'having': 1,
#   'a': 1,
#   'good': 1,
#   'time': 1,
#   'but': 1,
#   'conversely': 1,
#   'believed': 1,
#   'they': 1,
#   'were': 1,
#   'far': 1,
#   'for': 1,
#   'precisely': 1,
#   'same': 1,
#   'reason': 1,
#   'douglas': 1,
#   'adams': 1},
#  'You can`t teach an old dogma new tricks. - Dorothy Parker': {'you': 1,
#   'can`t': 1,
#   'teach': 1,
#   'an': 1,
#   'old': 1,
#   'dogma': 1,
#   'new': 1,
#   'tricks': 1,
#   'dorothy': 1,
#   'parker': 1},
#  'If you will not fight for the right when you can easily win without bloodshed; if you will not fight when your victory will be sure and not too costly; you may come to the moment when you will have to fight with all the odds against you and only a small chance of survival. There may even be a worse case: you may have to fight when there is no hope of victory, because it is better to perish than to live as slaves. - Winston Churchill': {'if': 2,
#   'you': 7,
#   'will': 4,
#   'not': 3,
#   'fight': 4,
#   'for': 1,
#   'the': 3,
#   'right': 1,
#   'when': 4,
#   'can': 1,
#   'easily': 1,
#   'win': 1,
#   'without': 1,
#   'bloodshed': 1,
#   'your': 1,
#   'victory': 2,
#   'be': 2,
#   'sure': 1,
#   'and': 2,
#   'too': 1,
#   'costly': 1,
#   'may': 3,
#   'come': 1,
#   'to': 5,
#   'moment': 1,
#   'have': 2,
#   'with': 1,
#   'all': 1,
#   'odds': 1,
#   'against': 1,
#   'only': 1,
#   'a': 2,
#   'small': 1,
#   'chance': 1,
#   'of': 2,
#   'survival': 1,
#   'there': 2,
#   'even': 1,
#   'worse': 1,
#   'case': 1,
#   'is': 2,
#   'no': 1,
#   'hope': 1,
#   'because': 1,
#   'it': 1,
#   'better': 1,
#   'perish': 1,
#   'than': 1,
#   'live': 1,
#   'as': 1,
#   'slaves': 1,
#   'winston': 1,
#   'churchill': 1},
#  'The best defense against usurpatory government is an assertive citizenry. - William F. Buckley': {'the': 1,
#   'best': 1,
#   'defense': 1,
#   'against': 1,
#   'usurpatory': 1,
#   'government': 1,
#   'is': 1,
#   'an': 1,
#   'assertive': 1,
#   'citizenry': 1,
#   'william': 1,
#   'f': 1,
#   'buckley': 1},
#  'Cowards die many times before their deaths. The valiant never taste of death but once. - William Shakespeare': {'cowards': 1,
#   'die': 1,
#   'many': 1,
#   'times': 1,
#   'before': 1,
#   'their': 1,
#   'deaths': 1,
#   'the': 1,
#   'valiant': 1,
#   'never': 1,
#   'taste': 1,
#   'of': 1,
#   'death': 1,
#   'but': 1,
#   'once': 1,
#   'william': 1,
#   'shakespeare': 1},
#  'It is astonishing what an effort it seems to be for many people to put their brains definitely and systematically to work. - Thomas Edison': {'it': 2,
#   'is': 1,
#   'astonishing': 1,
#   'what': 1,
#   'an': 1,
#   'effort': 1,
#   'seems': 1,
#   'to': 3,
#   'be': 1,
#   'for': 1,
#   'many': 1,
#   'people': 1,
#   'put': 1,
#   'their': 1,
#   'brains': 1,
#   'definitely': 1,
#   'and': 1,
#   'systematically': 1,
#   'work': 1,
#   'thomas': 1,
#   'edison': 1},
#  'Liberty exists in proportion to wholesome restraint. - Daniel Webster': {'liberty': 1,
#   'exists': 1,
#   'in': 1,
#   'proportion': 1,
#   'to': 1,
#   'wholesome': 1,
#   'restraint': 1,
#   'daniel': 1,
#   'webster': 1},
#  'To be what we are, and to become what we are capable of becoming, is the only end of life. - Robert Louis Stevenson': {'to': 2,
#   'be': 1,
#   'what': 2,
#   'we': 2,
#   'are': 2,
#   'and': 1,
#   'become': 1,
#   'capable': 1,
#   'of': 2,
#   'becoming': 1,
#   'is': 1,
#   'the': 1,
#   'only': 1,
#   'end': 1,
#   'life': 1,
#   'robert': 1,
#   'louis': 1,
#   'stevenson': 1},
#  'I honestly think it is better to be a failure at something you love than to be a success at something you hate. - George Burns': {'i': 1,
#   'honestly': 1,
#   'think': 1,
#   'it': 1,
#   'is': 1,
#   'better': 1,
#   'to': 2,
#   'be': 2,
#   'a': 2,
#   'failure': 1,
#   'at': 2,
#   'something': 2,
#   'you': 2,
#   'love': 1,
#   'than': 1,
#   'success': 1,
#   'hate': 1,
#   'george': 1,
#   'burns': 1},
#  'The power of accurate observation is commonly called cynicism by those who have not got it. - George Bernard Shaw': {'the': 1,
#   'power': 1,
#   'of': 1,
#   'accurate': 1,
#   'observation': 1,
#   'is': 1,
#   'commonly': 1,
#   'called': 1,
#   'cynicism': 1,
#   'by': 1,
#   'those': 1,
#   'who': 1,
#   'have': 1,
#   'not': 1,
#   'got': 1,
#   'it': 1,
#   'george': 1,
#   'bernard': 1,
#   'shaw': 1},
#  'Question with boldness even the existence of a God; because, if there be one, he must more approve of the homage of reason, than that of blind-folded fear. - Thomas Jefferson': {'question': 1,
#   'with': 1,
#   'boldness': 1,
#   'even': 1,
#   'the': 2,
#   'existence': 1,
#   'of': 4,
#   'a': 1,
#   'god': 1,
#   'because': 1,
#   'if': 1,
#   'there': 1,
#   'be': 1,
#   'one': 1,
#   'he': 1,
#   'must': 1,
#   'more': 1,
#   'approve': 1,
#   'homage': 1,
#   'reason': 1,
#   'than': 1,
#   'that': 1,
#   'blind': 1,
#   'folded': 1,
#   'fear': 1,
#   'thomas': 1,
#   'jefferson': 1},
#  'We are never deceived; we deceive ourselves. - Johann Wolfgang von Goethe': {'we': 2,
#   'are': 1,
#   'never': 1,
#   'deceived': 1,
#   'deceive': 1,
#   'ourselves': 1,
#   'johann': 1,
#   'wolfgang': 1,
#   'von': 1,
#   'goethe': 1},
#  'Government is not a solution to our problem, government is the problem. - Ronald Reagan': {'government': 2,
#   'is': 2,
#   'not': 1,
#   'a': 1,
#   'solution': 1,
#   'to': 1,
#   'our': 1,
#   'problem': 2,
#   'the': 1,
#   'ronald': 1,
#   'reagan': 1}}

# %% [markdown]
# #### (d) Build the reverse postings-list dictionary
# A reverse
# postings-list is a dictionary whose keys are the words, and the values are
# themselves dictionaries with the key being a full quote, and the value being
# the number of times the word appeared in the full quote. <br>

# %%
## Create a reverse_postings_list dictionary with key as a word and initialize the value as None

reverse_postings_list = {}

for i in list_of_quotes:
    words = words_in_quote(i)
        
    for word in words:
        dictionary = {}
        
        if word in reverse_postings_list:
            continue
        else:
            reverse_postings_list[word] = None

reverse_postings_list
# Out:
# {'how': None,
#  'we': None,
#  'spend': None,
#  'our': None,
#  'days': None,
#  'is': None,
#  'of': None,
#  'course': None,
#  'lives': None,
#  'annie': None,
#  'dillard': None,
#  'two': None,
#  'roads': None,
#  'diverged': None,
#  'in': None,
#  'a': None,
#  'wood': None,
#  'and': None,
#  'i': None,
#  'took': None,
#  'the': None,
#  'one': None,
#  'less': None,
#  'traveled': None,
#  'by': None,
#  'that': None,
#  'has': None,
#  'made': None,
#  'all': None,
#  'difference': None,
#  'robert': None,
#  'frost': None,
#  'what': None,
#  'happiness': None,
#  'feeling': None,
#  'power': None,
#  'growing': None,
#  'resistance': None,
#  'overcome': None,
#  'friedrich': None,
#  'nietzsche': None,
#  'great': None,
#  'deal': None,
#  'intelligence': None,
#  'can': None,
#  'be': None,
#  'invested': None,
#  'ignorance': None,
#  'when': None,
#  'need': None,
#  'for': None,
#  'illusion': None,
#  'deep': None,
#  'saul': None,
#  'bellow': None,
#  'those': None,
#  'who': None,
#  'are': None,
#  'preoccupied': None,
#  'with': None,
#  '`making': None,
#  'statement`': None,
#  'usually': None,
#  'don`t': None,
#  'have': None,
#  'any': None,
#  'statements': None,
#  'worth': None,
#  'making': None,
#  'thomas': None,
#  'sowell': None,
#  'women': None,
#  'reason': None,
#  'to': None,
#  'sex': None,
#  'men': None,
#  'just': None,
#  'place': None,
#  'billy': None,
#  'crystal': None,
#  'heart': None,
#  'its': None,
#  'reasons': None,
#  'which': None,
#  'mind': None,
#  'knows': None,
#  'nothing': None,
#  'blaise': None,
#  'pascal': None,
#  'it': None,
#  'necessary': None,
#  'welfare': None,
#  'society': None,
#  'genius': None,
#  'should': None,
#  'privileged': None,
#  'utter': None,
#  'sedition': None,
#  'blaspheme': None,
#  'outrage': None,
#  'good': None,
#  'taste': None,
#  'corrupt': None,
#  'youthful': None,
#  'generally': None,
#  'scandalize': None,
#  'one`s': None,
#  'uncles': None,
#  'george': None,
#  'bernard': None,
#  'shaw': None,
#  'freedom': None,
#  'not': None,
#  'something': None,
#  'anybody': None,
#  'given': None,
#  'people': None,
#  'take': None,
#  'as': None,
#  'free': None,
#  'they': None,
#  'want': None,
#  'james': None,
#  'baldwin': None,
#  'collecting': None,
#  'more': None,
#  'taxes': None,
#  'than': None,
#  'absolutely': None,
#  'legalized': None,
#  'robbery': None,
#  'calvin': None,
#  'coolidge': None,
#  'almost': None,
#  'had': None,
#  'pyschic': None,
#  'girlfriend': None,
#  'but': None,
#  'she': None,
#  'left': None,
#  'me': None,
#  'before': None,
#  'met': None,
#  'steven': None,
#  'wright': None,
#  'man': None,
#  'disobeys': None,
#  'his': None,
#  'parents': None,
#  'will': None,
#  'disobedient': None,
#  'sons': None,
#  'nachman': None,
#  'bratslav': None,
#  'know': None,
#  'god': None,
#  'give': None,
#  'anything': None,
#  'can`t': None,
#  'handle': None,
#  'wish': None,
#  'he': None,
#  'didn`t': None,
#  'trust': None,
#  'so': None,
#  'much': None,
#  'mother': None,
#  'teresa': None,
#  'an': None,
#  'american': None,
#  'says': None,
#  'loves': None,
#  'country': None,
#  'means': None,
#  'only': None,
#  'new': None,
#  'england': None,
#  'hills': None,
#  'prairies': None,
#  'glistening': None,
#  'sun': None,
#  'wide': None,
#  'rising': None,
#  'plains': None,
#  'mountains': None,
#  'sea': None,
#  'inner': None,
#  'air': None,
#  'light': None,
#  'draw': None,
#  'breath': None,
#  'self': None,
#  'respect': None,
#  'adlai': None,
#  'stevenson': None,
#  'words': None,
#  'do': None,
#  'christ': None,
#  'increase': None,
#  'darkness': None,
#  'my': None,
#  'dream': None,
#  'time': None,
#  'where': None,
#  'america': None,
#  'once': None,
#  'again': None,
#  'seen': None,
#  'last': None,
#  'best': None,
#  'hope': None,
#  'earth': None,
#  'abraham': None,
#  'lincoln': None,
#  'actor': None,
#  'at': None,
#  'most': None,
#  'poet': None,
#  'least': None,
#  'entertainer': None,
#  'marlon': None,
#  'brando': None,
#  'humility': None,
#  'foundation': None,
#  'other': None,
#  'virtues': None,
#  'hence': None,
#  'soul': None,
#  'this': None,
#  'virtue': None,
#  'does': None,
#  'exist': None,
#  'there': None,
#  'cannot': None,
#  'except': None,
#  'mere': None,
#  'appearance': None,
#  'saint': None,
#  'augustine': None,
#  'object': None,
#  'teaching': None,
#  'child': None,
#  'enable': None,
#  'him': None,
#  'get': None,
#  'along': None,
#  'without': None,
#  'teacher': None,
#  'elbert': None,
#  'hubbard': None,
#  'avoid': None,
#  'base': None,
#  'hypocrisy': None,
#  'condemning': None,
#  'you': None,
#  'pass': None,
#  'over': None,
#  'silence': None,
#  'committed': None,
#  'another': None,
#  'theodore': None,
#  'roosevelt': None,
#  'football': None,
#  'teams': None,
#  'temperamental': None,
#  'that`s': None,
#  '90': None,
#  'temper': None,
#  '10': None,
#  'mental': None,
#  'doug': None,
#  'plank': None,
#  'no': None,
#  'liberty': None,
#  'unless': None,
#  'economic': None,
#  'margaret': None,
#  'thatcher': None,
#  'idealism': None,
#  'fine': None,
#  'approaches': None,
#  'reality': None,
#  'costs': None,
#  'become': None,
#  'prohibitive': None,
#  'william': None,
#  'f': None,
#  'buckley': None,
#  'attend': None,
#  'funeral': None,
#  'sent': None,
#  'nice': None,
#  'letter': None,
#  'saying': None,
#  'approved': None,
#  'mark': None,
#  'twain': None,
#  'every': None,
#  'woman': None,
#  'about': None,
#  'everything': None,
#  'rudyard': None,
#  'kipling': None,
#  'perfect': None,
#  'dispenses': None,
#  'modesty': None,
#  'c': None,
#  's': None,
#  'lewis': None,
#  'think': None,
#  'gift': None,
#  'president': None,
#  'would': None,
#  'chocolate': None,
#  'revolver': None,
#  'since': None,
#  'he`s': None,
#  'busy': None,
#  'you`d': None,
#  'probably': None,
#  'run': None,
#  'up': None,
#  'hand': None,
#  'jack': None,
#  'handey': None,
#  'thought': None,
#  'being': None,
#  'frightens': None,
#  'job': None,
#  'ronald': None,
#  'reagan': None,
#  'journey': None,
#  'thousand': None,
#  'miles': None,
#  'begins': None,
#  'single': None,
#  'step': None,
#  'confucius': None,
#  'modern': None,
#  'root': None,
#  'fear': None,
#  'too': None,
#  'bold': None,
#  'endure': None,
#  'rules': None,
#  'rather': None,
#  'timid': None,
#  'responsibilities': None,
#  'gk': None,
#  'chesterton': None,
#  'television': None,
#  'medium': None,
#  'entertainment': None,
#  'permits': None,
#  'millions': None,
#  'listen': None,
#  'same': None,
#  'joke': None,
#  'yet': None,
#  'remain': None,
#  'lonesome': None,
#  't': None,
#  'eliot': None,
#  'imagination': None,
#  'often': None,
#  'carry': None,
#  'us': None,
#  'worlds': None,
#  'never': None,
#  'were': None,
#  'go': None,
#  'nowhere': None,
#  'carl': None,
#  'sagan': None,
#  'fairly': None,
#  'large': None,
#  'talkative': None,
#  'community': None,
#  'such': None,
#  'university': None,
#  'always': None,
#  'danger': None,
#  'alike': None,
#  'gravitate': None,
#  'together': None,
#  'henceforth': None,
#  'encounter': None,
#  'opposition': None,
#  'emasculated': None,
#  'form': None,
#  'rumour': None,
#  'outsiders': None,
#  'say': None,
#  'thus': None,
#  'absent': None,
#  'easily': None,
#  'refuted': None,
#  'complacent': None,
#  'dogmatism': None,
#  'thrives': None,
#  'differences': None,
#  'opinion': None,
#  'embittered': None,
#  'group': None,
#  'hostility': None,
#  'each': None,
#  'hears': None,
#  'worst': None,
#  'success': None,
#  'consist': None,
#  'mistakes': None,
#  'second': None,
#  'deliberate': None,
#  'action': None,
#  'arrived': None,
#  'stop': None,
#  'thinking': None,
#  'napoleon': None,
#  'bonaparte': None,
#  'i`m': None,
#  'going': None,
#  'famous': None,
#  'name': None,
#  'writ': None,
#  'on': None,
#  'roster': None,
#  'things': None,
#  'thing': None,
#  'used': None,
#  'bite': None,
#  'nails': None,
#  'even': None,
#  'dorothy': None,
#  'parker': None,
#  'money': None,
#  'doesn`t': None,
#  'talk': None,
#  'swears': None,
#  'bob': None,
#  'dylan': None,
#  'advertising': None,
#  'life': None,
#  'trade': None,
#  'christmas': None,
#  'celebrated': None,
#  'school': None,
#  'room': None,
#  'pine': None,
#  'trees': None,
#  'tinsel': None,
#  'reindeers': None,
#  'must': None,
#  'mention': None,
#  'whose': None,
#  'birthday': None,
#  'wonders': None,
#  'answer': None,
#  'if': None,
#  'student': None,
#  'asked': None,
#  'why': None,
#  'was': None,
#  'called': None,
#  'experience': None,
#  'marvelous': None,
#  'enables': None,
#  'recognize': None,
#  'mistake': None,
#  'make': None,
#  'franklin': None,
#  'jones': None,
#  'own': None,
#  'secure': None,
#  'guard': None,
#  'enemy': None,
#  'from': None,
#  'violates': None,
#  'duty': None,
#  'establishes': None,
#  'precedent': None,
#  'reach': None,
#  'himself': None,
#  'paine': None,
#  'originality': None,
#  'art': None,
#  'remembering': None,
#  'hear': None,
#  'forgetting': None,
#  'heard': None,
#  'laurence': None,
#  'peter': None,
#  'arrive': None,
#  'end': None,
#  'review': None,
#  'having': None,
#  'done': None,
#  'critic': None,
#  'described': None,
#  'movie': None,
#  'accurately': None,
#  'idea': None,
#  'see': None,
#  'argue': None,
#  'some': None,
#  'brave': None,
#  'curious': None,
#  'embody': None,
#  'spirit': None,
#  'first': None,
#  'wondered': None,
#  'like': None,
#  'eat': None,
#  'oyster': None,
#  'roger': None,
#  'ebert': None,
#  'marry': None,
#  'beginning': None,
#  'alexis': None,
#  'dupuy': None,
#  'show': None,
#  'thoroughly': None,
#  'satisfied': None,
#  'failure': None,
#  'edison': None,
#  'rest': None,
#  'sets': None,
#  'value': None,
#  'others': None,
#  'marcus': None,
#  'aurelius': None,
#  'find': None,
#  'out': None,
#  'moral': None,
#  'law': None,
#  'univerise': None,
#  'general': None,
#  'listening': None,
#  'conversation': None,
#  'looking': None,
#  'house': None,
#  'built': None,
#  'instead': None,
#  'trap': None,
#  'door': None,
#  'window': None,
#  'guy': None,
#  'looks': None,
#  'leans': None,
#  'far': None,
#  'falls': None,
#  'wait': None,
#  'guess': None,
#  'regular': None,
#  'promote': None,
#  'exertion': None,
#  'faculties': None,
#  'changes': None,
#  'external': None,
#  'circumstances': None,
#  'both': None,
#  'may': None,
#  'seem': None,
#  'favourable': None,
#  'adam': None,
#  'smith': None,
#  'man`s': None,
#  'secret': None,
#  'nerve': None,
#  'answers': None,
#  'vibrations': None,
#  'beauty': None,
#  'christopher': None,
#  'morley': None,
#  'jack`s': None,
#  'love': None,
#  'judge': None,
#  'jill`s': None,
#  'benjamin': None,
#  'democrats': None,
#  'basically': None,
#  'nicer': None,
#  'demonstrated': None,
#  'management': None,
#  'skills': None,
#  'celery': None,
#  'dave': None,
#  'barry': None,
#  'courage': None,
#  'wisdom': None,
#  'bears': None,
#  'fruit': None,
#  'baltasar': None,
#  'gracian': None,
#  'completely': None,
#  'absurd': None,
#  'presidency': None,
#  'dwight': None,
#  'eisenhower': None,
#  'happen': None,
#  'albert': None,
#  'einstein': None,
#  'fool': None,
#  'doth': None,
#  'wise': None,
#  'shakespeare': None,
#  'stay': None,
#  'nights': None,
#  'succeed': None,
#  'awake': None,
#  'author': None,
#  'unknown': None,
#  'happens': None,
#  'while': None,
#  'you`re': None,
#  'plans': None,
#  'john': None,
#  'lennon': None,
#  'dodge': None,
#  'dale': None,
#  'carnegie': None,
#  'hobby': None,
#  'world`s': None,
#  'largest': None,
#  'collection': None,
#  'shells': None,
#  'keep': None,
#  'scattered': None,
#  'beaches': None,
#  'world': None,
#  'maybe': None,
#  'you`ve': None,
#  'happy': None,
#  'lies': None,
#  'extracting': None,
#  'common': None,
#  'henry': None,
#  'ward': None,
#  'beecher': None,
#  'demoralize': None,
#  'within': None,
#  'surprise': None,
#  'terror': None,
#  'sabotage': None,
#  'assassination': None,
#  'war': None,
#  'future': None,
#  'adolf': None,
#  'hitler': None,
#  'eighty': None,
#  'percent': None,
#  'your': None,
#  'sales': None,
#  'come': None,
#  'twenty': None,
#  'items': None,
#  'kissinger': None,
#  'it`s': None,
#  'old': None,
#  'hard': None,
#  'work': None,
#  'jonah': None,
#  'barrington': None,
#  'sunshine': None,
#  'flowers': None,
#  'smiles': None,
#  'humanity': None,
#  'these': None,
#  'trifles': None,
#  'sure': None,
#  'life`s': None,
#  'pathway': None,
#  'inconceivable': None,
#  'joseph': None,
#  'addison': None,
#  'got': None,
#  'very': None,
#  'careful': None,
#  'because': None,
#  'might': None,
#  'yogi': None,
#  'berra': None,
#  'support': None,
#  'system': None,
#  'way': None,
#  'around': None,
#  'stephen': None,
#  'king': None,
#  'delightful': None,
#  'interval': None,
#  'between': None,
#  'meeting': None,
#  'beautiful': None,
#  'girl': None,
#  'discovering': None,
#  'haddock': None,
#  'barrymore': None,
#  'supernatural': None,
#  'natural': None,
#  'understood': None,
#  'forget': None,
#  'evil': None,
#  'seek': None,
#  'facts': None,
#  'likely': None,
#  'achieve': None,
#  'view': None,
#  'through': None,
#  'distorting': None,
#  'their': None,
#  'desires': None,
#  'bertrand': None,
#  'russell': None,
#  'proves': None,
#  'or': None,
#  'according': None,
#  'preconceptions': None,
#  'bring': None,
#  'separates': None,
#  'generations': None,
#  'music': None,
#  'eight': None,
#  'nine': None,
#  'developed': None,
#  'passion': None,
#  'stronger': None,
#  'passions': None,
#  'procrastination': None,
#  'weird': None,
#  'clothes': None,
#  'bill': None,
#  'cosby': None,
#  'hour': None,
#  'departure': None,
#  'ways': None,
#  'die': None,
#  'live': None,
#  'better': None,
#  'plato': None,
#  'statistics': None,
#  'sanity': None,
#  'four': None,
#  'americans': None,
#  'suffering': None,
#  'illness': None,
#  'three': None,
#  'friends': None,
#  'they`re': None,
#  'okay': None,
#  'then': None,
#  'rita': None,
#  'mae': None,
#  'brown': None,
#  'stupid': None,
#  'abnormal': None,
#  'leo': None,
#  'tolstoy': None,
#  'everybody': None,
#  'serve': None,
#  'college': None,
#  'degree': None,
#  'subject': None,
#  'verb': None,
#  'agree': None,
#  'full': None,
#  'grace': None,
#  'generated': None,
#  'martin': None,
#  'luther': None,
#  'jr': None,
#  '': None,
#  'becoming': None,
#  'encourage': None,
#  'them': None,
#  'nag': None,
#  'frauds': None,
#  'admit': None,
#  'myself': None,
#  'deny': None,
#  'mencken': None,
#  'blanket': None,
#  'piece': None,
#  'unbroken': None,
#  'cloth': None,
#  'color': None,
#  'texture': None,
#  'size': None,
#  'quilt': None,
#  'many': None,
#  'patches': None,
#  'pieces': None,
#  'colors': None,
#  'sizes': None,
#  'woven': None,
#  'held': None,
#  'thread': None,
#  'jesse': None,
#  'jackson': None,
#  'seems': None,
#  'help': None,
#  'look': None,
#  'stonecutter': None,
#  'hammering': None,
#  'away': None,
#  'rock': None,
#  'perhaps': None,
#  'hundred': None,
#  'times': None,
#  'crack': None,
#  'showing': None,
#  'blow': None,
#  'split': None,
#  'did': None,
#  'gone': None,
#  'jacob': None,
#  'august': None,
#  'riis': None,
#  'moment': None,
#  'decision': None,
#  'right': None,
#  'denial': None,
#  'shining': None,
#  'sore': None,
#  'leprous': None,
#  'body': None,
#  'christianity': None,
#  'oscar': None,
#  'wilde': None,
#  'been': None,
#  'hurt': None,
#  'said': None,
#  'defense': None,
#  'against': None,
#  'foreign': None,
#  'historically': None,
#  'instruments': None,
#  'tyranny': None,
#  'home': None,
#  'madison': None,
#  'courageous': None,
#  'enough': None,
#  'risks': None,
#  'accomplish': None,
#  'muhammad': None,
#  'ali': None,
#  'fights': None,
#  'runs': None,
#  'turn': None,
#  'fight': None,
#  'day': None,
#  'battle': None,
#  'slain': None,
#  'rise': None,
#  'tacitus': None,
#  'invent': None,
#  'human': None,
#  'rights': None,
#  'real': None,
#  'sense': None,
#  'invented': None,
#  'jimmy': None,
#  'carter': None,
#  'matter': None,
#  'cats': None,
#  'plenty': None,
#  'kittens': None,
#  'depend': None,
#  'upon': None,
#  'position': None,
#  'hold': None,
#  'yourself': None,
#  'makes': None,
#  'height': None,
#  'lacks': None,
#  'length': None,
#  'poetry': None,
#  'creating': None,
#  'imaginary': None,
#  'gardens': None,
#  'toads': None,
#  'marianne': None,
#  'moore': None,
#  'goodness': None,
#  'benefits': None,
#  'speech': None,
#  'use': None,
#  'either': None,
#  'bible': None,
#  'book': None,
#  'religion': None,
#  'could': None,
#  'assent': None,
#  'long': None,
#  'complicated': None,
#  'christian': None,
#  'dogma': None,
#  'wrapped': None,
#  'quotations': None,
#  'beggar': None,
#  'enfold': None,
#  'purple': None,
#  'emperors': None,
#  'truth': None,
#  'trick': None,
#  'among': None,
#  'speaks': None,
#  'loudly': None,
#  'ralph': None,
#  'waldo': None,
#  'emerson': None,
#  'glory': None,
#  'fleeting': None,
#  'patton': None,
#  'distance': None,
#  'lapse': None,
#  'lessen': None,
#  'friendship': None,
#  'persuaded': None,
#  'other`s': None,
#  'southey': None,
#  'washington': None,
#  'city': None,
#  'southern': None,
#  'efficiency': None,
#  'northern': None,
#  'charm': None,
#  'kennedy': None,
#  'boxing': None,
#  'match': None,
#  'try': None,
#  'let': None,
#  'guy`s': None,
#  'glove': None,
#  'touch': None,
#  'lips': None,
#  'discourage': None,
#  'anyone': None,
#  'continually': None,
#  'progress': None,
#  'slow': None,
#  'finding': None,
#  'plumber': None,
#  'sunday': None,
#  'woody': None,
#  'allen': None,
#  'rome': None,
#  'remained': None,
#  'years': None,
#  'sparta': None,
#  'although': None,
#  'citizens': None,
#  'armed': None,
#  'states': None,
#  'disarmed': None,
#  'lost': None,
#  'liberties': None,
#  'forty': None,
#  'nicolo': None,
#  'machiavelli': None,
#  'science': None,
#  'lame': None,
#  'blind': None,
#  'knowledge': None,
#  'rests': None,
#  'alone': None,
#  'error': None,
#  'also': None,
#  'jung': None,
#  'politics': None,
#  'shared': None,
#  'hatreds': None,
#  'basis': None,
#  'friendships': None,
#  'de': None,
#  'tocqueville': None,
#  'limitations': None,
#  'stupidity': None,
#  'handicapped': None,
#  'moves': None,
#  'curves': None,
#  'edward': None,
#  'bulwer': None,
#  'lytton': None,
#  'planted': None,
#  'bird': None,
#  'seed': None,
#  'came': None,
#  'now': None,
#  'feed': None,
#  'trusts': None,
#  'paintings': None,
#  'believe': None,
#  'photographs': None,
#  'ansel': None,
#  'adams': None,
#  'destroy': None,
#  'prosperity': None,
#  'price': None,
#  'peace': None,
#  'safety': None,
#  'soft': None,
#  ...}

# %%
## The key dictionary is now updated to contain quotes as keys that has the word;
## The frequency of the word in that quote as value

for key in reverse_postings_list.keys():
    
    dictionary = {}
    
    for quote in list_of_quotes:
        if key in words_in_quote(quote):
            
            dictionary[quote] = postings_list[quote][key]
        
    reverse_postings_list[key] = dictionary

# %%
reverse_postings_list
# Out:
# {'how': {'How we spend our days is, of course, how we spend our lives. - Annie Dillard': 2,
#   'Christmas can be celebrated in the school room with pine trees, tinsel and reindeers, but there must be no mention of the man whose birthday is being celebrated. One wonders how a teacher would answer if a student asked why it was called Christmas. - Ronald Reagan': 1,
#   'I have often wondered how it is that every man loves himself more than all the rest of men, but yet sets less value on his own opinion of himself than on the opinion of others. - Marcus Aurelius': 1,
#   'It`s not how old you are, it`s how hard you work at it. - Jonah Barrington': 2,
#   'No matter how much cats fight, there always seem to be plenty of kittens. - Abraham Lincoln': 1,
#   'Success, the real success, does not depend upon the position you hold but upon how you carry yourself in that position. - Theodore Roosevelt': 1,
#   'Never discourage anyone who continually makes progress, no matter how slow. - Plato': 1,
#   'True wisdom comes to each of us when we realize how little we understand about life, ourselves, and the world around us. - Socrates': 1,
#   'How did it get so late so soon? It`s night before it`s afternoon. December is here before it`s June. My goodness how the time has flewn. How did it get so late so soon? - Theodor Seuss Geisel': 3,
#   'One thing they never tell you about child raising is that for the rest of your life, at the drop of a hat, you are expected to know your child`s name and how old he or she is. - Erna Bombeck': 1,
#   'If a man is proud of his wealth, he should not be praised until it is known how he employs it. - Socrates': 1,
#   'We`ve got to live. No matter how many skies have fallen. - D.H. Lawrence': 1,
#   'The ACLU is always yakking about the Constitution, and most of us are getting mighty tired of it. I mean, if the Constitution is so great, how come it was amended so many times? Huh? - Dave Barry': 1,
#   'Many of life`s failures are people who did not realize how close they were to success when they gave up. - Thomas Edison': 1,
#   'How did it happen that their lips came together? How does it happen that birds sing, that snow melts, that the rose unfolds, that the dawn whitens behind the stark shapes of trees on the quivering summit of the hill? A kiss, and all was said. - Victor Hugo': 2,
#   'My role in society, or any artist`s or poet`s role, is to try and express what we all feel. Not to tell people how to feel. Not as a preacher, not as a leader, but as a reflection of us all. - John Lennon': 1,
#   'Our nettlesome task is to discover how to organize our strength into compelling power. - Martin Luther King Jr.': 1,
#   'I do not believe one can settle how much we ought to give. I am afraid the only safe rule is to give more than we can spare. - C.S. Lewis': 1,
#   'There is no question that there is an unseen world. The problem is, how far is it from midtown and how late is it open? - Woody Allen': 2,
#   'It`s not how much we give but how much love we put into giving. - Mother Teresa': 2,
#   'All children are artists. The problem is how to remain an artist once he grows up. - Pablo Picasso': 1},
#  'we': {'How we spend our days is, of course, how we spend our lives. - Annie Dillard': 2,
#   'I almost had a pyschic girlfriend, but she left me before we met. - Steven Wright': 1,
#   'Most modern freedom is at root fear. It is not so much that we are too bold to endure rules; it is rather that we are too timid to endure responsibilities. - GK Chesterton': 2,
#   'Imagination will often carry us to worlds that never were. But without it, we go nowhere. - Carl Sagan': 1,
#   'Experience proves this, or that, or nothing, according to the preconceptions we bring to it. - C.S. Lewis': 1,
#   'The hour of departure has arrived, and we go our ways - I to die, and you to live. Which is better God only knows. - Plato': 1,
#   'It is by the goodness of God that, in this country, we have three benefits: freedom of speech, freedom of thought, and the wisdom never to use either. - Mark Twain': 1,
#   'If we do not help a man in trouble, it is as if we caused the trouble. - Nachman of Bratslav': 2,
#   'True wisdom comes to each of us when we realize how little we understand about life, ourselves, and the world around us. - Socrates': 2,
#   'Were it possible for us to wait for ourselves to come into the room, not many of us would find our hearts breaking into flower as we heard the door handle turn. - Rebecca West': 1,
#   'It is always thus, impelled by a state of mind which is destined not to last, that we make our irrevocable decisions. - Marcel Proust': 1,
#   'We ascribe beauty to that which is simple; which has no superfluous parts; which exactly answers its end; which stands related to all things; which is the mean of many extremes. - Ralph Waldo Emerson': 1,
#   'In the long run, we shape our lives and we shape ourselves. The process never ends until we die, and the choices that we make are ultimately our responsibility. - Eleanor Roosevelt': 4,
#   'We all wish to be judged by our peers, by the men `after our own heart.` Only they really know our mind and only they judge it by standards we fully acknowledge. Theirs is the praise we really covet and the blame we really dread. The little pockets of early Chrstians survived because they cared exclusively for the love of `the bretheren` and stopped their ears to the opinion of the Pagan society around them. But a circle of criminals, cranks, or perverts survives in just the same way; by becoming deaf to the opinion of the outer world, by discounting it as the chatter of outsiders who `don`t understand,` of the `conventional,` the `bourgeois,` the `Establishment,` of prigs, prudes, and humbugs. - C.S. Lewis': 4,
#   'If there is any principle of the Constitution that more imperatively calls for attachment than any other it is the principle of free thought, not free thought for those who agree with us but freedom for the thought that we hate. - Oliver Wendell Holmes': 1,
#   'We should take care not to make the intellect our god; it has, of course, powerful muscles, but no personality. - Albert Einstein': 1,
#   'The significant problems we face cannot be solved at the same level of thinking we were at when we created them. - Albert Einstein': 3,
#   'Without computers, the government would be unable to function at the level of effectiveness and efficiency that we have come to expect.  This is because the primary function of the government is -- and here I am quoting directly from the U.S. Constitution -- `to spew out paper.` - Dave Barry': 1,
#   'The greatest thing in this world is not so much where we are, but in what direction we are moving. - Oliver Wendell Holmes': 2,
#   'There are some who`ve forgotten why we have a military. It`s not to promote war; it`s to be prepared for peace. - Ronald Reagan': 1,
#   'If we have no peace, it is because we have forgotten that we belong to each other. - Mother Teresa': 3,
#   'Alexander, Caesar, Charlemagne, and myself founded empires; but what foundation did we rest the creations of our genius? Upon force. Jesus Christ founded an empire upon love; and at this hour millions of men would die for Him. - Napoleon Bonaparte': 1,
#   'There is hope for the future because God has a sense of humor and we are funny to God. - Bill Cosby': 1,
#   'If we will be quiet and ready enough, we shall find compensation in every disappointment. - Henry Thoreau': 2,
#   'Chicago sounds rough to the maker of verse. One comfort we have: Cincinnati sounds worse. - Oliver Wendell Holmes': 1,
#   'We have the Bill of Rights. What we need is a Bill of Responsibilities. - Bill Maher': 2,
#   'We are what we repeatedly do. Excellence, therefore, is not an act, but a habit. - Aristotle': 2,
#   'Being is desirable because it is identical with Beauty, and Beauty is loved because it is Being. We ourselves possess Beauty when we are true to our own being; ugliness is in going over to another order; knowing ourselves, we are beautiful; in self-ignorance, we are ugly. - Ambrose Bierce': 4,
#   'We live in an age when unnecessary things are our only necessities. - Oscar Wilde': 1,
#   'Four-fifths of all our troubles would disappear, if we would only sit down and keep still. - Calvin Coolidge': 1,
#   'We must repsect the other fellow`s religion, but only in the sense and to the extent that we respect his theory that his wife is beautiful and his children are smart. - Henry Mencken': 2,
#   'We are all worms, but I do believe I am a glow-worm. - Winston Churchill': 1,
#   'There are very few monsters who warrant the fear we have of them. - André Gide': 1,
#   'My role in society, or any artist`s or poet`s role, is to try and express what we all feel. Not to tell people how to feel. Not as a preacher, not as a leader, but as a reflection of us all. - John Lennon': 1,
#   'We know too much, and are convinced of too little. Our literature is a substitute for religion, and so is our religion. - T.S. Eliot': 1,
#   'I hope that when you are my age, you will be able to say as I have been able to say: We lived in freedom. We lived lives that were a statement, not an apology. - Ronald Reagan': 2,
#   'New knowledge is the most valuable commodity on earth. The more truth we have to work with, the richer we become. - Kurt Vonnegut': 2,
#   'The greatest happiness of life is the conviction that we are loved, loved for ourselves, or rather, loved in spite of ourselves. - Victor Hugo': 1,
#   'When we die, our bodies are buried. When we live, our souls are buried. - Jason Mechalek': 2,
#   'It is only our bad temper that we put down to being tired or worried or hungry; we put our good temper down to ourselves. - C.S. Lewis': 2,
#   'Every difference of opinion is not a difference of principle. We have called by different names brethren of the same principle. - Thomas Jefferson': 1,
#   'If we command our wealth, we shall be rich and free; if our wealth commands us, we are poor indeed. - Edmund Burke': 3,
#   'If you have an apple and I have an apple and we exchange these apples then you and I will still each have one apple. But if you have an idea and I have an idea and we exchange these ideas, then each of us will have two ideas. - George Bernard Shaw': 2,
#   'Intoxicated with unbroken success, we have become too self-sufficient to feel the necessity of redeeming and preserving grace, too proud to pray to the God that made us. - Abraham Lincoln': 1,
#   'In the Orthodox spiritual tradition, the ultimate moral question we ask is the following: Is what we are doing, is what I am doing, beautiful or not? - Carolyn Gifford': 2,
#   'She was what we used to call a suicide blond - dyed by her own hand. - Saul Bellow': 1,
#   'I do not believe one can settle how much we ought to give. I am afraid the only safe rule is to give more than we can spare. - C.S. Lewis': 2,
#   'No sooner do we depart from sense and instinct to follow reason but we are insensibly drawn into uncouth paradoxes, difficulties, and inconsistencies, which multiply and grow upon us as we advance in speculation; till at length, having wandered through many intricate mazes, we find ourselves just where we were, or, which is worse, sit down in a forlorn scepticism. - George Berkeley': 5,
#   'We make a living by what we get, but we make a life by what we give. - Winston Churchill': 4,
#   'The reason we hold truth in such respect is because we have so little opportunity to get familiar with it. - Mark Twain': 2,
#   'One of the great attractions of patriotism -- it fulfills our worst wishes. In the person of our nation we are able, vicariously, to bully and cheat. Bully and cheat, what`s more, with a feeling that we are profoundly virtuous. - Aldous Huxley': 2,
#   'There are perhaps no days of our childhood we lived so fully as those we spent with a favorite book. - Marcel Proust': 2,
#   'Failure is success if we learn from it. - Malcolm Forbes': 1,
#   'Through pride we are ever deceiving ourselves. But deep down below the surface of the average conscience a still, small voice says to us, something is out of tune. - Carl Jung': 1,
#   'The time which we have at our disposal every day is elastic; the passions we feel expand it, those that we inspire contract it, and habit fills up what remains. - Marcel Proust': 3,
#   'This will never be a civilized country until we expend more money for books than we do for chewing gum. - Elbert Hubbard': 2,
#   'It`s not how much we give but how much love we put into giving. - Mother Teresa': 2,
#   'Some of your countrymen were unable to distinguish between their native dislike for war and the stainless patriotism of those who suffered its scars. But there has been a rethinking and now we can say to you, and say as a nation, thank you for your courage. - Ronald Reagan': 1,
#   'We are healed from suffering only by experiencing it to the full. - Marcel Proust': 1,
#   'Nature is trying very hard to make us succeed, but nature does not depend on us. We are not the only experiment. - Buckminster Fuller': 1,
#   'We turn not older with years, but newer every day. - Emily Dickinson': 1,
#   'To defend Western Europe we have to let the Pentagon buy all these tanks and guns and things, and the Pentagon is unable to buy any object that that costs less than a condominium in Vail. If the Pentagon needs, say, fruit, it will argue that it must have fruit that can withstand the rigors of combat conditions, and it will wind up purchasing the FX-700 Seedless Tactical Grape, which will cost $160,000 per bunch, and will have an 83 percent failure rate. - Dave Barry': 1,
#   'We seem to be going through a period of nostalgia, and everyone seems to think yesterday was better than today. I don`t think it was, and I would advise you not to wait ten years before admitting today was great. If you`re hung up on nostalgia, pretend today is yesterday and just go out and have one hell of a time. - Art Buchwald': 1,
#   'The thing we all have to understand to put these last two years in focus, is that liberals in this country care more about whether European leaders like us than they do about whether terrorists are killing us. - Rush Limbaugh': 1,
#   'In the councils of government, we must guard against the acquisition of unwarranted influence, whether sought or unsought, by the military-industrial complex. - Dwight Eisenhower': 1,
#   'What we are today comes from our thoughts of yesterday and our present thoughts build our life tomorrow. Our life is the creation of our mind. - Siddhartha Buddha': 1,
#   'Life`s Tragedy is that we get old to soon and wise too late. - Benjamin Franklin': 1,
#   'We are living in a world, where what we earn is a function of what we learn. - Bill Clinton': 3,
#   'The cost of freedom is always high, but Americans have always paid it. And one path we shall never choose, and that is the path of surrender, or submission. - John F. Kennedy': 1,
#   'We know life is futile. A man who considers that his life is of very wonderful importance is awfully close to a padded cell. - Clarence Darrow': 1,
#   'We all want progress, but if you`re on the wrong road, progress means doing an about-turn and walking back to the right road; in that case, the man who turns back soonest is the most progressive. - C.S. Lewis': 1,
#   'Let us have faith that right makes might, and in that faith, let us, to the end, dare to do our duty as we understand it. - Abraham Lincoln': 1,
#   'When we got into office, the thing that surprised me the most was that things were as bad as we`d been saying they were. - John F. Kennedy': 1,
#   'If the United Nations once admits that international disputes can be settled by using force, then we will have destroyed the foundation of the organization and our best hope of establishing a world order. - Dwight Eisenhower': 1,
#   'On account of being a democracy and run by the people, we are the only nation in the world that has to keep a government four years, no matter what it does. - Will Rogers': 1,
#   'God does not give heed to the ambitiousness of our prayers, because he is always ready to give to us his light, not a visible light but an intellectual and spiritual one; but we are not always ready to receive it when we turn aside and down to other things out of a desire for temporal things. - Saint Augustine': 2,
#   'We have it in our power to begin the world over again. - Thomas Paine': 1,
#   'I think computer viruses should count as life. I think it says something about human nature that the only form of life we have created so far is purely destructive. We`ve created life in our own image. - Stephen Hawking': 1,
#   'Parting is all we know of heaven and all we need to know of hell. - Emily Dickinson': 2,
#   'There is luxury in self-reproach. When we blame ourselves, we feel no one else has a right to blame us. - Oscar Wilde': 2,
#   'We need not just a new generation of leadership but a new gender of leadership. - Bill Clinton': 1,
#   'The illegal we do immediately. The unconstitutional takes a little longer. - Henry Kissinger': 1,
#   'We do survive every moment, after all, except the last one. - John Updike': 1,
#   'We have to make America the best place in the world to do business. - Dick Cheney': 1,
#   'That is the true season of love, when we believe that we alone can love, that no one could ever have loved so before us, and that no one will love in the same way after us. - Johann Wolfgang von Goethe': 2,
#   'To be what we are, and to become what we are capable of becoming, is the only end of life. - Robert Louis Stevenson': 2,
#   'We are never deceived; we deceive ourselves. - Johann Wolfgang von Goethe': 2},
#  'spend': {'How we spend our days is, of course, how we spend our lives. - Annie Dillard': 2,
#   'Are you entitled to the fruits of your labor or does government have some presumptive right to spend and spend and spend? - Ronald Reagan': 3,
#   'If God had wanted us to spend our time fretting about the problems of home ownership, He would never have invented beer. - Dave Barry': 1},
#  'our': {'How we spend our days is, of course, how we spend our lives. - Annie Dillard': 2,
#   'The hour of departure has arrived, and we go our ways - I to die, and you to live. Which is better God only knows. - Plato': 1,
#   'Marriage is our last, best chance to grow up. - Joseph Barth': 1,
#   'Deliberation and debate is the way you stir the soul of our democracy. - Jesse Jackson': 1,
#   'Were it possible for us to wait for ourselves to come into the room, not many of us would find our hearts breaking into flower as we heard the door handle turn. - Rebecca West': 1,
#   'It is always thus, impelled by a state of mind which is destined not to last, that we make our irrevocable decisions. - Marcel Proust': 1,
#   'In the long run, we shape our lives and we shape ourselves. The process never ends until we die, and the choices that we make are ultimately our responsibility. - Eleanor Roosevelt': 2,
#   'We all wish to be judged by our peers, by the men `after our own heart.` Only they really know our mind and only they judge it by standards we fully acknowledge. Theirs is the praise we really covet and the blame we really dread. The little pockets of early Chrstians survived because they cared exclusively for the love of `the bretheren` and stopped their ears to the opinion of the Pagan society around them. But a circle of criminals, cranks, or perverts survives in just the same way; by becoming deaf to the opinion of the outer world, by discounting it as the chatter of outsiders who `don`t understand,` of the `conventional,` the `bourgeois,` the `Establishment,` of prigs, prudes, and humbugs. - C.S. Lewis': 3,
#   'We should take care not to make the intellect our god; it has, of course, powerful muscles, but no personality. - Albert Einstein': 1,
#   'The magic of first love is our ignorance that it can never end. - Benjamin Disraeli': 1,
#   'Alexander, Caesar, Charlemagne, and myself founded empires; but what foundation did we rest the creations of our genius? Upon force. Jesus Christ founded an empire upon love; and at this hour millions of men would die for Him. - Napoleon Bonaparte': 1,
#   'Being is desirable because it is identical with Beauty, and Beauty is loved because it is Being. We ourselves possess Beauty when we are true to our own being; ugliness is in going over to another order; knowing ourselves, we are beautiful; in self-ignorance, we are ugly. - Ambrose Bierce': 1,
#   'We live in an age when unnecessary things are our only necessities. - Oscar Wilde': 1,
#   'Four-fifths of all our troubles would disappear, if we would only sit down and keep still. - Calvin Coolidge': 1,
#   'The greatness of our country has been based on our thinking that everyone has a right even to be wrong. - Ronald Reagan': 2,
#   'We know too much, and are convinced of too little. Our literature is a substitute for religion, and so is our religion. - T.S. Eliot': 2,
#   'Happy, happy Christmas, that can win us back to the delusions of our childhood days, recall to the old man the pleasures of his youth, and transport the traveler back to his own fireside and quiet home! - Charles Dickens': 1,
#   'Our nettlesome task is to discover how to organize our strength into compelling power. - Martin Luther King Jr.': 2,
#   'Such is the delicacy of man alone, that no object is produced to his liking. He finds that in everything there is need for improvement. The whole industry of human life is employed not in procuring the supply of our three humble necessities, food, clothes and lodging, but in procuring the conveniences of it according to the nicety and delicacy of our tastes. - Adam Smith': 2,
#   'Experts tell us that if the Millennium Bug is not fixed, when the year 2000 arrives, our financial records will be inaccurate, our telephone system will be unreliable, our government will be paralyzed and airline flights will be canceled without warning. In other words, things will be pretty much the same as they are now. - Dave Barry': 3,
#   'When we die, our bodies are buried. When we live, our souls are buried. - Jason Mechalek': 2,
#   'It is only our bad temper that we put down to being tired or worried or hungry; we put our good temper down to ourselves. - C.S. Lewis': 2,
#   'If we command our wealth, we shall be rich and free; if our wealth commands us, we are poor indeed. - Edmund Burke': 2,
#   'Blood is the ink of our life`s story. - Jason Mechalek': 1,
#   'One of the great attractions of patriotism -- it fulfills our worst wishes. In the person of our nation we are able, vicariously, to bully and cheat. Bully and cheat, what`s more, with a feeling that we are profoundly virtuous. - Aldous Huxley': 2,
#   'If God had wanted us to spend our time fretting about the problems of home ownership, He would never have invented beer. - Dave Barry': 1,
#   'There are perhaps no days of our childhood we lived so fully as those we spent with a favorite book. - Marcel Proust': 1,
#   'The time which we have at our disposal every day is elastic; the passions we feel expand it, those that we inspire contract it, and habit fills up what remains. - Marcel Proust': 1,
#   'Of all tyrannies, a tyranny exercised for the good of its victims may be the most oppressive. It may be better to live under robber barons than under omnipotent moral busybodies. The robber baron`s cruelty may sometimes sleep, his cupidity may at some point be satiated; but those who torment us for our own good will torment us without end, for they do so with the approval of their own conscience. - C.S. Lewis': 1,
#   'Goldie and I did have a car stolen right out of our yard. It took us three days to notice. - Kurt Russell': 1,
#   'War - an act of violence whose object is to constrain the enemy, to accomplish our will. - George Washington': 1,
#   'What we are today comes from our thoughts of yesterday and our present thoughts build our life tomorrow. Our life is the creation of our mind. - Siddhartha Buddha': 5,
#   'Let us have faith that right makes might, and in that faith, let us, to the end, dare to do our duty as we understand it. - Abraham Lincoln': 1,
#   'If the United Nations once admits that international disputes can be settled by using force, then we will have destroyed the foundation of the organization and our best hope of establishing a world order. - Dwight Eisenhower': 1,
#   'God does not give heed to the ambitiousness of our prayers, because he is always ready to give to us his light, not a visible light but an intellectual and spiritual one; but we are not always ready to receive it when we turn aside and down to other things out of a desire for temporal things. - Saint Augustine': 1,
#   'We have it in our power to begin the world over again. - Thomas Paine': 1,
#   'I think computer viruses should count as life. I think it says something about human nature that the only form of life we have created so far is purely destructive. We`ve created life in our own image. - Stephen Hawking': 1,
#   'Our attitude towards others determines their attitude towards us. - Earl Nightingale': 1,
#   'The mystic chords of memory, stretching from every battlefield and patriot grave to every living heart and hearthstone all over this broad land, will yet swell the chorus of the Union, when again touched, as surely they will be, by the better angels of our nature. - Abraham Lincoln': 1,
#   'If all our misfortunes were laid in one common heap, whence everyone must take an equal portion, most people would be content to take their own and depart. - Socrates': 1,
#   'Government is not a solution to our problem, government is the problem. - Ronald Reagan': 1},
#  'days': {'How we spend our days is, of course, how we spend our lives. - Annie Dillard': 1,
#   'You don`t have to stay up nights to succeed; you have to stay awake days. - Author Unknown': 1,
#   'Beauty is all very well at first sight; but whoever looks at it when it has been in the house three days? - George Bernard Shaw': 1,
#   'Back in the old days, most families were close-knit. Grown children and their parents continued to live together, under the same roof, sometimes in the same small, crowded room, year in and year out, until they died, frequently by strangulation. - Dave Barry': 1,
#   'Happy, happy Christmas, that can win us back to the delusions of our childhood days, recall to the old man the pleasures of his youth, and transport the traveler back to his own fireside and quiet home! - Charles Dickens': 1,
#   'The days of looking the other way while despotic regimes trample human rights, rob their nations` wealth, and then excuse their failings by feeding their people a steady diet of anti-Western hatred are over. - Dick Cheney': 1,
#   'When you work seven days a week, fourteen hours a day, you get lucky. - Armand Hammer': 1,
#   'There are perhaps no days of our childhood we lived so fully as those we spent with a favorite book. - Marcel Proust': 1,
#   'Goldie and I did have a car stolen right out of our yard. It took us three days to notice. - Kurt Russell': 1},
#  'is': {'How we spend our days is, of course, how we spend our lives. - Annie Dillard': 1,
#   'What is happiness? The feeling that power is growing, that resistance is overcome. - Friedrich Nietzsche': 3,
#   'A great deal of intelligence can be invested in ignorance when the need for illusion is deep. - Saul Bellow': 1,
#   'It is necessary for the welfare of society that genius should be privileged to utter sedition, to blaspheme, to outrage good taste, to corrupt the youthful mind, and generally to scandalize one`s uncles. - George Bernard Shaw': 1,
#   'Freedom is not something that anybody can be given; freedom is something people take and people are as free as they want to be. - James Baldwin': 2,
#   'Collecting more taxes than is absolutely necessary is legalized robbery. - Calvin Coolidge': 2,
#   'My dream is of a place and a time where America will once again be seen as the last best hope of earth. - Abraham Lincoln': 1,
#   'An actor is at most a poet and at least an entertainer. - Marlon Brando': 1,
#   'Humility is the foundation of all the other virtues hence, in the soul in which this virtue does not exist there cannot be any other virtue except in mere appearance. - Saint Augustine': 1,
#   'The object of teaching a child is to enable him to get along without a teacher. - Elbert Hubbard': 1,
#   'There can be no liberty unless there is economic liberty. - Margaret Thatcher': 1,
#   'Idealism is fine, but as it approaches reality, the costs become prohibitive. - William F. Buckley': 1,
#   'Most modern freedom is at root fear. It is not so much that we are too bold to endure rules; it is rather that we are too timid to endure responsibilities. - GK Chesterton': 3,
#   'Television is a medium of entertainment which permits millions of people to listen to the same joke at the same time, and yet remain lonesome. - T.S. Eliot': 1,
#   'In any fairly large and talkative community such as a university there is always the danger that those who think alike should gravitate together where they will henceforth encounter opposition only in the emasculated form of rumour that the outsiders say thus and thus. The absent are easily refuted, complacent dogmatism thrives, and differences of opinion are embittered by the group hostility. Each group hears not the best, but the worst, that the other group can say. - C.S. Lewis': 1,
#   'Advertising is the life of trade. - Calvin Coolidge': 1,
#   'Christmas can be celebrated in the school room with pine trees, tinsel and reindeers, but there must be no mention of the man whose birthday is being celebrated. One wonders how a teacher would answer if a student asked why it was called Christmas. - Ronald Reagan': 1,
#   'Experience is that marvelous thing that enables you to recognize a mistake when you make it again. - Franklin Jones': 1,
#   'Originality is the fine art of remembering what you hear but forgetting where you heard it. - Laurence Peter': 1,
#   'I have often wondered how it is that every man loves himself more than all the rest of men, but yet sets less value on his own opinion of himself than on the opinion of others. - Marcus Aurelius': 1,
#   'In every man`s heart there is a secret nerve that answers to the vibrations of beauty. - Christopher Morley': 1,
#   'The only reason for time is so that everything doesn`t happen at once. - Albert Einstein': 1,
#   'The fool doth think he is wise, but the wise man knows himself to be a fool. - William Shakespeare': 1,
#   'Life is what happens to you while you`re busy making other plans. - John Lennon': 1,
#   'Demoralize the enemy from within by surprise, terror, sabotage, assassination. This is the war of the future. - Adolf Hitler': 1,
#   'What sunshine is to flowers, smiles are to humanity. These are but trifles, to be sure; but scattered along life`s pathway, the good they do is inconceivable. - Joseph Addison': 2,
#   'Life is not a support system for art. It`s the other way around. - Stephen King': 1,
#   'Love is the delightful interval between meeting a beautiful girl and discovering that she looks like a haddock. - John Barrymore': 1,
#   'The supernatural is the natural not yet understood. - Elbert Hubbard': 1,
#   'Nothing separates the generations more than music. By the time a child is eight or nine, he has developed a passion for his own music that is even stronger than his passions for procrastination and weird clothes. - Bill Cosby': 2,
#   'The hour of departure has arrived, and we go our ways - I to die, and you to live. Which is better God only knows. - Plato': 1,
#   'All men are frauds. The only difference between them is that some admit it. I myself deny it. - Henry Mencken': 1,
#   'America is not like a blanket: one piece of unbroken cloth, the same color, the same texture, the same size. America is more like a quilt: many patches, many pieces, many colors, many sizes, all woven and held together by a common thread. - Jesse Jackson': 2,
#   'In any moment of decision, the best thing you can do is the right thing. The worst thing you can do is nothing. - Theodore Roosevelt': 2,
#   'Self-denial is the shining sore on the leprous body of Christianity. - Oscar Wilde': 1,
#   'He who is not courageous enough to take risks will accomplish nothing in life. - Muhammad Ali': 1,
#   'He that fights and runs away, may turn and fight another day; but he that is in battle slain, will never rise to fight again. - Tacitus': 1,
#   'Poetry is the art of creating imaginary gardens with real toads. - Marianne Moore': 1,
#   'It is by the goodness of God that, in this country, we have three benefits: freedom of speech, freedom of thought, and the wisdom never to use either. - Mark Twain': 1,
#   'The Bible is not my book, and Christianity is not my religion. I could never give assent to the long, complicated statements of Christian dogma. - Abraham Lincoln': 2,
#   'The truth is always a trick to those who live among lies. - Author Unknown': 1,
#   'All glory is fleeting. - George Patton': 1,
#   'Washington is a city of Southern efficiency and Northern charm. - John F. Kennedy': 1,
#   'Not only is there no God, but try finding a plumber on Sunday. - Woody Allen': 1,
#   'Science without religion is lame, religion without science is blind. - Albert Einstein': 2,
#   'Genius may have its limitations, but stupidity is not thus handicapped. - Elbert Hubbard': 1,
#   'If we do not help a man in trouble, it is as if we caused the trouble. - Nachman of Bratslav': 1,
#   'Patience is the companion of wisdom. - Saint Augustine': 1,
#   'Marriage is our last, best chance to grow up. - Joseph Barth': 1,
#   'Patriotism is not short, frenzied outbursts of emotion, but the tranquil and steady dedication of a lifetime. - Adlai Stevenson': 1,
#   'A man`s very highest moment is, I have no doubt at all, when he kneels in the dust, and beats his breast, and tells all the sins of his life. - Oscar Wilde': 1,
#   'Beauty is all very well at first sight; but whoever looks at it when it has been in the house three days? - George Bernard Shaw': 1,
#   'To assert that the earth revolves around the sun is as erroneous as to claim that Jesus was not born of a virgin. - Cardinal Bellarmine': 1,
#   'Reality is that which, when you stop believing in it, doesn`t go away. - Phillip K. Dick': 1,
#   'Deliberation and debate is the way you stir the soul of our democracy. - Jesse Jackson': 1,
#   'Nothing noble is done without risk. - André Gide': 1,
#   'Fatherhood is pretending the present you love most is soap on-a-rope. - Bill Cosby': 2,
#   'No nation keeps its word. A nation is a big, blind worm, following what? Fate perhaps. A nation has no honor, it has no word to keep. - Carl Jung': 1,
#   'Women are the only realists; their whole object in life is to pit their realism against the extravagant, excessive, and occasionally drunken idealism of men. - GK Chesterton': 1,
#   'Man is the only animal that blushes - or needs to. - Mark Twain': 1,
#   'Any reviewer who expresses rage and loathing for a novel is preposterous. He or she is like a person who has put on full armor and attacked a hot fudge sundae. - Kurt Vonnegut': 2,
#   'There is no substitute for hard work. - Thomas Edison': 1,
#   'She is not perfect. You are not perfect. The question is whether or not you are perfect for each other. - Robin Williams': 2,
#   'Government is not reason; it is not eloquent; it is force. Like fire, it is a dangerous servant and a fearful master. - George Washington': 4,
#   'Let us not forget that the cultivation of the earth is the most important labor of man. When tillage begins, other arts will follow. The farmers, therefore, are the founders of civilization. - Daniel Webster': 1,
#   'A right delayed is a right denied. - Martin Luther King Jr.': 1,
#   'Everything is simpler than you think and at the same time more complex than you imagine. - Johann Wolfgang von Goethe': 1,
#   'The world is full of suffering. It is also full of overcoming it. - Helen Keller': 2,
#   'Love is repaid by love alone! - Mother Teresa': 1,
#   'The only way to keep your health is to eat what you don`t want, drink what you don`t like, and do what you`d rather not. - Mark Twain': 1,
#   'It behooves every man to remember that the work of the critic is of altogether secondary importance, and that, in the end, progress is accomplished by the man who does things. - Theodore Roosevelt': 2,
#   'It is error alone which needs the support of government. Truth can stand by itself. - Thomas Jefferson': 1,
#   'Fame is a fickle food upon a shifting plate. - Emily Dickinson': 1,
#   'Philosophy is to the real world as masturbation is to sex. - Karl Marx': 2,
#   'It is always thus, impelled by a state of mind which is destined not to last, that we make our irrevocable decisions. - Marcel Proust': 2,
#   'Love anything and your heart will be wrung and possibly broken. If you want to make sure of keeping it intact you must give it to no one, not even an animal. Wrap it carefully round with hobbies and little luxuries; avoid all entanglements. Lock it up safe in the casket or coffin of your selfishness. But in that casket, safe, dark, motionless, airless, it will change. It will not be broken; it will become unbreakable, impenetrable, irredeemable. To love is to be vulnerable. - C.S. Lewis': 1,
#   'To explain the unknown by the known is a logical procedure; to explain the known by the unknown is a form of theological lunacy. - David Brooks': 2,
#   'We ascribe beauty to that which is simple; which has no superfluous parts; which exactly answers its end; which stands related to all things; which is the mean of many extremes. - Ralph Waldo Emerson': 2,
#   'Christmas is a time when you get homesick, even when you`re home. - Carol Nelson': 1,
#   'We all wish to be judged by our peers, by the men `after our own heart.` Only they really know our mind and only they judge it by standards we fully acknowledge. Theirs is the praise we really covet and the blame we really dread. The little pockets of early Chrstians survived because they cared exclusively for the love of `the bretheren` and stopped their ears to the opinion of the Pagan society around them. But a circle of criminals, cranks, or perverts survives in just the same way; by becoming deaf to the opinion of the outer world, by discounting it as the chatter of outsiders who `don`t understand,` of the `conventional,` the `bourgeois,` the `Establishment,` of prigs, prudes, and humbugs. - C.S. Lewis': 1,
#   'A free society is one where it is safe to be unpopular. - Adlai Stevenson': 2,
#   'If variety is the spice of life, marriage is the big can of leftover Spam. - Johnny Carson': 2,
#   'A mind that is stretched by a new experience can never go back to its old dimensions. - Oliver Wendell Holmes': 1,
#   'If there is any principle of the Constitution that more imperatively calls for attachment than any other it is the principle of free thought, not free thought for those who agree with us but freedom for the thought that we hate. - Oliver Wendell Holmes': 2,
#   'All art is but imitation of nature. - Lucius Annaeus Seneca': 1,
#   'Heroism is not only in the man, but in the occasion. - Calvin Coolidge': 1,
#   'Nothing is wrong with Southern California that a rise in the ocean level wouldn`t cure. - Kenneth Millar': 1,
#   'A `geek` by definition is someone who eats live animals....I`ve never eaten live animals. - Crispin Glover': 1,
#   'Politics is perhaps the only profession for which no preparation is thought necessary. - Robert Louis Stevenson': 2,
#   'The only kind of seafood I trust is the fish stick, a totally featureless fish that doesn`t have eyeballs or fins. - Dave Barry': 1,
#   'Skepticism is a virtue in history as well as in philosophy. - Napoleon Bonaparte': 1,
#   'After silence, that which comes nearest to expressing the inexpressible is Music. - Aldous Huxley': 1,
#   'To one who has faith, no explanation is necessary. To one without faith, no explanation is possible. - Thomas Aquinas': 2,
#   'Thinking is the hardest work there is, which is the probable reason why so few engage in it. - Henry Ford': 3,
#   'The first principle is that you must not fool yourself - and you are the easiest person to fool. - Richard P. Feynman': 1,
#   'Anyone who invokes authors in discussion is not using his intelligence but his memory. - Leonardo da Vinci': 1,
#   'There is no glory in battle worth the blood it costs. - Dwight Eisenhower': 1,
#   'Being born is like being kidnapped. And then sold into slavery. - Andy Warhol': 1,
#   'The magic of first love is our ignorance that it can never end. - Benjamin Disraeli': 1,
#   'Without computers, the government would be unable to function at the level of effectiveness and efficiency that we have come to expect.  This is because the primary function of the government is -- and here I am quoting directly from the U.S. Constitution -- `to spew out paper.` - Dave Barry': 2,
#   'There are several good protections against temptation, but the surest is cowardice. - Mark Twain': 1,
#   'A Native American elder once described his own inner struggles in this manner: Inside of me there are two dogs. One of the dogs is mean and evil. The other dog is good. The mean dog fights the good dog all the time. When asked which dog wins, he reflected. - George Bernard Shaw': 2,
#   'Surely what a man does when he is caught off his guard is the best evidence as to what sort of man he is. - C.S. Lewis': 3,
#   'For each illness that doctors cure with medicine, they provoke ten in healthy people by inoculating them with the virus that is a thousand times more powerful than any microbe: the idea that one is ill. - Marcel Proust': 2,
#   'When I took office, only high energy physicists had ever heard of what is called the Worldwide Web....now even my cat has its own page. - Bill Clinton': 1,
#   'Of all the animals, man is the only one that lies. - Mark Twain': 1,
#   'The greatest thing in this world is not so much where we are, but in what direction we are moving. - Oliver Wendell Holmes': 1,
#   'How did it get so late so soon? It`s night before it`s afternoon. December is here before it`s June. My goodness how the time has flewn. How did it get so late so soon? - Theodor Seuss Geisel': 1,
#   'Humor is mankind`s greatest blessing. - Mark Twain': 1,
#   'The surest way of spoiling a pleasure is to start examining your satisfaction. - C.S. Lewis': 1,
#   'Bashfulness is an ornament to youth, but a reproach to old age. - Aristotle': 1,
#   'The philosophy of one century is the common sense of the next. - Henry Ward Beecher': 1,
#   'The MPAA rates this PG-13. It is too vulgar for anyone under 13, and too dumb for anyone over 13. - Roger Ebert': 1,
#   'Dying is the most embarrassing thing that can ever happen to you, because someone`s got to take care of all your details. - Andy Warhol': 1,
#   'It has been said that man is a rational animal. All my life I have been searching for evidence which could support this. - Bertrand Russell': 1,
#   'Of course the people dont want war...that is understood. But voice or no voice, the people can always be brought to the bidding of the leaders. That is easy. All you have to do is tell them they are being attacked, and denounce the pacifists for lack of patriotism and exposing the country to danger. It works the same in any country. - Hermann Goering': 3,
#   'One thing they never tell you about child raising is that for the rest of your life, at the drop of a hat, you are expected to know your child`s name and how old he or she is. - Erna Bombeck': 2,
#   'If we have no peace, it is because we have forgotten that we belong to each other. - Mother Teresa': 1,
#   'I think it`s the duty of the comedian to find out where the line is drawn and cross it deliberately. - George Carlin': 1,
#   'Nothing in the world is more dangerous than sincere ignorance and conscientious stupidity. - Martin Luther King Jr.': 1,
#   'If a man is called to be a streetsweeper, he should sweep streets even as Michelangelo painted, or Beethoven composed music, or Shakespeare wrote poetry. He should sweep streets so well that all the host of heaven and earth will pause to say, here lived a great streetsweeper who did his job well. - Martin Luther King Jr.': 1,
#   'There is a great deal of difference between an eager man who wants to read a book and the tired man who wants a book to read. - GK Chesterton': 1,
#   'Forever is composed of nows. - Emily Dickinson': 1,
#   'Man`s best possession is a sympathetic wife. - Euripides': 1,
#   'Laughter is the sun that drives winter from the human face. - Victor Hugo': 1,
#   'If I feel physically as if the top of my head were taken off, I know that is poetry. - Emily Dickinson': 1,
#   'Love is a fruit in season at all times, and within reach of every hand. - Mother Teresa': 1,
#   'Having someone wonder where you are when you don`t come home at night is a very old human need. - Margaret Mead': 1,
#   'I think the best possible social program is a job. - Ronald Reagan': 1,
#   'Moral indignation is jealousy with a halo. - H.G. Wells': 1,
#   'Information is not knowledge. - Albert Einstein': 1,
#   'The price of greatness is responsibility. - Winston Churchill': 1,
#   'There is hope for the future because God has a sense of humor and we are funny to God. - Bill Cosby': 1,
#   'The mind of the thoroughly well-informed man is a dreadful thing. It is like a bric-à-brac shop, all monsters and dust, with everything priced above its proper value. - Oscar Wilde': 2,
#   'On the plus side, death is one of the few things that can be done just as easily lying down. - Woody Allen': 1,
#   'Imagination is a quality given a man to compensate him for what he is not, and a sense of humor was provided to console him for what he is. - Oscar Wilde': 3,
#   'You can`t depend on your eyes when your imagination is out of focus. - Mark Twain': 1,
#   'Let us now set forth one of the fundamental truths about marriage: the wife is in charge. - Bill Cosby': 1,
#   'If a man is proud of his wealth, he should not be praised until it is known how he employs it. - Socrates': 2,
#   'There is a theory which states that if ever anyone discovers exactly what the Universe is for and why it is here, it will instantly disappear and be replaced by something even more bizarre and inexplicable. There is another theory which states that this has already happened. - Douglas Adams': 4,
#   'I don`t care what is written about me, so long as it isn`t true. - Dorothy Parker': 1,
#   'I always cheer up immensely if an attack is particularly wounding because I think, well, if they attack one personally, it means they have not a single political argument left. - Margaret Thatcher': 1,
#   'Observe constantly that all things take place by change, and accustom thyself to consider that the nature of the Universe love nothing so much as to change. The Universe is change. - Marcus Aurelius': 1,
#   'Since love grows within you, so beauty grows. For love is the beauty of the soul. - Saint Augustine': 1,
#   'Freedom is the right to question and change the established way of doing things. It is the continuous revolution of the marketplace. It is the understanding that allows us to recognize shortcomings and seek solutions. - Ronald Reagan': 3,
#   'There is time for everything. - Thomas Edison': 1,
#   'There are no secrets to success. It is the result of preparation, hard work, and learning from failure. - Colin Powell': 1,
#   'The movie`s director is the pilot. It`s his vision. For an actor, the time to worry about flying is when you`re on the ground. If you don`t want to fly with the director, don`t get on the plane. - Denzel Washington': 2,
#   'My aim is to put down on paper what I see and what I feel in the best and simplest way. - Ernest Hemingway': 1,
#   'Analyzing humor is like dissecting a frog. Few people are interested and the frog dies of it. - E.B. White': 1,
#   'The ACLU is always yakking about the Constitution, and most of us are getting mighty tired of it. I mean, if the Constitution is so great, how come it was amended so many times? Huh? - Dave Barry': 2,
#   'One definition of an economist is somebody who sees something happen in practice and wonders if it will work in theory. - Ronald Reagan': 1,
# ...
#  'politics': {'In politics shared hatreds are almost always the basis of friendships. - Alexis de Tocqueville': 1,
#   'Politics is perhaps the only profession for which no preparation is thought necessary. - Robert Louis Stevenson': 1,
#   'Politics has got so expensive that it takes lots of money to even get beat with. - Will Rogers': 1,
#   'In politics, if you want anything said, ask a man; if you want anything done, ask a woman. - Margaret Thatcher': 1,
#   'A typical vice of American politics is the avoidance of saying anything real on real issues. - Theodore Roosevelt': 1,
#   'PRESIDENCY, n. The greased pig in the field game of American politics. - Ambrose Bierce': 1,
#   'In politics, an organized minority is a political majority. - Jesse Jackson': 1},
#  'shared': {'In politics shared hatreds are almost always the basis of friendships. - Alexis de Tocqueville': 1},
#  'hatreds': {'In politics shared hatreds are almost always the basis of friendships. - Alexis de Tocqueville': 1},
#  'basis': {'In politics shared hatreds are almost always the basis of friendships. - Alexis de Tocqueville': 1},
#  'friendships': {'In politics shared hatreds are almost always the basis of friendships. - Alexis de Tocqueville': 1},
#  'de': {'In politics shared hatreds are almost always the basis of friendships. - Alexis de Tocqueville': 1,
#   'Americans are so enamored of equality, they would rather be equal in slavery than unequal in freedom. - Alexis de Tocqueville': 1,
#   'The last thing a political party gives up is its vocabulary. - Alexis de Tocqueville': 1,
#   'The health of a democratic society may be measured by the quality of functions performed by private citizens. - Alexis de Tocqueville': 1,
#   'What is the most important for democracy is not that great fortunes should not exist, but that great fortunes should not remain in the same hands. In that way there are rich men, but they do not form a class. - Alexis de Tocqueville': 1,
#   'There is hardly a political question in the United States which does not sooner or later turn into a judicial one. - Alexis de Tocqueville': 1,
#   'The whole life of an American is passed like a game of chance, a revolutionary crisis, or a battle. - Alexis de Tocqueville': 1,
#   'It is the dissimilarities and inequalities among men which give rise to the notion of honor; as such differences become less, it grows feeble; and when they disappear, it will vanish too. - Alexis de Tocqueville': 1,
#   'The surface of American society is covered with a layer of democratic paint, but from time to time one can see the old aristocratic colours breaking through. - Alexis de Tocqueville': 1},
#  'tocqueville': {'In politics shared hatreds are almost always the basis of friendships. - Alexis de Tocqueville': 1,
#   'Americans are so enamored of equality, they would rather be equal in slavery than unequal in freedom. - Alexis de Tocqueville': 1,
#   'The last thing a political party gives up is its vocabulary. - Alexis de Tocqueville': 1,
#   'The health of a democratic society may be measured by the quality of functions performed by private citizens. - Alexis de Tocqueville': 1,
#   'What is the most important for democracy is not that great fortunes should not exist, but that great fortunes should not remain in the same hands. In that way there are rich men, but they do not form a class. - Alexis de Tocqueville': 1,
#   'There is hardly a political question in the United States which does not sooner or later turn into a judicial one. - Alexis de Tocqueville': 1,
#   'The whole life of an American is passed like a game of chance, a revolutionary crisis, or a battle. - Alexis de Tocqueville': 1,
#   'It is the dissimilarities and inequalities among men which give rise to the notion of honor; as such differences become less, it grows feeble; and when they disappear, it will vanish too. - Alexis de Tocqueville': 1,
#   'The surface of American society is covered with a layer of democratic paint, but from time to time one can see the old aristocratic colours breaking through. - Alexis de Tocqueville': 1},
#  'limitations': {'Genius may have its limitations, but stupidity is not thus handicapped. - Elbert Hubbard': 1},
#  'stupidity': {'Genius may have its limitations, but stupidity is not thus handicapped. - Elbert Hubbard': 1,
#   'Nothing in the world is more dangerous than sincere ignorance and conscientious stupidity. - Martin Luther King Jr.': 1,
#   'I hate war as only a soldier who has lived it can, only as one who has seen its brutality, its futility, its stupidity. - Dwight Eisenhower': 1,
#   'The difference between genius and stupidity is that genius has its limits. - Albert Einstein': 1},
#  'handicapped': {'Genius may have its limitations, but stupidity is not thus handicapped. - Elbert Hubbard': 1},
#  'moves': {'In life, as in art, the beautiful moves in curves. - Edward Bulwer-Lytton': 1},
#  'curves': {'In life, as in art, the beautiful moves in curves. - Edward Bulwer-Lytton': 1},
#  'edward': {'In life, as in art, the beautiful moves in curves. - Edward Bulwer-Lytton': 1},
#  'bulwer': {'In life, as in art, the beautiful moves in curves. - Edward Bulwer-Lytton': 1},
#  'lytton': {'In life, as in art, the beautiful moves in curves. - Edward Bulwer-Lytton': 1},
#  'planted': {'I planted some bird seed. A bird came up. Now I don`t know what to feed it. - Steven Wright': 1,
#   'A radical is a man with both feet firmly planted in the air. - Franklin D. Roosevelt': 1},
#  'bird': {'I planted some bird seed. A bird came up. Now I don`t know what to feed it. - Steven Wright': 2},
#  'seed': {'I planted some bird seed. A bird came up. Now I don`t know what to feed it. - Steven Wright': 1},
#  'came': {'I planted some bird seed. A bird came up. Now I don`t know what to feed it. - Steven Wright': 1,
#   'I had a dream the other night. I dreamed that Jimmy Carter came to me and asked why I wanted his job. I told him I didn`t want his job. I want to be President. - Ronald Reagan': 1,
#   'How did it happen that their lips came together? How does it happen that birds sing, that snow melts, that the rose unfolds, that the dawn whitens behind the stark shapes of trees on the quivering summit of the hill? A kiss, and all was said. - Victor Hugo': 1},
#  'now': {'I planted some bird seed. A bird came up. Now I don`t know what to feed it. - Steven Wright': 1,
#   'When I took office, only high energy physicists had ever heard of what is called the Worldwide Web....now even my cat has its own page. - Bill Clinton': 1,
#   'Let us now set forth one of the fundamental truths about marriage: the wife is in charge. - Bill Cosby': 1,
#   'Experts tell us that if the Millennium Bug is not fixed, when the year 2000 arrives, our financial records will be inaccurate, our telephone system will be unreliable, our government will be paralyzed and airline flights will be canceled without warning. In other words, things will be pretty much the same as they are now. - Dave Barry': 1,
#   'What is now proved was once only imagined. - William Blake': 1,
#   'Everything that used to be a sin is now a disease. - Bill Maher': 1,
#   'Some of your countrymen were unable to distinguish between their native dislike for war and the stainless patriotism of those who suffered its scars. But there has been a rethinking and now we can say to you, and say as a nation, thank you for your courage. - Ronald Reagan': 1},
#  'feed': {'I planted some bird seed. A bird came up. Now I don`t know what to feed it. - Steven Wright': 1},
#  'trusts': {'Not everybody trusts paintings, but people believe photographs. - Ansel Adams': 1},
#  'paintings': {'Not everybody trusts paintings, but people believe photographs. - Ansel Adams': 1},
#  'believe': {'Not everybody trusts paintings, but people believe photographs. - Ansel Adams': 1,
#   'I confess, I do not believe in time. - Vladimir Nabokov': 1,
#   'Science is not about building a body of known `facts`. It is a method for asking awkward questions and subjecting them to a reality-check, thus avoiding the human tendency to believe whatever makes us feel good. - Terry Pratchett': 1,
#   'We are all worms, but I do believe I am a glow-worm. - Winston Churchill': 1,
#   'I believe this government cannot endure permanently half slave and half free. - Abraham Lincoln': 1,
#   'This does not mean that the enemy is to be allowed to escape. The object is to make him believe that there is a road to safety, and thus prevent his fighting with the courage of despair. After that, you may crush him. - Sun Tzu': 1,
#   'Of course I don`t believe in it. But I understand that it brings you luck whether you believe in it or not. - Niels Bohr': 2,
#   'People can misinterpret almost anything so that it coincides with views they already hold. They take from art what they already believe. - Stanley Kubrick': 1,
#   'I do not believe one can settle how much we ought to give. I am afraid the only safe rule is to give more than we can spare. - C.S. Lewis': 1,
#   'I believe one of the reasons so many do not get a higher education is the fear of their parents that they will lose more morally than they will receive mentally. - William Jennings Bryan': 1,
#   'It is hard to believe that a man is telling the truth when you know that you would lie if you were in his place. - Henry Mencken': 1,
#   'I believe in Christianity as I believe that the sun has risen, not only because I see it, but because by it I see everything else. - C.S. Lewis': 2,
#   'Your faith is what you believe, not what you know. - Mark Twain': 1,
#   'I believe the highest aspiration of man should be individual freedom and the development of the individual. - Ronald Reagan': 1,
#   'I like television. I still believe that television is the most powerful form of communication on Earth -- I just hate what is being done with it. - Alton Brown': 1,
#   'Those who believe they are exclusively in the right are generally those who achieve something. - Aldous Huxley': 1,
#   'That is the true season of love, when we believe that we alone can love, that no one could ever have loved so before us, and that no one will love in the same way after us. - Johann Wolfgang von Goethe': 1},
#  'photographs': {'Not everybody trusts paintings, but people believe photographs. - Ansel Adams': 1},
#  'ansel': {'Not everybody trusts paintings, but people believe photographs. - Ansel Adams': 1,
#   'You don`t take a photograph, you make it. - Ansel Adams': 1},
#  'adams': {'Not everybody trusts paintings, but people believe photographs. - Ansel Adams': 1,
#   'In the beginning, the universe was created. This made a lot of people very angry, and has been widely regarded as a bad idea. - Douglas Adams': 1,
#   'There is a theory which states that if ever anyone discovers exactly what the Universe is for and why it is here, it will instantly disappear and be replaced by something even more bizarre and inexplicable. There is another theory which states that this has already happened. - Douglas Adams': 1,
#   'You don`t take a photograph, you make it. - Ansel Adams': 1,
#   'He therefore is the truest friend to the liberty of this country who tries most to promote its virtue, and who, so far as his power and influence extend, will not suffer a man to be chosen into any office of power and trust who is not a wise and virtuous man. - Samuel Adams': 1,
#   'I love deadlines. I especially like the whooshing sound they make as they go flying by. - Douglas Adams': 1,
#   'It does not require a majority to prevail, but rather an irate, tireless minority keen to set brush fires in people`s minds. - Samuel Adams': 1,
#   'Man [has] always assumed that he was more intelligent than dolphins because he had achieved so much-the wheel, New York, wars and so on-while all the dolphins had ever done was muck about in the water having a good time. But conversely, the dolphins had always believed that they were far more intelligent than man-for precisely the same reason. - Douglas Adams': 1},
#  'destroy': {'The things that will destroy America are prosperity at any price, peace at any price, safety first instead of duty first, the love of soft living and the get rich quick theory of life. - Theodore Roosevelt': 1,
#   'To you taxpayers out there, let me say this: Make sure you file your tax return on time! And remember that, even though income taxes can be a “pain in the neck,” the folks at the IRS are regular people just like you, except that they can destroy your life. - Dave Barry': 1},
#  'prosperity': {'The things that will destroy America are prosperity at any price, peace at any price, safety first instead of duty first, the love of soft living and the get rich quick theory of life. - Theodore Roosevelt': 1},
#  'price': {'The things that will destroy America are prosperity at any price, peace at any price, safety first instead of duty first, the love of soft living and the get rich quick theory of life. - Theodore Roosevelt': 2,
#   'The price of greatness is responsibility. - Winston Churchill': 1,
#   'Even peace may be purchased at too high a price. - Benjamin Franklin': 1},
#  'peace': {'The things that will destroy America are prosperity at any price, peace at any price, safety first instead of duty first, the love of soft living and the get rich quick theory of life. - Theodore Roosevelt': 1,
#   'There are some who`ve forgotten why we have a military. It`s not to promote war; it`s to be prepared for peace. - Ronald Reagan': 1,
#   'If we have no peace, it is because we have forgotten that we belong to each other. - Mother Teresa': 1,
#   'Even peace may be purchased at too high a price. - Benjamin Franklin': 1,
#   'Let him who desires peace prepare for war. - Vegetius': 1,
#   'You know what the fellow said: In Italy for thirty years under the Borgias they had warfare, terror, murder, and bloodshed, but they produced Michaelangelo, Leonardo Da Vinci, and the Renaissance. In Switzerland, they had brotherly love--they had five hundred years of democracy and peace, and what did they produce? The cuckoo clock. - Orson Welles': 1,
#   'Though force can protect in emergency, only justice, fairness, consideration and cooperation can finally lead men to the dawn of eternal peace. - Dwight Eisenhower': 1,
#   'He that would live in peace and at ease must not speak all he knows or all he sees. - Benjamin Franklin': 1,
#   'Parents are not interested in justice, they`re interested in peace and quiet. - Bill Cosby': 1,
#   'Never continue in a job you don`t enjoy. If you`re happy in what you`re doing, you`ll like yourself, you`ll have inner peace. And if you have that, along with physical health, you will have had more success than you could possibly have imagined. - Johnny Carson': 1,
#   'Peace is its own reward. - Mahatma Gandhi': 1,
#   'To be prepared for war is one of the most effectual means of preserving peace. - George Washington': 1},
#  'safety': {'The things that will destroy America are prosperity at any price, peace at any price, safety first instead of duty first, the love of soft living and the get rich quick theory of life. - Theodore Roosevelt': 1,
#   'This does not mean that the enemy is to be allowed to escape. The object is to make him believe that there is a road to safety, and thus prevent his fighting with the courage of despair. After that, you may crush him. - Sun Tzu': 1,
#   'They that can give up essential liberty to obtain a little temporary safety deserve neither liberty nor safety. - Benjamin Franklin': 2},
#  'soft': {'The things that will destroy America are prosperity at any price, peace at any price, safety first instead of duty first, the love of soft living and the get rich quick theory of life. - Theodore Roosevelt': 1,
#   'Money can help you to get medicines but not health. Money can help you to get soft pillows, but not sound sleep. Money can help you to get material comforts, but not eternal bliss. Money can help you to get ornaments, but not beauty. Money will help you to get an electric earphone, but not natural hearing. Attain the supreme wealth, wisdom, and you will have everything. - Benjamin Franklin': 1},
#  ...}

# %% [markdown]
# #### (e) Writing a TF-IDF function
# To measure how much a full
# quote is about a particular word, one typically uses the TF-IDF measure.
# >• TF stands for “term frequency”; the term frequency of a word w in
# a full quote q is the number of times w occurs in q, divided by the
# maximum number of times any word occurs in q. <br>
# • IDF stands for “inverse document frequency”: the IDF of a word w is
# the logarithm of the ratio of the total number N of full quotes to the
# number of full quotes in that contain the word w. <br>
# • TF-IDF of a word w for a full quote q is just the product of the TF
# and IDF. <br>
# The function tf_idf computes the TF-IDF of any word in any full quote,
# using the postings and reverse-postings.<br>

# %%
number_of_quotes = len(list_of_quotes)

def tf_idf(word, quote):
    
    '''
    A function to calculate TF-IDF value for a word-quote pair
    
    Parameters:
    word (str), quote (str): A word and a full quote as input
    
    Returns:
    The TF-IDF for the word-quote pair
    '''
    
    if word in words_in_quote(quote):
        tf = reverse_postings_list[word][quote]/max(postings_list[quote].values())
    
        idf = math.log(number_of_quotes/len(reverse_postings_list[word].keys()))
    
        tf_idf_value = tf * idf
    else:
        return 0
    
    return tf_idf_value

# %%
tf_idf('entertainer', 'An actor is at most a poet and at least an entertainer. - Marlon Brando')
# Out:
# 3.3933584753025405

# %% [markdown]
# #### (f) Quote search using a single word
# The function tf_idf_dictionary takes a word as argument, and returns a dictionary whose keys are full
# quotes containing that word, and whose values are the TF-IDF score of that
# word for that full quote. <br>

# %%
def tf_idf_dictionary(word):
    
    '''
    A function to create a dictionary with keys as full quotes containing input word, 
    and whose values are the TF-IDF score of that word for that full quote.
    
    Parameters:
    word (str) : A word for which the dictionary needs to be created
    
    Returns:
    A dictionary key keys as full quotes containing the word, values are TF-IDF score for the word-quote combination
    '''
    
    dictionary = {}
    
    for keys in reverse_postings_list[word].keys():
        
        dictionary[keys] = tf_idf(word,keys)     
        
    return dictionary

# %%
tf_idf_dictionary('how')
# Out:
# {'How we spend our days is, of course, how we spend our lives. - Annie Dillard': 3.742194512881658,
#  'Christmas can be celebrated in the school room with pine trees, tinsel and reindeers, but there must be no mention of the man whose birthday is being celebrated. One wonders how a teacher would answer if a student asked why it was called Christmas. - Ronald Reagan': 1.871097256440829,
#  'I have often wondered how it is that every man loves himself more than all the rest of men, but yet sets less value on his own opinion of himself than on the opinion of others. - Marcus Aurelius': 1.2473981709605526,
#  'It`s not how old you are, it`s how hard you work at it. - Jonah Barrington': 3.742194512881658,
#  'No matter how much cats fight, there always seem to be plenty of kittens. - Abraham Lincoln': 3.742194512881658,
#  'Success, the real success, does not depend upon the position you hold but upon how you carry yourself in that position. - Theodore Roosevelt': 1.871097256440829,
#  'Never discourage anyone who continually makes progress, no matter how slow. - Plato': 3.742194512881658,
#  'True wisdom comes to each of us when we realize how little we understand about life, ourselves, and the world around us. - Socrates': 1.871097256440829,
#  'How did it get so late so soon? It`s night before it`s afternoon. December is here before it`s June. My goodness how the time has flewn. How did it get so late so soon? - Theodor Seuss Geisel': 2.8066458846612434,
#  'One thing they never tell you about child raising is that for the rest of your life, at the drop of a hat, you are expected to know your child`s name and how old he or she is. - Erna Bombeck': 1.871097256440829,
#  'If a man is proud of his wealth, he should not be praised until it is known how he employs it. - Socrates': 1.871097256440829,
#  'We`ve got to live. No matter how many skies have fallen. - D.H. Lawrence': 3.742194512881658,
#  'The ACLU is always yakking about the Constitution, and most of us are getting mighty tired of it. I mean, if the Constitution is so great, how come it was amended so many times? Huh? - Dave Barry': 1.2473981709605526,
#  'Many of life`s failures are people who did not realize how close they were to success when they gave up. - Thomas Edison': 1.871097256440829,
#  'How did it happen that their lips came together? How does it happen that birds sing, that snow melts, that the rose unfolds, that the dawn whitens behind the stark shapes of trees on the quivering summit of the hill? A kiss, and all was said. - Victor Hugo': 1.4968778051526632,
#  'My role in society, or any artist`s or poet`s role, is to try and express what we all feel. Not to tell people how to feel. Not as a preacher, not as a leader, but as a reflection of us all. - John Lennon': 1.2473981709605526,
#  'Our nettlesome task is to discover how to organize our strength into compelling power. - Martin Luther King Jr.': 1.871097256440829,
#  'I do not believe one can settle how much we ought to give. I am afraid the only safe rule is to give more than we can spare. - C.S. Lewis': 1.871097256440829,
#  'There is no question that there is an unseen world. The problem is, how far is it from midtown and how late is it open? - Woody Allen': 1.4968778051526632,
#  'It`s not how much we give but how much love we put into giving. - Mother Teresa': 3.742194512881658,
#  'All children are artists. The problem is how to remain an artist once he grows up. - Pablo Picasso': 3.742194512881658}

# %% [markdown]
# #### (g) Quote search using multiple words
# The function word_dictionary takes a list of words as argument, and returns a dictionary whose keys
# are full quotes containing one or more of the words in that list, and whose
# values are the sum of TF-IDF scores of the words in that list for that full
# quote

# %%
def word_dictionary(list_of_words):
    
    '''
    A function that creates a dictionary whose keys are full quotes containing one or more of the words in the input list
    and whose values are the sum of TF-IDF scores of the words in that list for that full quote.
    
    Parameters:
    list_of_words (list): A list of words
    
    Returns:
    A dictionary with quotes as keys that contain one or more words from the list and 
    value is the sum of the TF-IDF score of the words from the input list that occur in the quote
    '''
    
    dictionary = {}
    
    for quote in list_of_quotes:
        tf_idf_value = 0
        
        quote_words = words_in_quote(quote)
        
        for word in quote_words:
            if word in list_of_words:
                tf_idf_value += tf_idf(word,quote)
            
            dictionary[quote] = tf_idf_value 
            
    final_dictionary = {k: v for k, v in dictionary.items() if v>0}
            
    return final_dictionary

# %%
val = word_dictionary(['heart', 'mind', 'disease'])
val
# Out:
# {'The heart has its reasons, of which the mind knows nothing. - Blaise Pascal': 4.281399303556952,
#  'It is necessary for the welfare of society that genius should be privileged to utter sedition, to blaspheme, to outrage good taste, to corrupt the youthful mind, and generally to scandalize one`s uncles. - George Bernard Shaw': 0.8157333499005741,
#  'In every man`s heart there is a secret nerve that answers to the vibrations of beauty. - Christopher Morley': 4.484131857611035,
#  'Everybody can be great... because anybody can serve. You don`t have to have a college degree to serve. You don`t have to make your subject and verb agree to serve. You only need a heart full of grace. A soul generated by love. - Martin Luther King Jr.': 1.1210329644027588,
#  'It is always thus, impelled by a state of mind which is destined not to last, that we make our irrevocable decisions. - Marcel Proust': 2.0393333747514353,
#  'Love anything and your heart will be wrung and possibly broken. If you want to make sure of keeping it intact you must give it to no one, not even an animal. Wrap it carefully round with hobbies and little luxuries; avoid all entanglements. Lock it up safe in the casket or coffin of your selfishness. But in that casket, safe, dark, motionless, airless, it will change. It will not be broken; it will become unbreakable, impenetrable, irredeemable. To love is to be vulnerable. - C.S. Lewis': 0.640590265373005,
#  'We all wish to be judged by our peers, by the men `after our own heart.` Only they really know our mind and only they judge it by standards we fully acknowledge. Theirs is the praise we really covet and the blame we really dread. The little pockets of early Chrstians survived because they cared exclusively for the love of `the bretheren` and stopped their ears to the opinion of the Pagan society around them. But a circle of criminals, cranks, or perverts survives in just the same way; by becoming deaf to the opinion of the outer world, by discounting it as the chatter of outsiders who `don`t understand,` of the `conventional,` the `bourgeois,` the `Establishment,` of prigs, prudes, and humbugs. - C.S. Lewis': 0.6116284719367076,
#  'A mind that is stretched by a new experience can never go back to its old dimensions. - Oliver Wendell Holmes': 2.0393333747514353,
#  'The mind of the thoroughly well-informed man is a dreadful thing. It is like a bric-à-brac shop, all monsters and dust, with everything priced above its proper value. - Oscar Wilde': 2.0393333747514353,
#  'I will honor Christmas in my heart, and try to keep it all the year. - Charles Dickens': 4.484131857611035,
#  'Show me your hands. Do they have scars from giving? Show me your feet. Are they wounded in service? Show me your heart. Have you left a place for divine love? - Fulton J. Sheen': 1.4947106192036783,
#  '`Tis the business of little minds to shrink, but he whose heart is firm, and whose conscience approves his conduct, will pursue his principles unto death. - Thomas Paine': 2.2420659288055176,
#  'No passion so effectually robs the mind of all its powers of acting and reasoning as fear. - Edmund Burke': 2.0393333747514353,
#  'Too many poets delude themselves by thinking that the mind is dangerous and must be left out. Well, the mind is dangerous and must be left in. - Robert Frost': 8.157333499005741,
#  'It is your mind that creates this world. - Siddhartha Buddha': 4.078666749502871,
#  'As every divided kingdom falls, so every mind divided between many studies confounds and saps itself. - Leonardo da Vinci': 2.0393333747514353,
#  'Everything that used to be a sin is now a disease. - Bill Maher': 3.3933584753025405,
#  'My mind is my own church. - Thomas Paine': 2.0393333747514353,
#  'The best and most beautiful things in the world cannot be seen or even touched. They must be felt with the heart. - Helen Keller': 1.4947106192036783,
#  'What we are today comes from our thoughts of yesterday and our present thoughts build our life tomorrow. Our life is the creation of our mind. - Siddhartha Buddha': 0.8157333499005741,
#  'Beauty is ever to the lonely mind a shadow fleeting; she is never plain. She is a visitor who leaves behind the gift of grief, the souvenir of pain. - Christopher Morley': 1.3595555831676234,
#  'What a man`s mind can create, man`s character can control. - Thomas Edison': 2.0393333747514353,
#  'The mystic chords of memory, stretching from every battlefield and patriot grave to every living heart and hearthstone all over this broad land, will yet swell the chorus of the Union, when again touched, as surely they will be, by the better angels of our nature. - Abraham Lincoln': 1.1210329644027588,
#  'Games lubricate the body and the mind. - Benjamin Franklin': 2.0393333747514353}

# %%
quote = 'We all wish to be judged by our peers, by the men `after our own heart.` Only they really know our mind and only they judge it by standards we fully acknowledge. Theirs is the praise we really covet and the blame we really dread. The little pockets of early Chrstians survived because they cared exclusively for the love of `the bretheren` and stopped their ears to the opinion of the Pagan society around them. But a circle of criminals, cranks, or perverts survives in just the same way; by becoming deaf to the opinion of the outer world, by discounting it as the chatter of outsiders who `don`t understand,` of the `conventional,` the `bourgeois,` the `Establishment,` of prigs, prudes, and humbugs. - C.S. Lewis'
print(f'Value of the quote in the dictionary: {val[quote]}')

print(f'TF-IDF of disease in the quote: {tf_idf("disease",quote)}')
print(f'TF-IDF of heart in the quote: {tf_idf("heart",quote)}')
print(f'TF-IDF of mind in the quote: {tf_idf("mind",quote)}')
# Out:
# Value of the quote in the dictionary: 0.6116284719367076
# TF-IDF of disease in the quote: 0
# TF-IDF of heart in the quote: 0.3202951326865025
# TF-IDF of mind in the quote: 0.29133333925020505

# %% [markdown]
# # END-OF-CODE
